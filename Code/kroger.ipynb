# %%
import requests
import pandas as pd
import json

import base64
from datetime import datetime
from pprint import pprint

#new library
from urllib.parse import quote


from import_export import addTo_products_dataframe
from import_export import get_products_dataframe



#from api_keys import kroger_client_id
#from api_keys import kroger_client_secret


# >>> import base64
# >>> string = 'data to be encoded'
# >>> data = base64.b64encode(string.encode())
# >>> print(data)
# b'ZGF0YSB0byBiZSBlbmNvZGVk'


ingredients = ['eggs','flour','granulated sugar','milk','vanilla extract','salted butter', 'chocolate chips']
ingredients = ['large eggs','all purpose flour','granulated sugar','milk',
                   'pure vanilla extract','salted butter', 'chocolate chips',
                   'light brown sugar', 'iodized salt', 'baking soda', 'baking powder']
#store
#product
#price
#category
#store

# %%
#Code to provide authorization token
# Token can expire, rerun this if you start getting authorization errors

settings = {
  "async": True,
  "crossDomain": True,
  "url": "https://api.kroger.com/v1/connect/oauth2/token",
  "method": "POST",
  "headers": {
    "Content-Type": "application/x-www-form-urlencoded",
    "Authorization": "Basic " + base64.b64encode(b"grocerycomparisonproject-ba364435af369cc4088e0ccdf0dba1049128172333015617933:0N8WdzZAhfrQMNV7fnvDlPtApWoacv2o2hsRNUTq").decode()
  },
  "data": {
    "grant_type": "client_credentials"
  },
  "parameters": {"scope" : "product.compact"}
}

response = requests.post(settings["url"], headers=settings["headers"], data=settings["data"],params=settings["parameters"])

if response.status_code == 200:
    TOKEN = response.json()['access_token']
else:
    print("Request failed with status code:", response.status_code)

# %%
#Debugging
print(response.json()['access_token'])
# Out:
# eyJhbGciOiJSUzI1NiIsImprdSI6Imh0dHBzOi8vYXBpLmtyb2dlci5jb20vdjEvLndlbGwta25vd24vandrcy5qc29uIiwia2lkIjoiWjRGZDNtc2tJSDg4aXJ0N0xCNWM2Zz09IiwidHlwIjoiSldUIn0.....wnJpZwaILU8f_KdBugV7oHUj0e05FeCzzak5_FoRVag3lntaAMvs1eUeEGGo84WvYlq3xMRzgQqyxm8j4MdMmsKWqd6Vznt_lHuw9Ggj7v2ghPY7butRgMJIPQloxmF9rDxtovj7wqPXtwzZk64SILk3LLba-BIs0tcYmosRcMWXbKBb39GsCIx5SmK5KMac4wfVBvdQJ5Fnn_kqUaaU--FrU6EaQAydXuRKi4FyFpeSvkZoWp7KSs3ZvP_ZzyYtJB9fsiKo8H0JtwD3OxrJ00eNt-HrA39ilYtEWwPi8Z8-XSXBRl5eFyflriyhlj3vy5AV010FseGei534w8N33A

# %%
# using authorization token from above, request location data for zip code
# check documentation, can also change search radius - default is 10 miles

#Check pagination

zipCode = "44907"

settings = {
    "async": True,
    "crossDomain": True,
    "url": "https://api.kroger.com/v1/locations/?filter.zipCode.near=" + zipCode,
    "method": "GET",
    "headers": {
        "Accept": "application/json",
        "Authorization": "Bearer " + TOKEN   
    }
}

# Make the request
response = requests.get(settings["url"], headers=settings["headers"])

# Handle the response
if response.status_code == 200:
    locationData = response.json()
    #get first location in the list
    pprint(locationData['data'][0])
else:
    print("Request failed with status code:", response.status_code)
# Out:
# {'address': {'addressLine1': '1500 Lexington Ave',
#              'city': 'Mansfield',
#              'county': 'RICHLAND COUNTY',
#              'state': 'OH',
#              'zipCode': '44907'},
#  'chain': 'KROGER',
#  'departments': [{'departmentId': '99', 'name': 'Check Cashing'},
#                  {'departmentId': '08', 'name': 'Floral'},
#                  {'departmentId': '12', 'name': 'Cosmetics'},
#                  {'departmentId': '32', 'name': 'Natural And Organics'},
#                  {'departmentId': '38', 'name': 'Apparel'},
#                  {'departmentId': '61', 'name': 'Ticketmaster'},
#                  {'departmentId': '89', 'name': 'Western Union'},
#                  {'departmentId': '94', 'name': 'Pickup'},
#                  {'departmentId': '06',
#                   'hours': {'friday': {'close': '21:00',
#                                        'open': '09:00',
#                                        'open24': False},
#                             'monday': {'close': '21:00',
#                                        'open': '09:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '21:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'sunday': {'close': '21:00',
#                                        'open': '11:00',
#                                        'open24': False},
#                             'thursday': {'close': '21:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'tuesday': {'close': '21:00',
#                                         'open': '09:00',
#                                         'open24': False},
#                             'wednesday': {'close': '21:00',
#                                           'open': '09:00',
#                                           'open24': False}},
#                   'name': 'Liquor'},
#                  {'departmentId': '18', 'name': 'Books And Magazines'},
#                  {'departmentId': '21', 'name': 'Self Checkout'},
#                  {'departmentId': '62', 'name': 'Urgent Care'},
#                  {'departmentId': '69', 'name': 'Online Deli/Bakery Ordering'},
#                  {'departmentId': '02', 'name': 'Bakery'},
#                  {'departmentId': '0G', 'name': 'Meal Kits'},
#                  {'departmentId': '29', 'name': 'Event Tickets'},
#                  {'departmentId': '04', 'name': 'Meat Department'},
#                  {'departmentId': '07', 'name': 'Restaurant'},
#                  {'departmentId': '09',
#                   'hours': {'friday': {'close': '20:00',
#                                        'open': '08:00',
#                                        'open24': False},
#                             'monday': {'close': '20:00',
#                                        'open': '08:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '18:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'sunday': {'close': '17:00',
#                                        'open': '10:00',
#                                        'open24': False},
#                             'thursday': {'close': '20:00',
#                                          'open': '08:00',
#                                          'open24': False},
#                             'tuesday': {'close': '20:00',
#                                         'open': '08:00',
#                                         'open24': False},
#                             'wednesday': {'close': '20:00',
#                                           'open': '08:00',
#                                           'open24': False}},
#                   'name': 'Pharmacy',
#                   'phone': '4197567023'},
#                  {'address': {'addressLine1': '1500 Lexington Ave',
#                               'city': 'Mansfield',
#                               'state': 'OH',
#                               'zipCode': '44907'},
#                   'departmentId': '10',
#                   'geolocation': {'latLng': '40.7188147,-82.5492472',
#                                   'latitude': 40.7188147,
#                                   'longitude': -82.5492472},
#                   'hours': {'friday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'monday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '23:00',
#                                          'open': '06:00',
#                                          'open24': False},
#                             'sunday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'thursday': {'close': '23:00',
#                                          'open': '06:00',
#                                          'open24': False},
#                             'tuesday': {'close': '23:00',
#                                         'open': '06:00',
#                                         'open24': False},
#                             'wednesday': {'close': '23:00',
#                                           'open': '06:00',
#                                           'open24': False}},
#                   'name': 'Gas Station',
#                   'offsite': True,
#                   'phone': '4197563275'},
#                  {'departmentId': '46', 'name': 'Sushi'},
#                  {'departmentId': '55', 'name': 'Atm'},
#                  {'departmentId': 'TL', 'name': 'Tobacco'},
#                  {'departmentId': '01', 'name': 'Deli'},
#                  {'departmentId': '11', 'name': 'Bank'},
#                  {'departmentId': '48', 'name': 'Starbucks'},
#                  {'departmentId': '50', 'name': 'Olive Bar'},
#                  {'departmentId': 'AF', 'name': 'Account Funding'},
#                  {'departmentId': '03', 'name': 'Cheese Counter'},
#                  {'departmentId': '05', 'name': 'Seafood Department'},
#                  {'departmentId': '16', 'name': 'Drive-thru Pharmacy'},
#                  {'departmentId': '23', 'name': 'Drug & General Merchandise'},
#                  {'departmentId': '37', 'name': 'Shoes'},
#                  {'departmentId': '65', 'name': 'Money Services'},
#                  {'departmentId': '73', 'name': 'Eco Atm'},
#                  {'departmentId': '31', 'name': 'Coinstar'},
#                  {'departmentId': '44', 'name': 'Beer'},
#                  {'departmentId': '49', 'name': 'Kitchen Place'},
#                  {'departmentId': '60', 'name': 'Redbox'},
#                  {'departmentId': '64', 'name': 'Baby World'},
#                  {'departmentId': '66', 'name': "Murray's Cheese"},
#                  {'departmentId': '0J', 'name': 'Home Chef'},
#                  {'departmentId': '45', 'name': 'Wine'},
#                  {'departmentId': '53', 'name': "Boar's Head"},
#                  {'departmentId': '58', 'name': 'Free Wireless Access'},
#                  {'departmentId': '63', 'name': 'I-wireless'},
#                  {'departmentId': 'LY', 'name': 'Lottery Tickets'}],
#  'divisionNumber': '016',
#  'geolocation': {'latLng': '40.7188147,-82.5492472',
#                  'latitude': 40.7188147,
#                  'longitude': -82.5492472},
#  'hours': {'friday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'gmtOffset': '(UTC-05:00) Eastern Time (US Canada)',
#            'monday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'open24': False,
#            'saturday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'sunday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'thursday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'timezone': 'America/New_York',
#            'tuesday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'wednesday': {'close': '22:00', 'open': '06:00', 'open24': False}},
#  'locationId': '01600836',
#  'name': 'Kroger Marketplace - Lexington Avenue',
#  'phone': '4197566049',
#  'storeNumber': '00836'}

# %%
#using first location in the list
print(locationData['data'][0]['name'])
print(locationData['data'][0]['locationId'])
print(locationData['data'][0]['geolocation'])
# Out:
# Kroger Marketplace - Lexington Avenue
# 01600836
# {'latitude': 40.7188147, 'longitude': -82.5492472, 'latLng': '40.7188147,-82.5492472'}

# %%
# using authorization token from above, request location data for zip code
# check documentation, can also change search radius - default is 10 miles
chain = locationData['data'][0]['chain']
locationId = locationData['data'][0]['locationId']


#products_df = pd.DataFrame(columns = ['Item', 'Description','Price', 'Size'])
products = []

for ingredient in ingredients:
    #use urllib to change search term to URL friendly, like replacing spaces with %20
    searchTerm = quote(ingredient)

    #add filter for available in store

    #filter.productId
    #filter.fulfillment
    #   ais - Available In Store
    #   csp - Curbside Pickup
    #   dth - Delivery To Home
    #   sth - Ship To Home

    settings = {
        "async": True,
        "crossDomain": True,
        "url": f"https://api.kroger.com/v1/products/?filter.locationId={locationId}&filter.term={searchTerm}&filter.inStore=True&filter.fulfillment=ais",
        "method": "GET",
        "headers": {
            "Accept": "application/json",
            "Authorization": "Bearer " + TOKEN 
        }
    }

    # Make the request
    response = requests.get(settings["url"], headers=settings["headers"])

    # Handle the response
    if response.status_code == 200:
        productData = response.json()
        # pprint(productData['data'][0])

        
        for item in productData['data']:
            #Add to dataframe
            #columns = ['Item', 'Description','Price', 'Size'])
            # print(productData['data'][0]['upc'])
            # print(productData['data'][0]['description'])
            # print(productData['data'][0]['items'][0]['inventory']['stockLevel']) # HIGH,LOW,OUT-OF-STOCK
            # print(productData['data'][0]['items'][0]['price'])  #promo and regular
            # print(productData['data'][0]['items'][0]['size'])
            if item['items'][0]['price']['promo'] > 0:
                finalPrice = item['items'][0]['price']['promo']
            else:
                finalPrice = item['items'][0]['price']['regular']
                
            products.append({'Product': item['description'],
                             'Brand': item['brand'], 
                             'Price' : finalPrice, 
                             'Size' : item['items'][0]['size'],
                             'Ingredient' : ingredient,
                             'Store': chain,
                             'Date': datetime.now()})

    else:
        print("Request failed with status code:", response.status_code)

products_df = pd.DataFrame(products)
# Out:
# {'aisleLocations': [{'bayNumber': '30',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '2',
#                      'shelfNumber': '2',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'},
#                     {'bayNumber': '30',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '2',
#                      'shelfNumber': '3',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'}],
#  'brand': 'Simple Truth',
#  'categories': ['Breakfast', 'Dairy', 'Natural & Organic'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Simple Truth™ Natural Cage Free Large Brown Eggs',
#  'images': [{'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0001111079770'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0001111079770'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0001111079770'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0001111079770'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111079770'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0001111079770'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0001111079770'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0001111079770'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0001111079770'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111079770'}]}],
#  'itemInformation': {'depth': '4.0', 'height': '2.75', 'width': '11.5'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0001111079770',
#             'price': {'promo': 0, 'regular': 3.49},
#             'size': '12 ct',
#             'soldBy': 'UNIT'}],
#  'productId': '0001111079770',
#  'temperature': {'heatSensitive': False, 'indicator': 'Refrigerated'},
#  'upc': '0001111079770'}
# {'aisleLocations': [{'bayNumber': '12',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '7',
#                      'shelfNumber': '2',
#                      'shelfPositionInBay': '4',
#                      'side': 'R'}],
#  'brand': 'Kroger',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Kroger® Unbleached All Purpose Enriched Flour',
#  'images': [{'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0001111086116'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0001111086116'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0001111086116'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0001111086116'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111086116'}]},
#             {'perspective': 'right',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/right/0001111086116'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/right/0001111086116'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/right/0001111086116'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/right/0001111086116'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/right/0001111086116'}]},
#             {'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0001111086116'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0001111086116'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0001111086116'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0001111086116'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111086116'}]},
#             {'perspective': 'bottom',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/bottom/0001111086116'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/bottom/0001111086116'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/bottom/0001111086116'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/bottom/0001111086116'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/bottom/0001111086116'}]},
#             {'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0001111086116'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0001111086116'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0001111086116'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0001111086116'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0001111086116'}]}],
#  'itemInformation': {'depth': '4.0', 'height': '8.0', 'width': '6.0'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0001111086116',
#             'price': {'promo': 0, 'regular': 2.69},
#             'size': '5 lb',
#             'soldBy': 'UNIT'}],
#  'productId': '0001111086116',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0001111086116'}
# {'aisleLocations': [{'bayNumber': '7',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '4',
#                      'shelfNumber': '2',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'}],
#  'brand': 'Imperial Sugar',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Imperial Pure Granulated Cane Sugar',
#  'images': [{'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0007210002600'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0007210002600'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0007210002600'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0007210002600'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0007210002600'}]},
#             {'perspective': 'right',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/right/0007210002600'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/right/0007210002600'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/right/0007210002600'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/right/0007210002600'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/right/0007210002600'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0007210002600'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0007210002600'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0007210002600'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0007210002600'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0007210002600'}]}],
#  'itemInformation': {'depth': '2.5', 'height': '6.1', 'width': '3.6'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0007210002600',
#             'price': {'promo': 0, 'regular': 2.69},
#             'size': '2 lb',
#             'soldBy': 'UNIT'}],
#  'productId': '0007210002600',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0007210002600'}
# {'aisleLocations': [{'bayNumber': '54',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '4',
#                      'shelfNumber': '1',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'},
#                     {'bayNumber': '54',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '4',
#                      'shelfNumber': '2',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'},
#                     {'bayNumber': '54',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '4',
#                      'shelfNumber': '3',
#                      'shelfPositionInBay': '1',
#                      'side': 'R'}],
#  'brand': 'Kroger',
#  'categories': ['Dairy'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Kroger® 1% Lowfat Milk',
#  'images': [{'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0001111041660'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0001111041660'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0001111041660'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0001111041660'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111041660'}]},
#             {'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0001111041660'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0001111041660'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0001111041660'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0001111041660'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0001111041660'}]},
#             {'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0001111041660'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0001111041660'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0001111041660'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0001111041660'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0001111041660'}]},
#             {'perspective': 'top',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/top/0001111041660'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/top/0001111041660'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/top/0001111041660'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/top/0001111041660'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/top/0001111041660'}]}],
#  'itemInformation': {'depth': '6.15', 'height': '9.9', 'width': '6.2'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0001111041660',
#             'price': {'promo': 0, 'regular': 2.79},
#             'size': '1 gal',
#             'soldBy': 'UNIT'}],
#  'productId': '0001111041660',
#  'temperature': {'heatSensitive': False, 'indicator': 'Refrigerated'},
#  'upc': '0001111041660'}
# {'aisleLocations': [{'bayNumber': '14',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '3',
#                      'shelfNumber': '9',
#                      'shelfPositionInBay': '17',
#                      'side': 'R'}],
#  'brand': 'Private Selection',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Private Selection® Pure Vanilla Extract',
#  'images': [{'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0001111009984'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0001111009984'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0001111009984'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0001111009984'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0001111009984'}]},
#             {'perspective': 'right',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/right/0001111009984'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/right/0001111009984'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/right/0001111009984'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/right/0001111009984'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/right/0001111009984'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0001111009984'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0001111009984'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0001111009984'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0001111009984'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111009984'}]}],
#  'itemInformation': {'depth': '2.7', 'height': '7.24', 'width': '2.7'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0001111009984',
#             'price': {'promo': 0, 'regular': 23.99},
#             'size': '16 fl oz',
#             'soldBy': 'UNIT'}],
#  'productId': '0001111009984',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0001111009984'}
# {'aisleLocations': [{'bayNumber': '9',
#                      'description': 'DAIRY',
#                      'number': '100',
#                      'numberOfFacings': '1',
#                      'shelfNumber': '4',
#                      'shelfPositionInBay': '6',
#                      'side': 'R'}],
#  'brand': 'Kerrygold',
#  'categories': ['Dairy'],
#  'countryOrigin': 'IRELAND',
#  'description': 'Kerrygold™ Grass-Fed Salted Pure Irish Butter',
#  'images': [{'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0076770700106'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0076770700106'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0076770700106'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0076770700106'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0076770700106'}]}],
#  'itemInformation': {'depth': '1.45', 'height': '2.4', 'width': '4.25'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0076770700106',
#             'price': {'promo': 0, 'regular': 4.99},
#             'size': '8 oz',
#             'soldBy': 'UNIT'}],
#  'productId': '0076770700106',
#  'temperature': {'heatSensitive': False, 'indicator': 'Refrigerated'},
#  'upc': '0076770700106'}
# {'aisleLocations': [{'bayNumber': '6',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '3',
#                      'shelfNumber': '3',
#                      'shelfPositionInBay': '1',
#                      'side': 'L'}],
#  'brand': 'Nestle Toll House',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Nestle® Toll House® Semi Sweet Chocolate Chips',
#  'images': [{'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0002800021580'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0002800021580'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0002800021580'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0002800021580'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0002800021580'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0002800021580'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0002800021580'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0002800021580'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0002800021580'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0002800021580'}]}],
#  'itemInformation': {'depth': '1.0', 'height': '8.8', 'width': '8.1'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0002800021580',
#             'price': {'promo': 0, 'regular': 4.99},
#             'size': '12 oz',
#             'soldBy': 'UNIT'}],
#  'productId': '0002800021580',
#  'temperature': {'heatSensitive': True, 'indicator': 'Ambient'},
#  'upc': '0002800021580'}
# {'aisleLocations': [{'bayNumber': '6',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '1',
#                      'shelfNumber': '4',
#                      'shelfPositionInBay': '4',
#                      'side': 'R'}],
#  'brand': 'Simple Truth Organic',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'ARGENTINA',
#  'description': 'Simple Truth Organic® Light Brown Sugar',
#  'images': [{'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0001111085325'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0001111085325'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0001111085325'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0001111085325'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0001111085325'}]}],
#  'itemInformation': {'depth': '6.05', 'height': '2.6', 'width': '9.0'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0001111085325',
#             'price': {'promo': 0, 'regular': 3.79},
#             'size': '24 oz',
#             'soldBy': 'UNIT'}],
#  'productId': '0001111085325',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0001111085325'}
# {'aisleLocations': [{'bayNumber': '14',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '4',
#                      'shelfNumber': '1',
#                      'shelfPositionInBay': '2',
#                      'side': 'R'}],
#  'brand': 'Morton',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Morton® Iodized Table Salt',
#  'images': [{'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0002460001003'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0002460001003'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0002460001003'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0002460001003'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0002460001003'}]},
#             {'perspective': 'right',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/right/0002460001003'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/right/0002460001003'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/right/0002460001003'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/right/0002460001003'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/right/0002460001003'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0002460001003'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0002460001003'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0002460001003'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0002460001003'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0002460001003'}]},
#             {'perspective': 'top',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/top/0002460001003'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/top/0002460001003'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/top/0002460001003'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/top/0002460001003'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/top/0002460001003'}]},
#             {'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0002460001003'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0002460001003'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0002460001003'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0002460001003'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0002460001003'}]}],
#  'itemInformation': {'depth': '3.38', 'height': '5.5', 'width': '3.38'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0002460001003',
#             'price': {'promo': 0, 'regular': 1.49},
#             'size': '26 oz',
#             'soldBy': 'UNIT'}],
#  'productId': '0002460001003',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0002460001003'}
# {'aisleLocations': [{'bayNumber': '4',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '2',
#                      'shelfNumber': '7',
#                      'shelfPositionInBay': '7',
#                      'side': 'L'}],
#  'brand': 'Arm & Hammer',
#  'categories': ['Baking Goods'],
#  'countryOrigin': 'UNITED STATES',
#  'description': 'Arm & Hammer™ Pure Baking Soda',
#  'images': [{'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0003320001110'}]},
#             {'perspective': 'right',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/right/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/right/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/right/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/right/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/right/0003320001110'}]},
#             {'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0003320001110'}]},
#             {'perspective': 'bottom',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/bottom/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/bottom/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/bottom/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/bottom/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/bottom/0003320001110'}]},
#             {'perspective': 'top',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/top/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/top/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/top/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/top/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/top/0003320001110'}]},
#             {'perspective': 'left',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/left/0003320001110'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/left/0003320001110'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/left/0003320001110'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/left/0003320001110'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/left/0003320001110'}]}],
#  'itemInformation': {'depth': '2.09', 'height': '4.69', 'width': '3.58'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0003320001110',
#             'price': {'promo': 0, 'regular': 1.69},
#             'size': '1 lb',
#             'soldBy': 'UNIT'}],
#  'productId': '0003320001110',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0003320001110'}
# {'aisleLocations': [{'bayNumber': '8',
#                      'description': 'AISLE 14',
#                      'number': '14',
#                      'numberOfFacings': '1',
#                      'shelfNumber': '8',
#                      'shelfPositionInBay': '9',
#                      'side': 'L'}],
#  'brand': "Fleischmann's",
#  'categories': ['Natural & Organic'],
#  'countryOrigin': 'CANADA',
#  'description': "Fleischmann's® Pizza Crust Yeast",
#  'images': [{'perspective': 'back',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/back/0004010000781'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/back/0004010000781'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/back/0004010000781'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/back/0004010000781'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/back/0004010000781'}]},
#             {'featured': True,
#              'perspective': 'front',
#              'sizes': [{'size': 'xlarge',
#                         'url': 'https://www.kroger.com/product/images/xlarge/front/0004010000781'},
#                        {'size': 'large',
#                         'url': 'https://www.kroger.com/product/images/large/front/0004010000781'},
#                        {'size': 'medium',
#                         'url': 'https://www.kroger.com/product/images/medium/front/0004010000781'},
#                        {'size': 'small',
#                         'url': 'https://www.kroger.com/product/images/small/front/0004010000781'},
#                        {'size': 'thumbnail',
#                         'url': 'https://www.kroger.com/product/images/thumbnail/front/0004010000781'}]}],
#  'itemInformation': {'depth': '3.0', 'height': '0.45', 'width': '8.15'},
#  'items': [{'favorite': False,
#             'fulfillment': {'curbside': True,
#                             'delivery': True,
#                             'inStore': True,
#                             'shipToHome': False},
#             'inventory': {'stockLevel': 'HIGH'},
#             'itemId': '0004010000781',
#             'price': {'promo': 0, 'regular': 2.69},
#             'size': '3 ct',
#             'soldBy': 'UNIT'}],
#  'productId': '0004010000781',
#  'temperature': {'heatSensitive': False, 'indicator': 'Ambient'},
#  'upc': '0004010000781'}

# %%
# print(products_df)
# Out:
#                                               Product                 Brand  \
# 0    Simple Truth™ Natural Cage Free Large Brown Eggs          Simple Truth
# 1   Eggland's Best Classic Large White Eggs, 12 count        Eggland's Best
# 2                   Eggland's Best Grade A Eggs Large        Eggland's Best
# 3                    Kroger® Grade A Large White Eggs                Kroger
# 4                     Eggland's Best Extra Large Eggs        Eggland's Best
# ..                                                ...                   ...
# 95          Simple Truth Organic™ Ground Curry Powder  Simple Truth Organic
# 96    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can             Hershey's
# 97     HERSHEY'S Natural Unsweetened Cocoa Powder Can             Hershey's
# 98                         Clabber Girl Baking Powder          Clabber Girl
# 99                  Bragg Nutritional Yeast Seasoning                 Bragg
#
#     Price          Size     Ingredient   Store                       Date
# 0    3.49         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 1    3.69         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 2    5.49         18 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 3    3.99         18 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 4    3.79         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# ..    ...           ...            ...     ...                        ...
# 95   4.29       1.66 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 96   5.99  1 can / 8 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 97   5.99  1 can / 8 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 98   3.79        8.1 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 99   7.99        4.5 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
#
# [100 rows x 7 columns]

# %%
print(productData['data'][0]['upc'])
print(productData['data'][0]['description'])
print(productData['data'][0]['items'][0]['inventory']['stockLevel']) # HIGH,LOW,OUT-OF-STOCK
print(productData['data'][0]['items'][0]['price'])  #promo and regular
print(productData['data'][0]['items'][0]['size'])
# Out:
# 0004010000781
# Fleischmann's® Pizza Crust Yeast
# HIGH
# {'regular': 2.69, 'promo': 0}
# 3 ct

# %%
products_df["Ingredient"].replace("salted butter", "butter", inplace=True)

# ??do additional ingredient name cleanup
# ??drop index/allow the database to handle it

kroger_products_df = products_df
kroger_products_df
# Out:
#                                               Product                 Brand  \
# 0    Simple Truth™ Natural Cage Free Large Brown Eggs          Simple Truth
# 1   Eggland's Best Classic Large White Eggs, 12 count        Eggland's Best
# 2                   Eggland's Best Grade A Eggs Large        Eggland's Best
# 3                    Kroger® Grade A Large White Eggs                Kroger
# 4                     Eggland's Best Extra Large Eggs        Eggland's Best
# ..                                                ...                   ...
# 95          Simple Truth Organic™ Ground Curry Powder  Simple Truth Organic
# 96    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can             Hershey's
# 97     HERSHEY'S Natural Unsweetened Cocoa Powder Can             Hershey's
# 98                         Clabber Girl Baking Powder          Clabber Girl
# 99                  Bragg Nutritional Yeast Seasoning                 Bragg
#
#     Price          Size     Ingredient   Store                       Date
# 0    3.49         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 1    3.69         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 2    5.49         18 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 3    3.99         18 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# 4    3.79         12 ct     large eggs  KROGER 2024-02-28 14:53:48.423706
# ..    ...           ...            ...     ...                        ...
# 95   4.29       1.66 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 96   5.99  1 can / 8 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 97   5.99  1 can / 8 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 98   3.79        8.1 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
# 99   7.99        4.5 oz  baking powder  KROGER 2024-02-28 14:54:02.916930
#
# [100 rows x 7 columns]

# %%
# %store kroger_products_df
# Out:
# Stored 'kroger_products_df' (DataFrame)

# %%
#Get dataframe of products currently in the database

df = pd.DataFrame()
df = get_products_dataframe()

df
# Out:
#       id                                            product  \
# 0   None   Simple Truth™ Natural Cage Free Large Brown Eggs
# 1   None  Eggland's Best Classic Large White Eggs, 12 count
# 2   None                  Eggland's Best Grade A Eggs Large
# 3   None                   Kroger® Grade A Large White Eggs
# 4   None                    Eggland's Best Extra Large Eggs
# ..   ...                                                ...
# 95  None          Simple Truth Organic™ Ground Curry Powder
# 96  None    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can
# 97  None     HERSHEY'S Natural Unsweetened Cocoa Powder Can
# 98  None                         Clabber Girl Baking Powder
# 99  None                  Bragg Nutritional Yeast Seasoning
#
#                    brand  price          size     ingredient   store  \
# 0           Simple Truth   3.49         12 ct     large eggs  KROGER
# 1         Eggland's Best   3.69         12 ct     large eggs  KROGER
# 2         Eggland's Best   5.49         18 ct     large eggs  KROGER
# 3                 Kroger   3.99         18 ct     large eggs  KROGER
# 4         Eggland's Best   3.79         12 ct     large eggs  KROGER
# ..                   ...    ...           ...            ...     ...
# 95  Simple Truth Organic   4.29       1.66 oz  baking powder  KROGER
# 96             Hershey's   5.99  1 can / 8 oz  baking powder  KROGER
# 97             Hershey's   5.99  1 can / 8 oz  baking powder  KROGER
# 98          Clabber Girl   3.79        8.1 oz  baking powder  KROGER
# 99                 Bragg   7.99        4.5 oz  baking powder  KROGER
#
#                           date
# 0   2024-02-28 14:53:48.423706
# 1   2024-02-28 14:53:48.423706
# 2   2024-02-28 14:53:48.423706
# 3   2024-02-28 14:53:48.423706
# 4   2024-02-28 14:53:48.423706
# ..                         ...
# 95  2024-02-28 14:54:02.916930
# 96  2024-02-28 14:54:02.916930
# 97  2024-02-28 14:54:02.916930
# 98  2024-02-28 14:54:02.916930
# 99  2024-02-28 14:54:02.916930
#
# [100 rows x 8 columns]

# %%
#add products dataframe to database products table

addTo_products_dataframe(kroger_products_df)
# Out:
# c:\Users\aholm\Documents\Data Science Bootcamp\Classwork\Project 3\Round 2\grocery_comparison_project\Code\april.py:70: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_df.to_sql(name='products',con=engine.raw_connection(), if_exists='append',index=False)
