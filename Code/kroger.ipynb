# %%
import requests
import pandas as pd
import json

import base64
from datetime import datetime
from pprint import pprint

#new library
from urllib.parse import quote

from import_export import addTo_products_dataframe
from import_export import get_products_dataframe
from import_export import get_cheapest_products_bydate

#from api_keys import kroger_client_id
#from api_keys import kroger_client_secret

# >>> import base64
# >>> string = 'data to be encoded'
# >>> data = base64.b64encode(string.encode())
# >>> print(data)
# b'ZGF0YSB0byBiZSBlbmNvZGVk'

ingredients = ['eggs','flour','granulated sugar','milk',
                   'vanilla extract','butter', 'chocolate chips',
                   'light brown sugar', 'salt', 'baking soda', 'baking powder']
#store
#product
#price
#category
#store
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 14
#      12 from import_export import addTo_products_dataframe
#      13 from import_export import get_products_dataframe
# ---> 14 from import_export import get_cheapest_products_bydate
#      16 #from api_keys import kroger_client_id
#      17 #from api_keys import kroger_client_secret
#      18
#    (...)
#      22 # >>> print(data)
#      23 # b'ZGF0YSB0byBiZSBlbmNvZGVk'
#      25 ingredients = ['eggs','flour','granulated sugar','milk',
#      26                    'vanilla extract','butter', 'chocolate chips',
#      27                    'light brown sugar', 'salt', 'baking soda', 'baking powder']
#
# ImportError: cannot import name 'get_cheapest_products_bydate' from 'import_export' (c:\Users\aholm\Documents\Data Science Bootcamp\Classwork\Project 3\Round 2\grocery_comparison_project\Code\import_export.py)

# %%
#Code to provide authorization token
# Token can expire, rerun this if you start getting authorization errors

settings = {
  "async": True,
  "crossDomain": True,
  "url": "https://api.kroger.com/v1/connect/oauth2/token",
  "method": "POST",
  "headers": {
    "Content-Type": "application/x-www-form-urlencoded",
    "Authorization": "Basic " + base64.b64encode(b"grocerycomparisonproject-ba364435af369cc4088e0ccdf0dba1049128172333015617933:0N8WdzZAhfrQMNV7fnvDlPtApWoacv2o2hsRNUTq").decode()
  },
  "data": {
    "grant_type": "client_credentials"
  },
  "parameters": {"scope" : "product.compact"}
}

response = requests.post(settings["url"], headers=settings["headers"], data=settings["data"],params=settings["parameters"])

if response.status_code == 200:
    TOKEN = response.json()['access_token']
else:
    print("Request failed with status code:", response.status_code)

# %%
#Debugging
print(response.json()['access_token'])
# Out:
# eyJhbGciOiJSUzI1NiIsImprdSI6Imh0dHBzOi8vYXBpLmtyb2dlci5jb20vdjEvLndlbGwta25vd24vandrcy5qc29uIiwia2lkIjoiWjRGZDNtc2tJSDg4aXJ0N0xCNWM2Zz09IiwidHlwIjoiSldUIn0.....svPqJtBObIl4Xl_5hEtHAjgMB74kY7wS5urw3rz2EIPPpja6oxJRTnYuvi9GFc_vzmNd2GC6iF1NsA2kps24qX03NE-XK7OwwYmsYIW2jSrwRe0ODkz_5RvpC85dwPn7BJqrAD3kKB0bhrYt4ar_aRtGb9bwVzJRlVS_xUuMLis7VKu3ZBnIY1lVLbF3s2ObSQt_7OkFWZvFHflo7_X0sWbSKbCAO5JzTQKo2c9w7sexfNevHClogv4pggxrya7WFBEHm9GUYh6WQwrWhvDAWug7LkPlHDJHQHxtWyRxjuehR_BlA1NzCo3E_8dR9MTswxcC6XtkPWNrFHOaCjjZ0g

# %%
# using authorization token from above, request location data for zip code
# check documentation, can also change search radius - default is 10 miles

#Check pagination

zipCode = "44907"

settings = {
    "async": True,
    "crossDomain": True,
    "url": "https://api.kroger.com/v1/locations/?filter.zipCode.near=" + zipCode,
    "method": "GET",
    "headers": {
        "Accept": "application/json",
        "Authorization": "Bearer " + TOKEN   
    }
}

# Make the request
response = requests.get(settings["url"], headers=settings["headers"])

# Handle the response
if response.status_code == 200:
    locationData = response.json()
    #get first location in the list
    pprint(locationData['data'][0])
else:
    print("Request failed with status code:", response.status_code)
# Out:
# {'address': {'addressLine1': '1500 Lexington Ave',
#              'city': 'Mansfield',
#              'county': 'RICHLAND COUNTY',
#              'state': 'OH',
#              'zipCode': '44907'},
#  'chain': 'KROGER',
#  'departments': [{'departmentId': '31', 'name': 'Coinstar'},
#                  {'departmentId': '29', 'name': 'Event Tickets'},
#                  {'departmentId': '53', 'name': "Boar's Head"},
#                  {'departmentId': '65', 'name': 'Money Services'},
#                  {'departmentId': '66', 'name': "Murray's Cheese"},
#                  {'departmentId': '73', 'name': 'Eco Atm'},
#                  {'departmentId': '18', 'name': 'Books And Magazines'},
#                  {'departmentId': '04', 'name': 'Meat Department'},
#                  {'departmentId': '09',
#                   'hours': {'friday': {'close': '20:00',
#                                        'open': '08:00',
#                                        'open24': False},
#                             'monday': {'close': '20:00',
#                                        'open': '08:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '18:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'sunday': {'close': '17:00',
#                                        'open': '10:00',
#                                        'open24': False},
#                             'thursday': {'close': '20:00',
#                                          'open': '08:00',
#                                          'open24': False},
#                             'tuesday': {'close': '20:00',
#                                         'open': '08:00',
#                                         'open24': False},
#                             'wednesday': {'close': '20:00',
#                                           'open': '08:00',
#                                           'open24': False}},
#                   'name': 'Pharmacy',
#                   'phone': '4197567023'},
#                  {'departmentId': '12', 'name': 'Cosmetics'},
#                  {'departmentId': '16', 'name': 'Drive-thru Pharmacy'},
#                  {'departmentId': '38', 'name': 'Apparel'},
#                  {'departmentId': '63', 'name': 'I-wireless'},
#                  {'departmentId': '99', 'name': 'Check Cashing'},
#                  {'departmentId': '01', 'name': 'Deli'},
#                  {'departmentId': 'TL', 'name': 'Tobacco'},
#                  {'departmentId': '05', 'name': 'Seafood Department'},
#                  {'departmentId': '23', 'name': 'Drug & General Merchandise'},
#                  {'departmentId': '45', 'name': 'Wine'},
#                  {'departmentId': '48', 'name': 'Starbucks'},
#                  {'departmentId': '49', 'name': 'Kitchen Place'},
#                  {'departmentId': '50', 'name': 'Olive Bar'},
#                  {'departmentId': '58', 'name': 'Free Wireless Access'},
#                  {'departmentId': '02', 'name': 'Bakery'},
#                  {'departmentId': '60', 'name': 'Redbox'},
#                  {'departmentId': '0G', 'name': 'Meal Kits'},
#                  {'departmentId': '11', 'name': 'Bank'},
#                  {'departmentId': '61', 'name': 'Ticketmaster'},
#                  {'departmentId': '62', 'name': 'Urgent Care'},
#                  {'departmentId': '64', 'name': 'Baby World'},
#                  {'departmentId': '89', 'name': 'Western Union'},
#                  {'departmentId': '07', 'name': 'Restaurant'},
#                  {'departmentId': '0J', 'name': 'Home Chef'},
#                  {'address': {'addressLine1': '1500 Lexington Ave',
#                               'city': 'Mansfield',
#                               'state': 'OH',
#                               'zipCode': '44907'},
#                   'departmentId': '10',
#                   'geolocation': {'latLng': '40.7188147,-82.5492472',
#                                   'latitude': 40.7188147,
#                                   'longitude': -82.5492472},
#                   'hours': {'friday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'monday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '23:00',
#                                          'open': '06:00',
#                                          'open24': False},
#                             'sunday': {'close': '23:00',
#                                        'open': '06:00',
#                                        'open24': False},
#                             'thursday': {'close': '23:00',
#                                          'open': '06:00',
#                                          'open24': False},
#                             'tuesday': {'close': '23:00',
#                                         'open': '06:00',
#                                         'open24': False},
#                             'wednesday': {'close': '23:00',
#                                           'open': '06:00',
#                                           'open24': False}},
#                   'name': 'Gas Station',
#                   'offsite': True,
#                   'phone': '4197563275'},
#                  {'departmentId': '21', 'name': 'Self Checkout'},
#                  {'departmentId': '32', 'name': 'Natural And Organics'},
#                  {'departmentId': '08', 'name': 'Floral'},
#                  {'departmentId': '44', 'name': 'Beer'},
#                  {'departmentId': '46', 'name': 'Sushi'},
#                  {'departmentId': '55', 'name': 'Atm'},
#                  {'departmentId': '69', 'name': 'Online Deli/Bakery Ordering'},
#                  {'departmentId': '94', 'name': 'Pickup'},
#                  {'departmentId': 'LY', 'name': 'Lottery Tickets'},
#                  {'departmentId': '03', 'name': 'Cheese Counter'},
#                  {'departmentId': '37', 'name': 'Shoes'},
#                  {'departmentId': 'AF', 'name': 'Account Funding'},
#                  {'departmentId': '06',
#                   'hours': {'friday': {'close': '21:00',
#                                        'open': '09:00',
#                                        'open24': False},
#                             'monday': {'close': '21:00',
#                                        'open': '09:00',
#                                        'open24': False},
#                             'open24': False,
#                             'saturday': {'close': '21:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'sunday': {'close': '21:00',
#                                        'open': '11:00',
#                                        'open24': False},
#                             'thursday': {'close': '21:00',
#                                          'open': '09:00',
#                                          'open24': False},
#                             'tuesday': {'close': '21:00',
#                                         'open': '09:00',
#                                         'open24': False},
#                             'wednesday': {'close': '21:00',
#                                           'open': '09:00',
#                                           'open24': False}},
#                   'name': 'Liquor'}],
#  'divisionNumber': '016',
#  'geolocation': {'latLng': '40.7188147,-82.5492472',
#                  'latitude': 40.7188147,
#                  'longitude': -82.5492472},
#  'hours': {'friday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'gmtOffset': '(UTC-05:00) Eastern Time (US Canada)',
#            'monday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'open24': False,
#            'saturday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'sunday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'thursday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'timezone': 'America/New_York',
#            'tuesday': {'close': '22:00', 'open': '06:00', 'open24': False},
#            'wednesday': {'close': '22:00', 'open': '06:00', 'open24': False}},
#  'locationId': '01600836',
#  'name': 'Kroger Marketplace - Lexington Avenue',
#  'phone': '4197566049',
#  'storeNumber': '00836'}

# %%
#using first location in the list
print(locationData['data'][0]['name'])
print(locationData['data'][0]['locationId'])
print(locationData['data'][0]['geolocation'])
# Out:
# Kroger Marketplace - Lexington Avenue
# 01600836
# {'latitude': 40.7188147, 'longitude': -82.5492472, 'latLng': '40.7188147,-82.5492472'}

# %%
# using authorization token from above, request location data for zip code
# check documentation, can also change search radius - default is 10 miles
chain = locationData['data'][0]['chain']
locationId = locationData['data'][0]['locationId']


#products_df = pd.DataFrame(columns = ['Item', 'Description','Price', 'Size'])
products = []

for ingredient in ingredients:
    #use urllib to change search term to URL friendly, like replacing spaces with %20
    searchTerm = quote(ingredient)

    #add filter for available in store

    #filter.productId
    #filter.fulfillment
    #   ais - Available In Store
    #   csp - Curbside Pickup
    #   dth - Delivery To Home
    #   sth - Ship To Home

    settings = {
        "async": True,
        "crossDomain": True,
        "url": f"https://api.kroger.com/v1/products/?filter.locationId={locationId}&filter.term={searchTerm}&filter.inStore=True&filter.fulfillment=ais",
        "method": "GET",
        "headers": {
            "Accept": "application/json",
            "Authorization": "Bearer " + TOKEN 
        }
    }

    # Make the request
    response = requests.get(settings["url"], headers=settings["headers"])

    # Handle the response
    if response.status_code == 200:
        productData = response.json()
        # pprint(productData['data'][0])

        
        for item in productData['data']:
            #Add to dataframe
            #columns = ['Item', 'Description','Price', 'Size'])
            # print(productData['data'][0]['upc'])
            # print(productData['data'][0]['description'])
            # print(productData['data'][0]['items'][0]['inventory']['stockLevel']) # HIGH,LOW,OUT-OF-STOCK
            # print(productData['data'][0]['items'][0]['price'])  #promo and regular
            # print(productData['data'][0]['items'][0]['size'])
            if item['items'][0]['price']['promo'] > 0:
                finalPrice = item['items'][0]['price']['promo']
            else:
                finalPrice = item['items'][0]['price']['regular']
                
            products.append({'Product': item['description'],
                             'Brand': item['brand'], 
                             'Price' : finalPrice, 
                             'Size' : item['items'][0]['size'],
                             'Ingredient' : ingredient,
                             'Store': chain,
                             'Date': datetime.now().strftime("%Y-%m-%d")})

    else:
        print("Request failed with status code:", response.status_code)

products_df = pd.DataFrame(products)

# %%
products_df
# Out:
#                                               Product           Brand  Price  \
# 0    Simple Truth™ Natural Cage Free Large Brown Eggs    Simple Truth   3.49
# 1   Eggland's Best Classic Large White Eggs, 12 count  Eggland's Best   3.69
# 2                    Kroger® Grade A Large White Eggs          Kroger   3.99
# 3          Happy Egg Co.® Free Range Large Brown Eggs   Happy Egg Co.   7.99
# 4   Happy Egg Co.® Free Range Large Brown Organic ...   Happy Egg Co.   6.99
# ..                                                ...             ...    ...
# 95    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can       Hershey's   5.99
# 96                     Simple Truth Nutritional Yeast    Simple Truth   5.99
# 97     HERSHEY'S Natural Unsweetened Cocoa Powder Can       Hershey's   5.99
# 98                         Clabber Girl Baking Powder    Clabber Girl   3.79
# 99                  Bragg Nutritional Yeast Seasoning           Bragg   7.99
#
#             Size     Ingredient   Store        Date
# 0          12 ct           eggs  KROGER  2024-02-29
# 1          12 ct           eggs  KROGER  2024-02-29
# 2          18 ct           eggs  KROGER  2024-02-29
# 3          18 ct           eggs  KROGER  2024-02-29
# 4          12 ct           eggs  KROGER  2024-02-29
# ..           ...            ...     ...         ...
# 95  1 can / 8 oz  baking powder  KROGER  2024-02-29
# 96        4.5 oz  baking powder  KROGER  2024-02-29
# 97  1 can / 8 oz  baking powder  KROGER  2024-02-29
# 98        8.1 oz  baking powder  KROGER  2024-02-29
# 99        4.5 oz  baking powder  KROGER  2024-02-29
#
# [100 rows x 7 columns]

# %%
print(productData['data'][0]['upc'])
print(productData['data'][0]['description'])
print(productData['data'][0]['items'][0]['inventory']['stockLevel']) # HIGH,LOW,OUT-OF-STOCK
print(productData['data'][0]['items'][0]['price'])  #promo and regular
print(productData['data'][0]['items'][0]['size'])
# Out:
# 0004010000781
# Fleischmann's® Pizza Crust Yeast
# HIGH
# {'regular': 2.69, 'promo': 0}
# 3 ct

# %%
products_df["Ingredient"].replace("salted butter", "butter", inplace=True)

# ??do additional ingredient name cleanup
# ??drop index/allow the database to handle it

kroger_products_df = products_df
kroger_products_df
# Out:
#                                               Product           Brand  Price  \
# 0    Simple Truth™ Natural Cage Free Large Brown Eggs    Simple Truth   3.49
# 1   Eggland's Best Classic Large White Eggs, 12 count  Eggland's Best   3.69
# 2                    Kroger® Grade A Large White Eggs          Kroger   3.99
# 3          Happy Egg Co.® Free Range Large Brown Eggs   Happy Egg Co.   7.99
# 4   Happy Egg Co.® Free Range Large Brown Organic ...   Happy Egg Co.   6.99
# ..                                                ...             ...    ...
# 95    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can       Hershey's   5.99
# 96                     Simple Truth Nutritional Yeast    Simple Truth   5.99
# 97     HERSHEY'S Natural Unsweetened Cocoa Powder Can       Hershey's   5.99
# 98                         Clabber Girl Baking Powder    Clabber Girl   3.79
# 99                  Bragg Nutritional Yeast Seasoning           Bragg   7.99
#
#             Size     Ingredient   Store        Date
# 0          12 ct           eggs  KROGER  2024-02-29
# 1          12 ct           eggs  KROGER  2024-02-29
# 2          18 ct           eggs  KROGER  2024-02-29
# 3          18 ct           eggs  KROGER  2024-02-29
# 4          12 ct           eggs  KROGER  2024-02-29
# ..           ...            ...     ...         ...
# 95  1 can / 8 oz  baking powder  KROGER  2024-02-29
# 96        4.5 oz  baking powder  KROGER  2024-02-29
# 97  1 can / 8 oz  baking powder  KROGER  2024-02-29
# 98        8.1 oz  baking powder  KROGER  2024-02-29
# 99        4.5 oz  baking powder  KROGER  2024-02-29
#
# [100 rows x 7 columns]

# %%
# %store kroger_products_df
# Out:
# Stored 'kroger_products_df' (DataFrame)

# %%
# Out:
#       id                                            product           brand  \
# 0      1   Simple Truth™ Natural Cage Free Large Brown Eggs    Simple Truth
# 1      2  Eggland's Best Classic Large White Eggs, 12 count  Eggland's Best
# 2      3                  Eggland's Best Grade A Eggs Large  Eggland's Best
# 3      4                   Kroger® Grade A Large White Eggs          Kroger
# 4      5                    Eggland's Best Extra Large Eggs  Eggland's Best
# ..   ...                                                ...             ...
# 239  240    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can       Hershey's
# 240  241                     Simple Truth Nutritional Yeast    Simple Truth
# 241  242     HERSHEY'S Natural Unsweetened Cocoa Powder Can       Hershey's
# 242  243                         Clabber Girl Baking Powder    Clabber Girl
# 243  244                  Bragg Nutritional Yeast Seasoning           Bragg
#
#      price          size     ingredient   store                        date
# 0     3.49         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 1     3.69         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 2     5.49         18 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 3     3.99         18 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 4     3.79         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# ..     ...           ...            ...     ...                         ...
# 239   5.99  1 can / 8 oz  baking powder  KROGER                  2024-02-29
# 240   5.99        4.5 oz  baking powder  KROGER                  2024-02-29
# 241   5.99  1 can / 8 oz  baking powder  KROGER                  2024-02-29
# 242   3.79        8.1 oz  baking powder  KROGER                  2024-02-29
# 243   7.99        4.5 oz  baking powder  KROGER                  2024-02-29
#
# [244 rows x 8 columns]

# %%
#add products dataframe to database products table

addTo_products_dataframe(kroger_products_df)
# Out:
# c:\Users\aholm\Documents\Data Science Bootcamp\Classwork\Project 3\Round 2\grocery_comparison_project\Code\import_export.py:53: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_df.to_sql(name='products',con=engine.raw_connection(), if_exists='append',index=False)

# %%
#Get dataframe of products currently in the database

df = pd.DataFrame()
df = get_products_dataframe()

df
# Out:
#       id                                            product           brand  \
# 0      1   Simple Truth™ Natural Cage Free Large Brown Eggs    Simple Truth
# 1      2  Eggland's Best Classic Large White Eggs, 12 count  Eggland's Best
# 2      3                  Eggland's Best Grade A Eggs Large  Eggland's Best
# 3      4                   Kroger® Grade A Large White Eggs          Kroger
# 4      5                    Eggland's Best Extra Large Eggs  Eggland's Best
# ..   ...                                                ...             ...
# 239  240    HERSHEY'S SPECIAL DARK Dutched Cocoa Powder Can       Hershey's
# 240  241                     Simple Truth Nutritional Yeast    Simple Truth
# 241  242     HERSHEY'S Natural Unsweetened Cocoa Powder Can       Hershey's
# 242  243                         Clabber Girl Baking Powder    Clabber Girl
# 243  244                  Bragg Nutritional Yeast Seasoning           Bragg
#
#      price          size     ingredient   store                        date
# 0     3.49         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 1     3.69         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 2     5.49         18 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 3     3.99         18 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# 4     3.79         12 ct     large eggs  KROGER  2024-02-28 14:53:48.423706
# ..     ...           ...            ...     ...                         ...
# 239   5.99  1 can / 8 oz  baking powder  KROGER                  2024-02-29
# 240   5.99        4.5 oz  baking powder  KROGER                  2024-02-29
# 241   5.99  1 can / 8 oz  baking powder  KROGER                  2024-02-29
# 242   3.79        8.1 oz  baking powder  KROGER                  2024-02-29
# 243   7.99        4.5 oz  baking powder  KROGER                  2024-02-29
#
# [244 rows x 8 columns]

# %%
grouped_df = df.groupby(['store','ingredient','date'])['price'].min()

grouped_df
# Out:
# store   ingredient
# Adli    baking powder           2.05
#         baking soda             0.99
#         iodized salt            0.75
# Aldi    butter                  2.99
#         chocolate chips         2.57
#         eggs                    2.09
#         flour                   2.55
#         granulated sugar        2.39
#         milk                    1.75
#         vanilla extract         5.49
# KROGER  all purpose flour       2.69
#         baking powder           2.69
#         baking soda             1.19
#         butter                  3.50
#         chocolate chips         2.69
#         eggs                    2.49
#         granulated sugar        2.69
#         iodized salt            0.79
#         large eggs              2.09
#         light brown sugar       2.79
#         milk                    1.99
#         pure vanilla extract    5.99
#         vanilla extract         1.99
# Name: price, dtype: float64

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from datetime import date
from sqlalchemy import text, func

from sqlalchemy import update
from sqlalchemy import delete


# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///../grocery.sqlite")

    # Declare a Base using `automap_base()`
Base = automap_base()

    # Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

Products = Base.classes.products

    
session = Session(bind=engine)


#date_rows = session.query(text("* from products WHERE date  IS NULL"))


update_to_date = date(2024, 2, 28)
stmt = (
     update(Products)
     .where(Products.date < date(2024, 2, 29))
     .values(date = update_to_date)
 )
engine.execute(stmt)

stmt = (
     update(Products)
     .where(Products.ingredient == "pure vanilla extract")
     .values(ingredient = "vanilla extract")
 )

engine.execute(stmt)

stmt = (
     update(Products)
     .where(Products.ingredient == "light brown sugar")
     .values(ingredient = "brown sugar")
 )

engine.execute(stmt)

stmt = (
     update(Products)
     .where(Products.ingredient == "large eggs")
     .values(ingredient = "eggs")
 )

engine.execute(stmt)

stmt = (
     update(Products)
     .where(Products.ingredient == "all purpose flour")
     .values(ingredient = "flour")
 )

engine.execute(stmt)

stmt = (
     delete(Products)
     .where(Products.ingredient == "brown sugar")
 )

engine.execute(stmt)


session.commit()

for row in session.query(Products.ingredient).\
     group_by(Products.ingredient).all():
     
         print(row)

# for row in session.query(Products.store).\
#      group_by(Products.store).all():
     
#          print(row)

# for row in session.query(Products.date, Products.store).\
#      group_by(Products.date).\
#         group_by(Products.store).\
#             order_by(Products.store).all():
     
#          print(row)

# session.commit()
#print(date_rows.count())

# for product in date_rows:
#     #print(product.id)
#     print(Products.product)
#     print(Products.store)
# Out:
# ('baking powder',)
# ('baking soda',)
# ('butter',)
# ('chocolate chips',)
# ('eggs',)
# ('flour',)
# ('granulated sugar',)
# ('iodized salt',)
# ('milk',)
# ('salt',)
# ('vanilla extract',)

# %%
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from datetime import date
from sqlalchemy import text, func

from sqlalchemy import update
from sqlalchemy import delete

import pandas as pd



# Create engine using the `grocery.sqlite` database file

engine = create_engine("sqlite:///../grocery.sqlite")
    
    # Declare a Base using `automap_base()`
Base = automap_base()

    # Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

    # Print all of the classes mapped to the Base
    # Base.classes.keys()
Products = Base.classes.products

session = Session(engine)
session = Session(bind=engine)


# sel = [Products.ingredient, Products.store, Products.date, 
#     func.min(Products.price)
#     ]

sel = [Products.ingredient, Products.store, Products.date, Products.price
    ]
prices = session.query(*sel).\
    group_by(Products.ingredient).\
    group_by(Products.store).\
    group_by(Products.date).\
    order_by(Products.date, Products.store, Products.ingredient).all()

session.close()

df1 = pd.DataFrame(prices)

cheapest_prices = df1.groupby(['store','date','price'])['price'].min()

# # df = df.groupby(['store', 'date'])['ingredient'].sum()
# print (df)

# print (df1)

cookie_totals_df = pd.DataFrame(df1.groupby(['store','date'])['price'].sum())
# cookie_totals_df = df1.groupby(['store','date'])['price'].sum()


cookie_totals_df.reset_index(inplace=True)
cookie_totals_df

clean_df = pd.DataFrame(cookie_totals_df)
# # clean_df.set_index(['date','store'], inplace=True)
# # clean_df.plot.bar()

# clean_df.plot(x=["date", "store"], y="price", kind="bar")

clean_df.pivot(index='date', columns='store', values='price').plot(kind='bar')
plt.savefig("totals_by_date.png")
