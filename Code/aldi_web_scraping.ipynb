# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd

url = 'https://new.aldi.us/products/dairy-eggs/eggs/k/75'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')
#print(soup.prettify())

eggs_text_elements = soup.find('div', class_= "product-grid")

eggs_list = []

for elem in eggs_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    eggs_each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }
    eggs_list.append(eggs_each_product)

#eggs_list
eggs_df = pd.DataFrame(eggs_list)
eggs_df["Size"] = eggs_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
eggs_df["Price"] = eggs_df["Price"].str.replace(r'\n', '', regex=True)

eggs_df
# Out:
#                                              Product          Brand  \
# 0            Cage Free Large Eggs - Grade A, 1 dozen        Goldhen
# 1      Free Range Large Brown Grade A Eggs, 12 count        Goldhen
# 2                  Grade A Large White Eggs, 1 dozen        Goldhen
# 3              Organic Cage Free Brown Eggs, 1 dozen  Simply Nature
# 4                           Liquid Egg Whites, 32 oz        Goldhen
# 5  Pasture Raised Large Brown Eggs Grade A, 12 count        Goldhen
#
#               Price  Size
# 0       $2.75        12ct
# 1       $4.05        12ct
# 2       $3.09
# 3       $4.35        12ct
# 4       $4.65        32oz
# 5       $4.95        12ct

# %%
#eggs_text_elements = soup.find('div', class_= "product-grid")

#for text in eggs_text_elements:
 #   print(text.text)

# %%
filtered_eggs_df = eggs_df[~eggs_df["Product"].str.contains("Liquid|Whites", regex=True)]
filtered_eggs_df["Ingredient"] = "eggs"
filtered_eggs_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1168351348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_eggs_df["Ingredient"] = "eggs"
#                                              Product          Brand  \
# 0            Cage Free Large Eggs - Grade A, 1 dozen        Goldhen
# 1      Free Range Large Brown Grade A Eggs, 12 count        Goldhen
# 2                  Grade A Large White Eggs, 1 dozen        Goldhen
# 3              Organic Cage Free Brown Eggs, 1 dozen  Simply Nature
# 5  Pasture Raised Large Brown Eggs Grade A, 12 count        Goldhen
#
#               Price  Size Ingredient
# 0       $2.75        12ct       eggs
# 1       $4.05        12ct       eggs
# 2       $3.09                   eggs
# 3       $4.35        12ct       eggs
# 5       $4.95        12ct       eggs

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=milk&category_key=76'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

milk_text_elements = soup.find('div', class_= "product-grid")

milk_list = []

for elem in milk_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    milk_list.append(each_product)

#milk_list
    
milk_df = pd.DataFrame(milk_list)
milk_df["Size"] = milk_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
milk_df["Price"] = milk_df["Price"].str.replace(r'\n', '', regex=True)

milk_df
# Out:
#                                              Product           Brand  \
# 0                                   1% Milk, 0.5 gal  Friendly Farms
# 1                                     1% Milk, 1 gal  Friendly Farms
# 2                                   2% Milk, 0.5 gal  Friendly Farms
# 3                                 Skim Milk, 0.5 gal  Friendly Farms
# 4                                Whole Milk, 0.5 gal  Friendly Farms
# 5                                  Whole Milk, 1 gal  Friendly Farms
# 6                                     2% Milk, 1 gal  Friendly Farms
# 7                     Lowfat Chocolate Milk, 0.5 gal  Friendly Farms
# 8                           Coconut Milk, 13.5 fl oz            Goya
# 9                          Evaporated Milk, 12 fl oz  Baker's Corner
# 10                   Sweetened Condensed Milk, 14 oz  Baker's Corner
# 11                       Organic Whole Milk, 0.5 gal   Simply Nature
# 12                          Organic 2% Milk, 0.5 gal   Simply Nature
# 13                     2% Lactose Free Milk, 0.5 gal  Friendly Farms
# 14                  Lactose Free Whole Milk, 0.5 gal  Friendly Farms
# 15               Organic Whole Omega-3 Milk, 0.5 gal   Simply Nature
# 16              Lactose Free Fat Free Milk, 64 fl oz  Friendly Farms
# 17               Carnation Evaporated Milk, 12 fl oz          Nestle
# 18  Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal   Simply Nature
# 19                            Milk Chocolate, 3.5 oz      Schogetten
# 20               Lactose Free Fat Free Milk, 0.5 gal  Friendly Farms
# 21                             Milk Hazelnut, 3.5 oz      Schogetten
# 22                              Milk Chocolate Chips       Hershey's
# 23                  Milk Mini Chocolate Bars, 1.4 oz         Choceur
#
#                Price      Size
# 0        $1.79          0.5gal
# 1        $2.95            1gal
# 2        $1.79          0.5gal
# 3        $1.79          0.5gal
# 4        $1.79          0.5gal
# 5        $2.95            1gal
# 6        $2.95            1gal
# 7        $1.79          0.5gal
# 8        $1.99        13.5floz
# 9        $1.35          12floz
# 10       $1.95            14oz
# 11       $4.19          64floz
# 12       $4.19          64floz
# 13       $3.55          64floz
# 14       $3.55          64floz
# 15       $4.65          64floz
# 16       $3.55          64floz
# 17       $1.89         12fl.oz
# 18       $4.65          64floz
# 19       $1.75           3.5oz
# 20       $2.65          64floz
# 21       $1.75           3.5oz
# 22       $2.57
# 23       $2.45        5x1.4oz.

# %%
filtered_milk_df = milk_df[~milk_df["Product"].str.contains("Coconut|Chocolate|Condensed|Evaporated", regex=True)]
filtered_milk_df["Ingredient"] = "milk"
filtered_milk_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\3665118053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_milk_df["Ingredient"] = "milk"
#                                              Product           Brand  \
# 0                                   1% Milk, 0.5 gal  Friendly Farms
# 1                                     1% Milk, 1 gal  Friendly Farms
# 2                                   2% Milk, 0.5 gal  Friendly Farms
# 3                                 Skim Milk, 0.5 gal  Friendly Farms
# 4                                Whole Milk, 0.5 gal  Friendly Farms
# 5                                  Whole Milk, 1 gal  Friendly Farms
# 6                                     2% Milk, 1 gal  Friendly Farms
# 11                       Organic Whole Milk, 0.5 gal   Simply Nature
# 12                          Organic 2% Milk, 0.5 gal   Simply Nature
# 13                     2% Lactose Free Milk, 0.5 gal  Friendly Farms
# 14                  Lactose Free Whole Milk, 0.5 gal  Friendly Farms
# 15               Organic Whole Omega-3 Milk, 0.5 gal   Simply Nature
# 16              Lactose Free Fat Free Milk, 64 fl oz  Friendly Farms
# 18  Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal   Simply Nature
# 20               Lactose Free Fat Free Milk, 0.5 gal  Friendly Farms
# 21                             Milk Hazelnut, 3.5 oz      Schogetten
#
#                Price    Size Ingredient
# 0        $1.79        0.5gal       milk
# 1        $2.95          1gal       milk
# 2        $1.79        0.5gal       milk
# 3        $1.79        0.5gal       milk
# 4        $1.79        0.5gal       milk
# 5        $2.95          1gal       milk
# 6        $2.95          1gal       milk
# 11       $4.19        64floz       milk
# 12       $4.19        64floz       milk
# 13       $3.55        64floz       milk
# 14       $3.55        64floz       milk
# 15       $4.65        64floz       milk
# 16       $3.55        64floz       milk
# 18       $4.65        64floz       milk
# 20       $2.65        64floz       milk
# 21       $1.75         3.5oz       milk

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=sugar&category_key=101'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

sugar_text_elements = soup.find('div', class_= "product-grid")

sugar_list = []

for elem in sugar_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    sugar_list.append(each_product)

#sugar_list
sugar_df = pd.DataFrame(sugar_list)
sugar_df["Size"] = sugar_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
sugar_df["Price"] = sugar_df["Price"].str.replace(r'\n', '', regex=True)


#filtered_sugar_df = sugar_df[sugar_df["Size":]]
    #can do like a "contains" for filtering "lb" instead of manually having to say "4lb"
        # REGEX: df[df['text'].str.contains('cat|hat|eat', regex=True)]

sugar_df
# Out:
#                                               Product            Brand  \
# 0                               Powdered Sugar, 32 oz   Baker's Corner
# 1                               Sugar Snap Peas, 8 oz
# 2                Wintergreen Sugar Free Mints, 1.5 oz       Excitemint
# 3                 Peppermint Sugar Free Mints, 1.5 oz       Excitemint
# 4                                    Granulated Sugar   Baker's Corner
# 5                            Light Brown Sugar, 32 oz   Baker's Corner
# 6                        Morena Pure Cane Sugar, 6 lb            Zulka
# 7                   Sugar Free Red Sour Mints, 1.5 oz       Excitemint
# 8                Sugar Free Yellow Sour Mints, 1.5 oz       Excitemint
# 9                     Organic Cane Sugar Pouch, 24 oz    Simply Nature
# 10                Pink Sugar Cookie Scented Wax Melts  Huntington Home
# 11                           Sugar Free Spearmint Gum       Excitemint
# 12                          Sugar Free Bubblemint Gum       Excitemint
# 13                          Sugar Cookie Mix, 17.5 oz   Baker's Corner
# 14        Watermelon Sugar Lemonade Scented Wax Melts  Huntington Home
# 15    Maple and Brown Sugar Instant Oatmeal, 10 count        Millville
# 16             Organic Light Brown Sugar Pouch, 24 oz    Simply Nature
# 17  Sugar Free French Vanilla Coffee Creamer, 32 f...        Barissimo
# 18       Sugar Free Hazelnut Coffee Creamer, 32 fl oz        Barissimo
# 19   Instant Sugar Free Chocolate Pudding Mix, 1.4 oz   Baker's Corner
# 20              Low Sugar Vanilla Greek Yogurt, 32 oz   Friendly Farms
# 21                Low Sugar Plain Greek Yogurt, 32 oz   Friendly Farms
# 22       Instant Sugar Free Vanilla Pudding Mix, 1 oz   Baker's Corner
# 23  Sugar Free French Vanilla Dry Coffee Creamer, ...        Barissimo
#
#                Price    Size
# 0        $2.39          32oz
# 1        $2.65           8oz
# 2        $2.19         1.5oz
# 3        $2.19         1.5oz
# 4        $3.45           4lb
# 5        $2.39          32oz
# 6        $6.25           6lb
# 7        $2.19         1.5oz
# 8        $2.19         1.5oz
# 9        $3.45          32oz
# 10       $1.89           1ea
# 11       $1.95          60ct
# 12       $1.95          60ct
# 13       $2.35        17.5oz
# 14       $1.89           1ea
# 15       $1.95        15.1oz
# 16       $3.45          24oz
# 17       $2.85        32floz
# 18       $2.85        32floz
# 19       $0.85         1.4oz
# 20       $5.45          32oz
# 21       $5.45          32oz
# 22       $0.85           1oz
# 23       $3.55        10.2oz

# %%
filtered_sugar_df = sugar_df[~sugar_df["Product"].str.contains("Yogurt|Powdered|Oatmeal|Gum|Mints|Pudding|Peas|Cookie|Mix|Creamer|Coffee|Free|Lemonade", regex=True)]
filtered_sugar_df["Ingredient"] = "granulated sugar"
filtered_sugar_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\3095491548.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sugar_df["Ingredient"] = "granulated sugar"
#                                    Product           Brand             Price  \
# 4                         Granulated Sugar  Baker's Corner       $3.45
# 5                 Light Brown Sugar, 32 oz  Baker's Corner       $2.39
# 6             Morena Pure Cane Sugar, 6 lb           Zulka       $6.25
# 9          Organic Cane Sugar Pouch, 24 oz   Simply Nature       $3.45
# 16  Organic Light Brown Sugar Pouch, 24 oz   Simply Nature       $3.45
#
#     Size        Ingredient
# 4    4lb  granulated sugar
# 5   32oz  granulated sugar
# 6    6lb  granulated sugar
# 9   32oz  granulated sugar
# 16  24oz  granulated sugar

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=flour'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

flour_text_elements = soup.find('div', class_= "product-grid")

flour_list = []

for elem in flour_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    flour_list.append(each_product)

#flour_list
    
flour_df = pd.DataFrame(flour_list)
flour_df["Size"] = flour_df["Size"].str.replace(r'\s+', '', regex=True)
flour_df["Price"] = flour_df["Price"].str.replace(r'\n', '', regex=True)

flour_df
# Out:
#                                       Product           Brand  \
# 0                         Almond Flour, 16 oz  Baker's Corner
# 1                   Flour Tortillas, 12 count      El Milagro
# 2                     All Purpose Flour, 5 lb  Baker's Corner
# 3         8" Fajita Flour Tortillas, 10 count      El Milagro
# 4      Large Burrito Flour Tortillas, 8 count    Pueblo Lindo
# 5                    Flour Tortillas, 17.5 oz    Pueblo Lindo
# 6                Organic Coconut Flour, 36 oz   Simply Nature
# 7            Fajita Flour Tortillas, 20 count    Pueblo Lindo
# 8    Almond Flour Birthday Cake Cookies, 3 oz        Benton's
# 9               Instant Corn Masa Mix, 4.4 lb    Pueblo Lindo
# 10  Gluten Free Pancake and Baking Mix, 16 oz       liveGfree
# 11             Gluten Free Brownie Mix, 16 oz       liveGfree
# 12         Gluten Free Yellow Cake Mix, 15 oz       liveGfree
#
#                Price    Size
# 0        $5.75          16oz
# 1        $1.25          12ct
# 2        $2.55           5lb
# 3        $2.19          10ct
# 4        $2.15           8ct
# 5        $2.15        17.5oz
# 6        $5.99          36oz
# 7        $2.19          23oz
# 8        $3.29           3oz
# 9        $3.45         4.4lb
# 10       $3.25          16oz
# 11       $3.25          16oz
# 12       $3.25          15oz

# %%
filtered_flour_df = flour_df[~flour_df["Product"].str.contains("Pancake|Brownie|Cake|Tortillas|Tortilla|Masa", regex=True)]
filtered_flour_df["Ingredient"] = "flour"
filtered_flour_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\4233480779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_flour_df["Ingredient"] = "flour"
#                         Product           Brand             Price  Size  \
# 0           Almond Flour, 16 oz  Baker's Corner       $5.75        16oz
# 2       All Purpose Flour, 5 lb  Baker's Corner       $2.55         5lb
# 6  Organic Coconut Flour, 36 oz   Simply Nature       $5.99        36oz
#
#   Ingredient
# 0      flour
# 2      flour
# 6      flour

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=chocolate%20chips'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

chocochip_text_elements = soup.find('div', class_= "product-grid")

chocochip_list = []

for elem in chocochip_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    chocochip_list.append(each_product)

#chocochip_list

chocochip_df = pd.DataFrame(chocochip_list)
chocochip_df["Size"] = chocochip_df["Size"].str.replace(r'\s+', '', regex=True)
chocochip_df["Price"] = chocochip_df["Price"].str.replace(r'\n', '', regex=True)

chocochip_df
# Out:
#                                               Product               Brand  \
# 0                       Chocolate Chip Cookies, 13 oz            Benton's
# 1                 Chewy Chocolate Chip Cookies, 13 oz            Benton's
# 2                     Chocolate Chip Muffins, 4 count           Bake Shop
# 3                                Milk Chocolate Chips           Hershey's
# 4                   Chocolate Chip Cookie Thins, 4 oz            Benton's
# 5                  Chocolate Chip Muffin Mix, 14.7 oz       Betty Crocker
# 6                Chocolate Chip Mini Muffins, 8.25 oz       Baker's Treat
# 7                  Chocolate Chip Mini Muffins, 12 oz           Bake Shop
# 8          Chocolate Chip Sliced Brioche Loaf, 1.1 lb  Specially Selected
# 9                  Chocolate Chip Cookie Mix, 17.5 oz      Baker's Corner
# 10      Mini Chocolate Chip Cookie Snack Packs, 12 oz            Benton's
# 11        Chewy Chocolate Chip Granola Bars, 10 count           Millville
# 12  Chocolate Chip Chewy Dipped Granola Bars, 6 count           Millville
# 13                      Chocolate Chip Cookies, 16 oz  Specially Selected
# 14            Mint Chocolate Chip Ice Cream, 48 fl oz       Sundae Shoppe
# 15  Peanut Butter Chocolate Chip Chewy Granola Bar...           Millville
# 16       Chocolate Chip Cookie Dough Ice Cream, 48 oz       Sundae Shoppe
# 17                  Chocolate Chip Keto Cookies, 3 oz            Benton's
# 18         Chocolate Chip Thumbprint Cookies, 10.5 oz           Bake Shop
# 19    Baked Chocolate Chip Wafer Snack Packs, 6 count        Fit & Active
# 20  Dark Chocolate Chip Peanut Butter Perfect Bar,...         Perfect Bar
# 21  Baked Chocolate Chip Wafer 100 Calorie Snack P...            Benton's
# 22                 Chocolate Chip Cookie Mix, 17.5 oz       Betty Crocker
# 23                Chocolate Chip Energy Bars, 6 count           Elevation
#
#                Price     Size
# 0        $2.19           13oz
# 1        $2.19           13oz
# 2        $4.25         14.1oz
# 3        $2.57
# 4        $3.29            4oz
# 5        $2.84        14.75oz
# 6        $2.65         8.25oz
# 7        $3.85           12oz
# 8        $5.39         17.6oz
# 9        $2.35         17.5oz
# 10       $3.55           12oz
# 11       $1.95           10ct
# 12       $2.09            6ct
# 13       $3.85          16oz.
# 14       $2.95         48floz
# 15       $1.95          10ct.
# 16       $2.95         48floz
# 17       $3.29            3oz
# 18       $3.49         10.5oz
# 19       $3.29         4.86oz
# 20       $2.59          2.3oz
# 21       $3.29         4.86oz
# 22       $2.75         17.5oz
# 23       $6.05            6ct

# %%
filtered_chocochip_df = chocochip_df[~chocochip_df["Product"].str.contains("Cookies|Mix|Thins|Ice|Cream|Granola|Muffins|Snack|Bar|Energy|Bread|Loaf", regex=True)]
filtered_chocochip_df["Ingredient"] = "chocolate chips"
filtered_chocochip_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\80061959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_chocochip_df["Ingredient"] = "chocolate chips"
#                 Product      Brand             Price Size       Ingredient
# 3  Milk Chocolate Chips  Hershey's       $2.57             chocolate chips

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=butter'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

butter_text_elements = soup.find('div', class_= "product-grid")

butter_list = []

for elem in butter_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    butter_list.append(each_product)

#butter_list
    
butter_df = pd.DataFrame(butter_list)
butter_df["Size"] = butter_df["Size"].str.replace(r'\s+', '', regex=True)
butter_df["Price"] = butter_df["Price"].str.replace(r'\n', '', regex=True)

butter_df
# Out:
#                                            Product                 Brand  \
# 0                          Pure Irish Butter, 8 oz  Countryside Creamery
# 1                     Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 2                       Salted Butter Sticks, 1 lb  Countryside Creamery
# 3                    Butter Entertainment Crackers              Savoritz
# 4                     Ghee Clarified Butter, 13 oz               Carlini
# 5   Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 6                     Organic Salted Butter, 16 oz         Simply Nature
# 7          Spreadable Irish Butter with Canola Oil  Countryside Creamery
# 8                         Peanut Butter Cups, 12oz               Choceur
# 9              Peanut Butter Filled Pretzels, 24oz              Clancy's
# 10                     Creamy Almond Butter, 12 oz         Simply Nature
# 11              Reese's Peanut Butter Cups, 1.5 oz               Reese's
# 12                  Peanut Butter Wafers, 12 count         Baker's Treat
# 13                      Butter Cooking Spray, 8 oz               Carlini
# 14               Butter Chicken Curry Sauce, 15 oz              Burman's
# 15          Milk Chocolate Butter Cookies, 4.41 oz    Specially Selected
# 16                  All Butter Croissants, 6 count    Specially Selected
# 17        Peanut Butter Fudge Crisp Breaktime Bars             Elevation
# 18     Peanut Butter Crème Sandwich Cookies, 16 oz              Benton's
# 19         Cocoa Peanut Butter Puffs Cereal, 13 oz             Millville
# 20                   Butter Pecan Ice Cream, 48 oz         Sundae Shoppe
# 21  Reese's Peanut Butter Cups Snack Size, 8 count             Hershey's
# 22            Butter Flavored Pancake Syrup, 24 oz             Millville
# 23                              Sweet Butter Salad      Little Salad Bar
#
#                Price    Size
# 0        $3.45           8oz
# 1        $4.09          16oz
# 2        $4.09          16oz
# 3        $2.45           7oz
# 4        $8.25          13oz
# 5        $2.99          15oz
# 6        $6.85         16oz.
# 7        $3.55         7.5oz
# 8        $4.39          12oz
# 9        $5.29          24oz
# 10       $4.19          12oz
# 11       $1.29         1.5oz
# 12       $2.05          12oz
# 13       $2.65           8oz
# 14       $3.95          15oz
# 15       $2.19        4.41oz
# 16       $4.39          12oz
# 17       $5.49           5ct
# 18       $2.75          16oz
# 19       $3.15          13oz
# 20       $2.95        48floz
# 21       $2.09         4.4oz
# 22       $2.59        24floz
# 23       $2.55           6oz

# %%
filtered_butter_df = butter_df[~butter_df['Product'].str.contains("Peanut|Cracker|Crackers|Almond|Sauce|Chicken|Cookies|Croissant|Croissants|Salad|Ice|Cream|Spray|Pancake|Syrup", regex=True)]
filtered_butter_df["Ingredient"] = "butter"
filtered_butter_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\3070681987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_butter_df["Ingredient"] = "butter"
#                                           Product                 Brand  \
# 0                         Pure Irish Butter, 8 oz  Countryside Creamery
# 1                    Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 2                      Salted Butter Sticks, 1 lb  Countryside Creamery
# 4                    Ghee Clarified Butter, 13 oz               Carlini
# 5  Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 6                    Organic Salted Butter, 16 oz         Simply Nature
# 7         Spreadable Irish Butter with Canola Oil  Countryside Creamery
#
#               Price   Size Ingredient
# 0       $3.45          8oz     butter
# 1       $4.09         16oz     butter
# 2       $4.09         16oz     butter
# 4       $8.25         13oz     butter
# 5       $2.99         15oz     butter
# 6       $6.85        16oz.     butter
# 7       $3.55        7.5oz     butter

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=vanilla%20extract'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

vanilla_text_elements = soup.find('div', class_= "product-grid")

vanilla_list = []

for elem in vanilla_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    vanilla_list.append(each_product)

#butter_list
    
vanilla_df = pd.DataFrame(vanilla_list)
vanilla_df["Size"] = vanilla_df["Size"].str.replace(r'\s+', '', regex=True)
vanilla_df["Price"] = vanilla_df["Price"].str.replace(r'\n', '', regex=True)

vanilla_df
# Out:
#                       Product      Brand             Price   Size
# 0  Pure Vanilla Extract, 2 oz  Stonemill       $5.49        2floz

# %%
vanilla_df["Ingredient"] = "vanilla extract"
vanilla_df
# Out:
#                       Product      Brand             Price   Size  \
# 0  Pure Vanilla Extract, 2 oz  Stonemill       $5.49        2floz
#
#         Ingredient
# 0  vanilla extract

# %%
filtered_butter_df["Store"] = "Aldi"
filtered_chocochip_df["Store"] = "Aldi"
filtered_eggs_df["Store"] = "Aldi"
filtered_flour_df["Store"] = "Aldi"
filtered_milk_df["Store"] = "Aldi"
filtered_sugar_df["Store"] = "Aldi"
vanilla_df["Store"] = "Aldi"
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_butter_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_chocochip_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_eggs_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_flour_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_milk_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_24188\1115478543.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sugar_df["Store"] = "Aldi"

# %%
dataframes = [filtered_eggs_df, filtered_butter_df, filtered_flour_df, filtered_milk_df, filtered_sugar_df, filtered_chocochip_df, vanilla_df]
Aldi_Cookie_df = pd.concat(dataframes)
Aldi_Cookie_df.reset_index(drop=True, inplace=True)
Aldi_Cookie_df
# Out:
#                                               Product                 Brand  \
# 0             Cage Free Large Eggs - Grade A, 1 dozen               Goldhen
# 1       Free Range Large Brown Grade A Eggs, 12 count               Goldhen
# 2                   Grade A Large White Eggs, 1 dozen               Goldhen
# 3               Organic Cage Free Brown Eggs, 1 dozen         Simply Nature
# 4   Pasture Raised Large Brown Eggs Grade A, 12 count               Goldhen
# 5                             Pure Irish Butter, 8 oz  Countryside Creamery
# 6                        Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 7                          Salted Butter Sticks, 1 lb  Countryside Creamery
# 8                        Ghee Clarified Butter, 13 oz               Carlini
# 9      Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 10                       Organic Salted Butter, 16 oz         Simply Nature
# 11            Spreadable Irish Butter with Canola Oil  Countryside Creamery
# 12                                Almond Flour, 16 oz        Baker's Corner
# 13                            All Purpose Flour, 5 lb        Baker's Corner
# 14                       Organic Coconut Flour, 36 oz         Simply Nature
# 15                                   1% Milk, 0.5 gal        Friendly Farms
# 16                                     1% Milk, 1 gal        Friendly Farms
# 17                                   2% Milk, 0.5 gal        Friendly Farms
# 18                                 Skim Milk, 0.5 gal        Friendly Farms
# 19                                Whole Milk, 0.5 gal        Friendly Farms
# 20                                  Whole Milk, 1 gal        Friendly Farms
# 21                                     2% Milk, 1 gal        Friendly Farms
# 22                        Organic Whole Milk, 0.5 gal         Simply Nature
# 23                           Organic 2% Milk, 0.5 gal         Simply Nature
# 24                      2% Lactose Free Milk, 0.5 gal        Friendly Farms
# 25                   Lactose Free Whole Milk, 0.5 gal        Friendly Farms
# 26                Organic Whole Omega-3 Milk, 0.5 gal         Simply Nature
# 27               Lactose Free Fat Free Milk, 64 fl oz        Friendly Farms
# 28   Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal         Simply Nature
# 29                Lactose Free Fat Free Milk, 0.5 gal        Friendly Farms
# 30                              Milk Hazelnut, 3.5 oz            Schogetten
# 31                                   Granulated Sugar        Baker's Corner
# 32                           Light Brown Sugar, 32 oz        Baker's Corner
# 33                       Morena Pure Cane Sugar, 6 lb                 Zulka
# 34                    Organic Cane Sugar Pouch, 24 oz         Simply Nature
# 35             Organic Light Brown Sugar Pouch, 24 oz         Simply Nature
# 36                               Milk Chocolate Chips             Hershey's
# 37                         Pure Vanilla Extract, 2 oz             Stonemill
#
#                Price    Size        Ingredient Store
# 0        $2.75          12ct              eggs  Aldi
# 1        $4.05          12ct              eggs  Aldi
# 2        $3.09                            eggs  Aldi
# 3        $4.35          12ct              eggs  Aldi
# 4        $4.95          12ct              eggs  Aldi
# 5        $3.45           8oz            butter  Aldi
# 6        $4.09          16oz            butter  Aldi
# 7        $4.09          16oz            butter  Aldi
# 8        $8.25          13oz            butter  Aldi
# 9        $2.99          15oz            butter  Aldi
# 10       $6.85         16oz.            butter  Aldi
# 11       $3.55         7.5oz            butter  Aldi
# 12       $5.75          16oz             flour  Aldi
# 13       $2.55           5lb             flour  Aldi
# 14       $5.99          36oz             flour  Aldi
# 15       $1.79        0.5gal              milk  Aldi
# 16       $2.95          1gal              milk  Aldi
# 17       $1.79        0.5gal              milk  Aldi
# 18       $1.79        0.5gal              milk  Aldi
# 19       $1.79        0.5gal              milk  Aldi
# 20       $2.95          1gal              milk  Aldi
# 21       $2.95          1gal              milk  Aldi
# 22       $4.19        64floz              milk  Aldi
# 23       $4.19        64floz              milk  Aldi
# 24       $3.55        64floz              milk  Aldi
# 25       $3.55        64floz              milk  Aldi
# 26       $4.65        64floz              milk  Aldi
# 27       $3.55        64floz              milk  Aldi
# 28       $4.65        64floz              milk  Aldi
# 29       $2.65        64floz              milk  Aldi
# 30       $1.75         3.5oz              milk  Aldi
# 31       $3.45           4lb  granulated sugar   NaN
# 32       $2.39          32oz  granulated sugar   NaN
# 33       $6.25           6lb  granulated sugar   NaN
# 34       $3.45          32oz  granulated sugar   NaN
# 35       $3.45          24oz  granulated sugar   NaN
# 36       $2.57                 chocolate chips  Aldi
# 37       $5.49         2floz   vanilla extract  Aldi

# %%
Aldi_Cookie_df.dtypes
# Out:
# Product       object
# Brand         object
# Price         object
# Size          object
# Ingredient    object
# Store         object
# dtype: object

# %%
#Aldi_Cookie_df.to_csv("aldi_cookies.csv", index=False)
