# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests
import pandas as pd
from datetime import datetime

from import_export import addTo_products_dataframe
from import_export import get_products_dataframe

url = 'https://new.aldi.us/products/dairy-eggs/eggs/k/75'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')
#print(soup.prettify())

eggs_text_elements = soup.find('div', class_= "product-grid")

eggs_list = []

for elem in eggs_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    eggs_each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }
    eggs_list.append(eggs_each_product)

#eggs_list
eggs_df = pd.DataFrame(eggs_list)
eggs_df["Size"] = eggs_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
eggs_df["Price"] = eggs_df["Price"].str.replace(r'\n', '', regex=True)

eggs_df
# Out:
#                                              Product          Brand  \
# 0            Cage Free Large Eggs - Grade A, 1 dozen        Goldhen
# 1      Free Range Large Brown Grade A Eggs, 12 count        Goldhen
# 2                  Grade A Large White Eggs, 1 dozen        Goldhen
# 3              Organic Cage Free Brown Eggs, 1 dozen  Simply Nature
# 4                           Liquid Egg Whites, 32 oz        Goldhen
# 5  Pasture Raised Large Brown Eggs Grade A, 12 count        Goldhen
#
#               Price  Size
# 0       $2.85        12ct
# 1       $4.05        12ct
# 2       $2.09
# 3       $4.35        12ct
# 4       $4.65        32oz
# 5       $5.49        12ct

# %%
#eggs_text_elements = soup.find('div', class_= "product-grid")

#for text in eggs_text_elements:
 #   print(text.text)

# %%
filtered_eggs_df = eggs_df[~eggs_df["Product"].str.contains("Liquid|Whites", regex=True)]
filtered_eggs_df["Ingredient"] = "eggs"
filtered_eggs_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\1168351348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_eggs_df["Ingredient"] = "eggs"
#                                              Product          Brand  \
# 0            Cage Free Large Eggs - Grade A, 1 dozen        Goldhen
# 1      Free Range Large Brown Grade A Eggs, 12 count        Goldhen
# 2                  Grade A Large White Eggs, 1 dozen        Goldhen
# 3              Organic Cage Free Brown Eggs, 1 dozen  Simply Nature
# 5  Pasture Raised Large Brown Eggs Grade A, 12 count        Goldhen
#
#               Price  Size Ingredient
# 0       $2.85        12ct       eggs
# 1       $4.05        12ct       eggs
# 2       $2.09                   eggs
# 3       $4.35        12ct       eggs
# 5       $5.49        12ct       eggs

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=milk&category_key=76'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

milk_text_elements = soup.find('div', class_= "product-grid")

milk_list = []

for elem in milk_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    milk_list.append(each_product)

#milk_list
    
milk_df = pd.DataFrame(milk_list)
milk_df["Size"] = milk_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
milk_df["Price"] = milk_df["Price"].str.replace(r'\n', '', regex=True)

milk_df
# Out:
#                                              Product           Brand  \
# 0                                   1% Milk, 0.5 gal  Friendly Farms
# 1                                     1% Milk, 1 gal  Friendly Farms
# 2                                   2% Milk, 0.5 gal  Friendly Farms
# 3                                 Skim Milk, 0.5 gal  Friendly Farms
# 4                                Whole Milk, 0.5 gal  Friendly Farms
# 5                                  Whole Milk, 1 gal  Friendly Farms
# 6                                     2% Milk, 1 gal  Friendly Farms
# 7                     Lowfat Chocolate Milk, 0.5 gal  Friendly Farms
# 8                           Coconut Milk, 13.5 fl oz            Goya
# 9                          Evaporated Milk, 12 fl oz  Baker's Corner
# 10                   Sweetened Condensed Milk, 14 oz  Baker's Corner
# 11                       Organic Whole Milk, 0.5 gal   Simply Nature
# 12                          Organic 2% Milk, 0.5 gal   Simply Nature
# 13                     2% Lactose Free Milk, 0.5 gal  Friendly Farms
# 14                  Lactose Free Whole Milk, 0.5 gal  Friendly Farms
# 15               Organic Whole Omega-3 Milk, 0.5 gal   Simply Nature
# 16              Lactose Free Fat Free Milk, 64 fl oz  Friendly Farms
# 17     2% Ultra-Filtered Lactose Free Milk, 52 fl oz        Fairlife
# 18               Carnation Evaporated Milk, 12 fl oz          Nestle
# 19  Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal   Simply Nature
# 20                            Milk Chocolate, 3.5 oz      Schogetten
# 21               Lactose Free Fat Free Milk, 0.5 gal  Friendly Farms
# 22                             Milk Hazelnut, 3.5 oz      Schogetten
# 23                              Milk Chocolate Chips       Hershey's
#
#                Price      Size
# 0        $1.75          0.5gal
# 1        $2.85            1gal
# 2        $1.75          0.5gal
# 3        $1.75          0.5gal
# 4        $1.75          0.5gal
# 5        $2.85            1gal
# 6        $2.85            1gal
# 7        $1.75          0.5gal
# 8        $1.99        13.5floz
# 9        $1.35         12fl.oz
# 10       $1.95            14oz
# 11       $4.19          64floz
# 12       $4.19          64floz
# 13       $3.55          64floz
# 14       $3.55          64floz
# 15       $4.65          64floz
# 16       $3.55          64floz
# 17       $4.95          52floz
# 18       $1.89         12fl.oz
# 19       $4.65          64floz
# 20       $1.75           3.5oz
# 21       $2.65          64floz
# 22       $1.75           3.5oz
# 23       $2.57

# %%
filtered_milk_df = milk_df[~milk_df["Product"].str.contains("Coconut|Chocolate|Condensed|Evaporated", regex=True)]
filtered_milk_df["Ingredient"] = "milk"
filtered_milk_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\3665118053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_milk_df["Ingredient"] = "milk"
#                                              Product           Brand  \
# 0                                   1% Milk, 0.5 gal  Friendly Farms
# 1                                     1% Milk, 1 gal  Friendly Farms
# 2                                   2% Milk, 0.5 gal  Friendly Farms
# 3                                 Skim Milk, 0.5 gal  Friendly Farms
# 4                                Whole Milk, 0.5 gal  Friendly Farms
# 5                                  Whole Milk, 1 gal  Friendly Farms
# 6                                     2% Milk, 1 gal  Friendly Farms
# 11                       Organic Whole Milk, 0.5 gal   Simply Nature
# 12                          Organic 2% Milk, 0.5 gal   Simply Nature
# 13                     2% Lactose Free Milk, 0.5 gal  Friendly Farms
# 14                  Lactose Free Whole Milk, 0.5 gal  Friendly Farms
# 15               Organic Whole Omega-3 Milk, 0.5 gal   Simply Nature
# 16              Lactose Free Fat Free Milk, 64 fl oz  Friendly Farms
# 17     2% Ultra-Filtered Lactose Free Milk, 52 fl oz        Fairlife
# 19  Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal   Simply Nature
# 21               Lactose Free Fat Free Milk, 0.5 gal  Friendly Farms
# 22                             Milk Hazelnut, 3.5 oz      Schogetten
#
#                Price    Size Ingredient
# 0        $1.75        0.5gal       milk
# 1        $2.85          1gal       milk
# 2        $1.75        0.5gal       milk
# 3        $1.75        0.5gal       milk
# 4        $1.75        0.5gal       milk
# 5        $2.85          1gal       milk
# 6        $2.85          1gal       milk
# 11       $4.19        64floz       milk
# 12       $4.19        64floz       milk
# 13       $3.55        64floz       milk
# 14       $3.55        64floz       milk
# 15       $4.65        64floz       milk
# 16       $3.55        64floz       milk
# 17       $4.95        52floz       milk
# 19       $4.65        64floz       milk
# 21       $2.65        64floz       milk
# 22       $1.75         3.5oz       milk

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=sugar&category_key=101'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

sugar_text_elements = soup.find('div', class_= "product-grid")

sugar_list = []

for elem in sugar_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    sugar_list.append(each_product)

#sugar_list
sugar_df = pd.DataFrame(sugar_list)
sugar_df["Size"] = sugar_df["Size"].str.replace(r'\s+', '', regex=True)
    # ^^this line removes all spaces in the size column
sugar_df["Price"] = sugar_df["Price"].str.replace(r'\n', '', regex=True)


#filtered_sugar_df = sugar_df[sugar_df["Size":]]
    #can do like a "contains" for filtering "lb" instead of manually having to say "4lb"
        # REGEX: df[df['text'].str.contains('cat|hat|eat', regex=True)]

sugar_df
# Out:
#                                               Product           Brand  \
# 0                               Powdered Sugar, 32 oz  Baker's Corner
# 1                              Granulated Sugar, 4 lb  Baker's Corner
# 2                               Sugar Snap Peas, 8 oz
# 3                Wintergreen Sugar Free Mints, 1.5 oz      Excitemint
# 4                 Peppermint Sugar Free Mints, 1.5 oz      Excitemint
# 5                            Light Brown Sugar, 32 oz  Baker's Corner
# 6                        Morena Pure Cane Sugar, 6 lb           Zulka
# 7                   Sugar Free Red Sour Mints, 1.5 oz      Excitemint
# 8                Sugar Free Yellow Sour Mints, 1.5 oz      Excitemint
# 9                     Organic Cane Sugar Pouch, 24 oz   Simply Nature
# 10                           Sugar Free Spearmint Gum      Excitemint
# 11                          Sugar Free Bubblemint Gum      Excitemint
# 12                          Sugar Cookie Mix, 17.5 oz  Baker's Corner
# 13  St. Patrick's Day Frosted Sugar Cookies, 10 count       Lofthouse
# 14    Maple and Brown Sugar Instant Oatmeal, 10 count       Millville
# 15             Organic Light Brown Sugar Pouch, 24 oz   Simply Nature
# 16  Sugar Free French Vanilla Coffee Creamer, 32 f...       Barissimo
# 17       Sugar Free Hazelnut Coffee Creamer, 32 fl oz       Barissimo
# 18   Instant Sugar Free Chocolate Pudding Mix, 1.4 oz  Baker's Corner
# 19              Low Sugar Vanilla Greek Yogurt, 32 oz  Friendly Farms
# 20                Low Sugar Plain Greek Yogurt, 32 oz  Friendly Farms
# 21       Instant Sugar Free Vanilla Pudding Mix, 1 oz  Baker's Corner
# 22  Sugar Free French Vanilla Dry Coffee Creamer, ...       Barissimo
# 23                          Sugar Cookie Mix, 17.5 oz   Betty Crocker
#
#                Price    Size
# 0        $2.39          32oz
# 1        $3.45           4lb
# 2        $2.65           8oz
# 3        $2.19         1.5oz
# 4        $2.19         1.5oz
# 5        $2.39          32oz
# 6        $6.25           6lb
# 7        $2.19         1.5oz
# 8        $2.19         1.5oz
# 9        $3.45          32oz
# 10       $1.95          60ct
# 11       $1.95          60ct
# 12       $2.45        17.5oz
# 13       $3.95        13.5oz
# 14       $1.95        15.1oz
# 15       $3.45          24oz
# 16       $2.85        32floz
# 17       $2.85        32floz
# 18       $0.85         1.4oz
# 19       $5.45          32oz
# 20       $5.45          32oz
# 21       $0.85           1oz
# 22       $3.55        10.2oz
# 23       $2.75        17.5oz

# %%
filtered_sugar_df = sugar_df[~sugar_df["Product"].str.contains("Yogurt|Powdered|Oatmeal|Gum|Mints|Pudding|Peas|Cookie|Mix|Creamer|Coffee|Free|Lemonade", regex=True)]
filtered_sugar_df["Ingredient"] = "granulated sugar"
filtered_sugar_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\3095491548.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sugar_df["Ingredient"] = "granulated sugar"
#                                    Product           Brand             Price  \
# 1                   Granulated Sugar, 4 lb  Baker's Corner       $3.45
# 5                 Light Brown Sugar, 32 oz  Baker's Corner       $2.39
# 6             Morena Pure Cane Sugar, 6 lb           Zulka       $6.25
# 9          Organic Cane Sugar Pouch, 24 oz   Simply Nature       $3.45
# 15  Organic Light Brown Sugar Pouch, 24 oz   Simply Nature       $3.45
#
#     Size        Ingredient
# 1    4lb  granulated sugar
# 5   32oz  granulated sugar
# 6    6lb  granulated sugar
# 9   32oz  granulated sugar
# 15  24oz  granulated sugar

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=flour'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

flour_text_elements = soup.find('div', class_= "product-grid")

flour_list = []

for elem in flour_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    flour_list.append(each_product)

#flour_list
    
flour_df = pd.DataFrame(flour_list)
flour_df["Size"] = flour_df["Size"].str.replace(r'\s+', '', regex=True)
flour_df["Price"] = flour_df["Price"].str.replace(r'\n', '', regex=True)

flour_df
# Out:
#                                       Product            Brand  \
# 0                         Almond Flour, 16 oz   Baker's Corner
# 1                   Flour Tortillas, 12 count       El Milagro
# 2                     All Purpose Flour, 5 lb   Baker's Corner
# 3         8" Fajita Flour Tortillas, 10 count       El Milagro
# 4      Large Burrito Flour Tortillas, 8 count     Pueblo Lindo
# 5                    Flour Tortillas, 17.5 oz     Pueblo Lindo
# 6                Organic Coconut Flour, 36 oz    Simply Nature
# 7            Fajita Flour Tortillas, 20 count     Pueblo Lindo
# 8    Almond Flour Birthday Cake Cookies, 3 oz         Benton's
# 9   White 30" x 30" Flour Sack Towels, 5 pack  Huntington Home
# 10              Instant Corn Masa Mix, 4.4 lb     Pueblo Lindo
# 11  Gluten Free Pancake and Baking Mix, 16 oz        liveGfree
# 12             Gluten Free Brownie Mix, 16 oz        liveGfree
# 13         Gluten Free Yellow Cake Mix, 15 oz        liveGfree
#
#                Price    Size
# 0        $5.75          16oz
# 1        $1.25          12ct
# 2        $2.55           5lb
# 3        $2.19          10ct
# 4        $2.15           8ct
# 5        $2.15        17.5oz
# 6        $5.99          36oz
# 7        $2.19          23oz
# 8        $3.29           3oz
# 9        $3.99           1ea
# 10       $3.45         4.4lb
# 11       $3.25          16oz
# 12       $3.25          16oz
# 13       $3.25          15oz

# %%
filtered_flour_df = flour_df[~flour_df["Product"].str.contains("Pancake|Brownie|Cake|Tortillas|Tortilla|Masa", regex=True)]
filtered_flour_df["Ingredient"] = "flour"
filtered_flour_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\4233480779.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_flour_df["Ingredient"] = "flour"
#                                      Product            Brand  \
# 0                        Almond Flour, 16 oz   Baker's Corner
# 2                    All Purpose Flour, 5 lb   Baker's Corner
# 6               Organic Coconut Flour, 36 oz    Simply Nature
# 9  White 30" x 30" Flour Sack Towels, 5 pack  Huntington Home
#
#               Price  Size Ingredient
# 0       $5.75        16oz      flour
# 2       $2.55         5lb      flour
# 6       $5.99        36oz      flour
# 9       $3.99         1ea      flour

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=chocolate%20chips'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

chocochip_text_elements = soup.find('div', class_= "product-grid")

chocochip_list = []

for elem in chocochip_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    chocochip_list.append(each_product)

#chocochip_list

chocochip_df = pd.DataFrame(chocochip_list)
chocochip_df["Size"] = chocochip_df["Size"].str.replace(r'\s+', '', regex=True)
chocochip_df["Price"] = chocochip_df["Price"].str.replace(r'\n', '', regex=True)

chocochip_df
# Out:
#                                               Product               Brand  \
# 0                       Chocolate Chip Cookies, 13 oz            Benton's
# 1                 Chewy Chocolate Chip Cookies, 13 oz            Benton's
# 2                     Chocolate Chip Muffins, 4 count           Bake Shop
# 3                                Milk Chocolate Chips           Hershey's
# 4                   Chocolate Chip Cookie Thins, 4 oz            Benton's
# 5                Chocolate Chip Mini Muffins, 8.25 oz       Baker's Treat
# 6                  Chocolate Chip Mini Muffins, 12 oz           Bake Shop
# 7          Chocolate Chip Sliced Brioche Loaf, 1.1 lb  Specially Selected
# 8                  Chocolate Chip Cookie Mix, 17.5 oz      Baker's Corner
# 9       Mini Chocolate Chip Cookie Snack Packs, 12 oz            Benton's
# 10        Chewy Chocolate Chip Granola Bars, 10 count           Millville
# 11  Chocolate Chip Chewy Dipped Granola Bars, 6 count           Millville
# 12                      Chocolate Chip Cookies, 16 oz  Specially Selected
# 13            Mint Chocolate Chip Ice Cream, 48 fl oz       Sundae Shoppe
# 14  Peanut Butter Chocolate Chip Chewy Granola Bar...           Millville
# 15       Chocolate Chip Cookie Dough Ice Cream, 48 oz       Sundae Shoppe
# 16                  Chocolate Chip Keto Cookies, 3 oz            Benton's
# 17         Chocolate Chip Thumbprint Cookies, 10.5 oz           Bake Shop
# 18    Baked Chocolate Chip Wafer Snack Packs, 6 count        Fit & Active
# 19  Dark Chocolate Chip Peanut Butter Perfect Bar,...         Perfect Bar
# 20  Baked Chocolate Chip Wafer 100 Calorie Snack P...            Benton's
# 21                 Chocolate Chip Cookie Mix, 17.5 oz       Betty Crocker
# 22                Chocolate Chip Energy Bars, 6 count           Elevation
# 23  Organic Chocolate Chip Chewy Granola Bars, 8 c...       Simply Nature
#
#                Price    Size
# 0        $2.19          13oz
# 1        $2.19          13oz
# 2        $4.25        14.1oz
# 3        $2.57
# 4        $3.29           4oz
# 5        $2.65        8.25oz
# 6        $3.85          12oz
# 7        $5.39        17.6oz
# 8        $2.45        17.5oz
# 9        $3.55          12oz
# 10       $1.95          10ct
# 11       $2.09           6ct
# 12       $3.85         16oz.
# 13       $2.95        48floz
# 14       $1.95         10ct.
# 15       $2.95        48floz
# 16       $3.29           3oz
# 17       $3.49        10.5oz
# 18       $3.29        4.86oz
# 19       $2.59         2.3oz
# 20       $3.29        4.86oz
# 21       $2.75        17.5oz
# 22       $6.05           6ct
# 23       $4.39           8ct

# %%
filtered_chocochip_df = chocochip_df[~chocochip_df["Product"].str.contains("Cookies|Mix|Thins|Ice|Cream|Granola|Muffins|Snack|Bar|Energy|Bread|Loaf", regex=True)]
filtered_chocochip_df["Ingredient"] = "chocolate chips"
filtered_chocochip_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\80061959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_chocochip_df["Ingredient"] = "chocolate chips"
#                 Product      Brand             Price Size       Ingredient
# 3  Milk Chocolate Chips  Hershey's       $2.57             chocolate chips

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=butter'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

butter_text_elements = soup.find('div', class_= "product-grid")

butter_list = []

for elem in butter_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    butter_list.append(each_product)

#butter_list
    
butter_df = pd.DataFrame(butter_list)
butter_df["Size"] = butter_df["Size"].str.replace(r'\s+', '', regex=True)
butter_df["Price"] = butter_df["Price"].str.replace(r'\n', '', regex=True)

butter_df
# Out:
#                                              Product                 Brand  \
# 0                            Pure Irish Butter, 8 oz  Countryside Creamery
# 1                       Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 2                         Salted Butter Sticks, 1 lb  Countryside Creamery
# 3                      Butter Entertainment Crackers              Savoritz
# 4                       Ghee Clarified Butter, 13 oz               Carlini
# 5     Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 6                       Organic Salted Butter, 16 oz         Simply Nature
# 7            Spreadable Irish Butter with Canola Oil  Countryside Creamery
# 8                           Peanut Butter Cups, 12oz               Choceur
# 9                Peanut Butter Filled Pretzels, 24oz              Clancy's
# 10                       Creamy Almond Butter, 12 oz         Simply Nature
# 11                Reese's Peanut Butter Cups, 1.5 oz               Reese's
# 12                    Peanut Butter Wafers, 12 count         Baker's Treat
# 13                        Butter Cooking Spray, 8 oz               Carlini
# 14                 Butter Chicken Curry Sauce, 15 oz              Burman's
# 15            Milk Chocolate Butter Cookies, 4.41 oz    Specially Selected
# 16                    All Butter Croissants, 6 count    Specially Selected
# 17          Peanut Butter Fudge Crisp Breaktime Bars             Elevation
# 18           Cocoa Peanut Butter Puffs Cereal, 13 oz             Millville
# 19                     Butter Pecan Ice Cream, 48 oz         Sundae Shoppe
# 20    Reese's Peanut Butter Cups Snack Size, 8 count             Hershey's
# 21              Butter Flavored Pancake Syrup, 24 oz             Millville
# 22                                Sweet Butter Salad      Little Salad Bar
# 23  Movie Theater Butter Microwave Popcorn, 12 count              Clancy's
#
#                Price      Size
# 0        $3.45             8oz
# 1        $4.09            16oz
# 2        $4.09            16oz
# 3        $2.45             7oz
# 4        $8.25            13oz
# 5        $2.99            15oz
# 6        $6.85           16oz.
# 7        $3.55           7.5oz
# 8        $4.39            12oz
# 9        $5.29            24oz
# 10       $4.19            12oz
# 11       $1.29           1.5oz
# 12       $2.05            12oz
# 13       $2.65             8oz
# 14       $3.95            15oz
# 15       $2.19          4.41oz
# 16       $4.39            12oz
# 17       $5.49             5ct
# 18       $3.15            13oz
# 19       $2.95          48floz
# 20       $2.09           4.4oz
# 21       $2.59          24floz
# 22       $2.55             6oz
# 23       $5.29        12x2.5oz

# %%
filtered_butter_df = butter_df[~butter_df['Product'].str.contains("Peanut|Cracker|Crackers|Almond|Sauce|Chicken|Cookies|Croissant|Croissants|Salad|Ice|Cream|Spray|Pancake|Syrup", regex=True)]
filtered_butter_df["Ingredient"] = "butter"
filtered_butter_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\3070681987.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_butter_df["Ingredient"] = "butter"
#                                              Product                 Brand  \
# 0                            Pure Irish Butter, 8 oz  Countryside Creamery
# 1                       Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 2                         Salted Butter Sticks, 1 lb  Countryside Creamery
# 4                       Ghee Clarified Butter, 13 oz               Carlini
# 5     Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 6                       Organic Salted Butter, 16 oz         Simply Nature
# 7            Spreadable Irish Butter with Canola Oil  Countryside Creamery
# 23  Movie Theater Butter Microwave Popcorn, 12 count              Clancy's
#
#                Price      Size Ingredient
# 0        $3.45             8oz     butter
# 1        $4.09            16oz     butter
# 2        $4.09            16oz     butter
# 4        $8.25            13oz     butter
# 5        $2.99            15oz     butter
# 6        $6.85           16oz.     butter
# 7        $3.55           7.5oz     butter
# 23       $5.29        12x2.5oz     butter

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=vanilla%20extract'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

vanilla_text_elements = soup.find('div', class_= "product-grid")

vanilla_list = []

for elem in vanilla_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    vanilla_list.append(each_product)

#butter_list
    
vanilla_df = pd.DataFrame(vanilla_list)
vanilla_df["Size"] = vanilla_df["Size"].str.replace(r'\s+', '', regex=True)
vanilla_df["Price"] = vanilla_df["Price"].str.replace(r'\n', '', regex=True)

vanilla_df
# Out:
#                       Product      Brand             Price   Size
# 0  Pure Vanilla Extract, 2 oz  Stonemill       $5.49        2floz

# %%
vanilla_df["Ingredient"] = "vanilla extract"
vanilla_df
# Out:
#                       Product      Brand             Price   Size  \
# 0  Pure Vanilla Extract, 2 oz  Stonemill       $5.49        2floz
#
#         Ingredient
# 0  vanilla extract

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=iodized%20salt'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

salt_text_elements = soup.find('div', class_= "product-grid")

salt_list = []

for elem in salt_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    salt_list.append(each_product)

#butter_list
    
salt_df = pd.DataFrame(salt_list)
salt_df["Size"] = salt_df["Size"].str.replace(r'\s+', '', regex=True)
salt_df["Price"] = salt_df["Price"].str.replace(r'\n', '', regex=True)

salt_df
# Out:
#                      Product      Brand             Price  Size
# 0  Iodized Table Salt, 26 oz  Stonemill       $0.75        26oz

# %%
salt_df['Ingredient'] = "iodized salt"
salt_df
# Out:
#                      Product      Brand             Price  Size    Ingredient
# 0  Iodized Table Salt, 26 oz  Stonemill       $0.75        26oz  iodized salt

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=baking%20soda&category_key=16'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

bakingsoda_text_elements = soup.find('div', class_= "product-grid")

bakingsoda_list = []

for elem in bakingsoda_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    bakingsoda_list.append(each_product)

#butter_list
    
bakingsoda_df = pd.DataFrame(bakingsoda_list)
bakingsoda_df["Size"] = bakingsoda_df["Size"].str.replace(r'\s+', '', regex=True)
bakingsoda_df["Price"] = bakingsoda_df["Price"].str.replace(r'\n', '', regex=True)

bakingsoda_df
# Out:
#                                               Product  \
# 0                                  Baking Soda, 16 oz
# 1        Scoopable Cat Litter with Baking Soda, 14 lb
# 2                      Cerulean Stoneware Baking Dish
# 3                        Shrimp & Lobster Bake, 18 oz
# 4                  Lobster Mac 'n' Cheese Bake, 18 oz
# 5   Mozzarella, Cherry Tomato, & Arugula Stone Bak...
# 6   Mushroom, Mascarpone, & Authentic Italian Chee...
# 7                  Cinnamon Rolls with Icing, 8 count
# 8                  Jumbo Buttermilk Biscuits, 8 count
# 9                        16" Cheese Deli Pizza, 41 oz
# 10                    16" Pepperoni Deli Pizza, 41 oz
# 11                       Chocolate Cake Pops, 4 count
# 12                         Vanilla Cake Pops, 4 count
# 13                            Calzone Pepperoni, 7 oz
# 14        Pepperoni and Mozzarella Flatbread, 13.1 oz
# 15                  16" Mega Meat Deli Pizza, 30.5 oz
# 16   12" Veggie Cauliflower Crust Deli Pizza, 17.6 oz
# 17  Sea Salt Caramel Chocolate Chunk Cookie Dough,...
# 18                           Mini Naan Bread, 12.7 oz
# 19                          Garlic Mini Naan, 12.7 oz
# 20                   Original Pancake Syrup, 24 fl oz
#
#                          Brand             Price     Size
# 0               Baker's Corner       $0.99           16oz
# 1                Heart to Tail       $6.85           14lb
# 2                      Crofton       $8.99            1ea
# 3           Specially Selected       $7.49           18oz
# 4           Specially Selected       $7.49           18oz
# 5           Specially Selected       $4.99        13.96oz
# 6           Specially Selected       $4.99        13.96oz
# 7         Bake House Creations       $2.39            8ct
# 8         Bake House Creations       $2.05           16oz
# 9   Mama Cozzi's Pizza Kitchen       $6.79         39.1oz
# 10  Mama Cozzi's Pizza Kitchen       $7.95           41oz
# 11                   Bake Shop       $4.49          5.4oz
# 12                   Bake Shop       $4.49          5.4oz
# 13  Mama Cozzi's Pizza Kitchen       $2.65            7oz
# 14  Mama Cozzi's Pizza Kitchen       $5.25         13.1oz
# 15  Mama Cozzi's Pizza Kitchen       $8.25         30.5oz
# 16  Mama Cozzi's Pizza Kitchen       $8.79         17.6oz
# 17          Specially Selected       $3.85           16oz
# 18          Specially Selected       $4.85         12.7oz
# 19          Specially Selected       $4.85         12.7oz
# 20                   Millville       $2.59         24floz

# %%
#filtered_butter_df = butter_df[~butter_df['Product'].str.contains("Peanut|Cracke
filtered_bakingsoda_df = bakingsoda_df[bakingsoda_df['Product'].str.contains("Soda", regex=True)]
filtered_bakingsoda_df = filtered_bakingsoda_df[~filtered_bakingsoda_df['Product'].str.contains("Cat", regex=True)]
filtered_bakingsoda_df["Ingredient"] = "baking soda"
filtered_bakingsoda_df
# Out:
#               Product           Brand             Price  Size   Ingredient
# 0  Baking Soda, 16 oz  Baker's Corner       $0.99        16oz  baking soda

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
import requests

url = 'https://new.aldi.us/results?q=baking%20powder'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}
response = requests.get(url, headers=headers)
soup = soup(response.content, 'html.parser')

bakingpowder_text_elements = soup.find('div', class_= "product-grid")

bakingpowder_list = []

for elem in bakingpowder_text_elements:
    title = elem.find("div", class_="product-tile__name").text
    brand = elem.find("div", class_="product-tile__brandname").text
    price = elem.find("div", class_="base-price product-tile__price base-price--product-tile").text
    size = elem.find("div", class_="product-tile__unit-of-measurement").text

    each_product = {
        "Product": title,
        "Brand": brand,
        "Price": price,
        "Size": size
    }

    bakingpowder_list.append(each_product)

#butter_list
    
bakingpowder_df = pd.DataFrame(bakingpowder_list)
bakingpowder_df["Size"] = bakingpowder_df["Size"].str.replace(r'\s+', '', regex=True)
bakingpowder_df["Price"] = bakingpowder_df["Price"].str.replace(r'\n', '', regex=True)

bakingpowder_df
# Out:
#                                          Product           Brand  \
# 0                          Baking Powder, 8.1 oz  Baker's Corner
# 1          Unsweetened Baking Cocoa Powder, 8 oz  Baker's Corner
# 2                          Powdered Sugar, 32 oz  Baker's Corner
# 3               Powdered Sugar Mini Donut, 14 oz       Bake Shop
# 4  Extra Moist Classic Yellow Cake Mix, 15.25 oz  Baker's Corner
# 5    Extra Moist Devil's Food Cake Mix, 15.25 oz  Baker's Corner
# 6                   Protein Pancake Mix, 18.5 oz       Millville
# 7                 Gluten Free Brownie Mix, 16 oz       liveGfree
# 8               Protein Oat Pancake Mix, 18.5 oz       Millville
#
#               Price     Size
# 0       $2.05          8.1oz
# 1       $2.59            8oz
# 2       $2.39           32oz
# 3       $3.49           14oz
# 4       $1.09        15.25oz
# 5       $1.09        15.25oz
# 6       $4.39         18.5oz
# 7       $3.25           16oz
# 8       $4.39         18.5oz

# %%
filtered_bakingpowder_df = bakingpowder_df[~bakingpowder_df["Product"].str.contains("Sugar|Cake|Mix|Cocoa", regex=True)]
filtered_bakingpowder_df["Ingredient"] = "baking powder"
filtered_bakingpowder_df
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\271367465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_bakingpowder_df["Ingredient"] = "baking powder"
#                  Product           Brand             Price   Size  \
# 0  Baking Powder, 8.1 oz  Baker's Corner       $2.05        8.1oz
#
#       Ingredient
# 0  baking powder

# %%
filtered_butter_df["Store"] = "Aldi"
filtered_chocochip_df["Store"] = "Aldi"
filtered_eggs_df["Store"] = "Aldi"
filtered_flour_df["Store"] = "Aldi"
filtered_milk_df["Store"] = "Aldi"
filtered_sugar_df["Store"] = "Aldi"
vanilla_df["Store"] = "Aldi"
salt_df["Store"] = "Adli"
filtered_bakingsoda_df["Store"] = "Adli"
filtered_bakingpowder_df["Store"] = "Adli"
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_butter_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_chocochip_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_eggs_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_flour_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_milk_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sugar_df["Store"] = "Aldi"
# C:\Users\lucas\AppData\Local\Temp\ipykernel_47452\2579278149.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_bakingpowder_df["Store"] = "Adli"

# %%
dataframes = [filtered_eggs_df, filtered_butter_df, filtered_flour_df, filtered_milk_df, filtered_sugar_df, filtered_chocochip_df, vanilla_df, salt_df, filtered_bakingsoda_df, filtered_bakingpowder_df]
aldi_products_df = pd.concat(dataframes)
aldi_products_df['Price'] = aldi_products_df['Price'].str.replace('$', '').astype(float)
aldi_products_df.reset_index(drop=True, inplace=True)
aldi_products_df["Date"] = datetime.now().strftime("%Y-%m-%d")
aldi_products_df
# Out:
#                                               Product                 Brand  \
# 0             Cage Free Large Eggs - Grade A, 1 dozen               Goldhen
# 1       Free Range Large Brown Grade A Eggs, 12 count               Goldhen
# 2                   Grade A Large White Eggs, 1 dozen               Goldhen
# 3               Organic Cage Free Brown Eggs, 1 dozen         Simply Nature
# 4   Pasture Raised Large Brown Eggs Grade A, 12 count               Goldhen
# 5                             Pure Irish Butter, 8 oz  Countryside Creamery
# 6                        Unsalted Butter Sticks, 1 lb  Countryside Creamery
# 7                          Salted Butter Sticks, 1 lb  Countryside Creamery
# 8                        Ghee Clarified Butter, 13 oz               Carlini
# 9      Tastes Like Butter Vegetable Oil Spread, 15 oz  Countryside Creamery
# 10                       Organic Salted Butter, 16 oz         Simply Nature
# 11            Spreadable Irish Butter with Canola Oil  Countryside Creamery
# 12   Movie Theater Butter Microwave Popcorn, 12 count              Clancy's
# 13                                Almond Flour, 16 oz        Baker's Corner
# 14                            All Purpose Flour, 5 lb        Baker's Corner
# 15                       Organic Coconut Flour, 36 oz         Simply Nature
# 16          White 30" x 30" Flour Sack Towels, 5 pack       Huntington Home
# 17                                   1% Milk, 0.5 gal        Friendly Farms
# 18                                     1% Milk, 1 gal        Friendly Farms
# 19                                   2% Milk, 0.5 gal        Friendly Farms
# 20                                 Skim Milk, 0.5 gal        Friendly Farms
# 21                                Whole Milk, 0.5 gal        Friendly Farms
# 22                                  Whole Milk, 1 gal        Friendly Farms
# 23                                     2% Milk, 1 gal        Friendly Farms
# 24                        Organic Whole Milk, 0.5 gal         Simply Nature
# 25                           Organic 2% Milk, 0.5 gal         Simply Nature
# 26                      2% Lactose Free Milk, 0.5 gal        Friendly Farms
# 27                   Lactose Free Whole Milk, 0.5 gal        Friendly Farms
# 28                Organic Whole Omega-3 Milk, 0.5 gal         Simply Nature
# 29               Lactose Free Fat Free Milk, 64 fl oz        Friendly Farms
# 30      2% Ultra-Filtered Lactose Free Milk, 52 fl oz              Fairlife
# 31   Organic 2% DHA Omega-3 Reduced Fat Milk, 0.5 gal         Simply Nature
# 32                Lactose Free Fat Free Milk, 0.5 gal        Friendly Farms
# 33                              Milk Hazelnut, 3.5 oz            Schogetten
# 34                             Granulated Sugar, 4 lb        Baker's Corner
# 35                           Light Brown Sugar, 32 oz        Baker's Corner
# 36                       Morena Pure Cane Sugar, 6 lb                 Zulka
# 37                    Organic Cane Sugar Pouch, 24 oz         Simply Nature
# 38             Organic Light Brown Sugar Pouch, 24 oz         Simply Nature
# 39                               Milk Chocolate Chips             Hershey's
# 40                         Pure Vanilla Extract, 2 oz             Stonemill
# 41                          Iodized Table Salt, 26 oz             Stonemill
# 42                                 Baking Soda, 16 oz        Baker's Corner
# 43                              Baking Powder, 8.1 oz        Baker's Corner
#
#     Price      Size        Ingredient Store        Date
# 0    2.85      12ct              eggs  Aldi  2024-02-29
# 1    4.05      12ct              eggs  Aldi  2024-02-29
# 2    2.09                        eggs  Aldi  2024-02-29
# 3    4.35      12ct              eggs  Aldi  2024-02-29
# 4    5.49      12ct              eggs  Aldi  2024-02-29
# 5    3.45       8oz            butter  Aldi  2024-02-29
# 6    4.09      16oz            butter  Aldi  2024-02-29
# 7    4.09      16oz            butter  Aldi  2024-02-29
# 8    8.25      13oz            butter  Aldi  2024-02-29
# 9    2.99      15oz            butter  Aldi  2024-02-29
# 10   6.85     16oz.            butter  Aldi  2024-02-29
# 11   3.55     7.5oz            butter  Aldi  2024-02-29
# 12   5.29  12x2.5oz            butter  Aldi  2024-02-29
# 13   5.75      16oz             flour  Aldi  2024-02-29
# 14   2.55       5lb             flour  Aldi  2024-02-29
# 15   5.99      36oz             flour  Aldi  2024-02-29
# 16   3.99       1ea             flour  Aldi  2024-02-29
# 17   1.75    0.5gal              milk  Aldi  2024-02-29
# 18   2.85      1gal              milk  Aldi  2024-02-29
# 19   1.75    0.5gal              milk  Aldi  2024-02-29
# 20   1.75    0.5gal              milk  Aldi  2024-02-29
# 21   1.75    0.5gal              milk  Aldi  2024-02-29
# 22   2.85      1gal              milk  Aldi  2024-02-29
# 23   2.85      1gal              milk  Aldi  2024-02-29
# 24   4.19    64floz              milk  Aldi  2024-02-29
# 25   4.19    64floz              milk  Aldi  2024-02-29
# 26   3.55    64floz              milk  Aldi  2024-02-29
# 27   3.55    64floz              milk  Aldi  2024-02-29
# 28   4.65    64floz              milk  Aldi  2024-02-29
# 29   3.55    64floz              milk  Aldi  2024-02-29
# 30   4.95    52floz              milk  Aldi  2024-02-29
# 31   4.65    64floz              milk  Aldi  2024-02-29
# 32   2.65    64floz              milk  Aldi  2024-02-29
# 33   1.75     3.5oz              milk  Aldi  2024-02-29
# 34   3.45       4lb  granulated sugar  Aldi  2024-02-29
# 35   2.39      32oz  granulated sugar  Aldi  2024-02-29
# 36   6.25       6lb  granulated sugar  Aldi  2024-02-29
# 37   3.45      32oz  granulated sugar  Aldi  2024-02-29
# 38   3.45      24oz  granulated sugar  Aldi  2024-02-29
# 39   2.57             chocolate chips  Aldi  2024-02-29
# 40   5.49     2floz   vanilla extract  Aldi  2024-02-29
# 41   0.75      26oz      iodized salt  Adli  2024-02-29
# 42   0.99      16oz       baking soda  Adli  2024-02-29
# 43   2.05     8.1oz     baking powder  Adli  2024-02-29

# %%
aldi_products_df.to_csv("aldi_data")

# %%
# %store aldi_products_df
# Out:
# Stored 'aldi_products_df' (DataFrame)

# %%
addTo_products_dataframe(aldi_products_df)
# Out:
# c:\Users\lucas\Git Assignments\grocery_comparison_project\Code\import_export.py:53: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_df.to_sql(name='products',con=engine.raw_connection(), if_exists='append',index=False)
