# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
#browser = Browser('chrome', incognito=True)

# %%
# Visit the walmart site for eggs
url = 'https://www.walmart.com/browse/food/eggs/976759_9176907_1001469?povid=GlobalNav_rWeb_Grocery_DairyEggs_Eggs&facet=number_of_pieces%3A12%7C%7Cfacet_product_type%3AEggs'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="AxI3IDz84pNu6eqo">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="AxI3IDz84pNu6eqo">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="AxI3IDz84pNu6eqo" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    Eggs in Dairy &amp; Eggs - Walmart.com
#   </title>
#   <meta content="Shop for Eggs in Dairy &amp; Eggs. Buy products such as Great Value Large White Eggs, 18 Count, Great Value Large White Eggs, 12 Count at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/eggs/976759_9176907_1001469" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/eggs/976759_9176907_1001469" property="og:url"/>
#   <meta content="Shop for Eggs in Dairy &amp; Eggs. Buy products such as Great Value Large White Eggs, 18 Count, Great Value Large White Eggs, 12 Count at Walmart and save." property="og:description"/>
#   <meta content="Eggs in Dairy &amp; Eggs - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/asr/b6760ce4-ef2b-4ee7-9c54-1e573897ad73.0e934a9843adc83711b5c933c7777f52.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="AxI3IDz84pNu6eqo" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/dairy-eggs/9176907","name":"Dairy & Eggs"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/eggs/1001469","name":"Eggs"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/b6760ce4-ef2b-4ee7-9c54-1e573897ad73.0e934a9843adc83711b5c933c7777f52.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/79441634-3cd8-4a4f-baf3-141f09effd84.1e6cbf7058716a18489b8e7dcb9f0061.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/cdcff1ce-65a6-434f-92c2-f8b46efaf9aa.0c696ab1cb1c7a99a1c53db327567439.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/8f5e21d5-bd1a-4880-926a-7ecfc5006a05.70f3c7a62ba99c221dc2c7fba304aef0.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="AxI3IDz84pNu6eqo">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="AxI3IDz84pNu6eqo" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="AxI3IDz84pNu6eqo" rel="stylesheet"/>
#   <noscript data-n-css="AxI3IDz84pNu6eqo">
#   </noscript>
#   <script defer="" nomodule="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_modules_pills-module.eb63d8a3432ae3f8.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-548a7d0b4fae9c5b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_in-grid-ad-placeholder.098358f7fc5219aa.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="AxI3IDz84pNu6eqo" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="AxI3IDz84pNu6eqo">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="AxI3IDz84pNu6eqo" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_9176907_1001469&amp;_be_shelf_id=&amp;facet=number_of_pieces%3A12%7C%7Cfacet_product_type%3AEggs&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=number_of_pieces%3A12%7C%7Cfacet_product_type%3AEggs&amp;stores=5281&amp;cat_id=976759_9176907_1001469&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/dairy-eggs/9176907" itemprop="item">
#                   <span itemprop="name">
#                    Dairy &amp; Eggs
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/cp/eggs/1001469" itemprop="item">
#                   <span itemprop="name">
#                    Eggs
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="false" aria-label="Filter by In-store" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Filter by Price not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Filter by Brand not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Filter by Fulfillment Speed not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <button class="flex-shrink-0 f6 bg-white bn ph2 pv0 pointer sans-serif underline">
#                 Clear all
#                </button>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <section aria-label="Quick refinements" class="pv3" style="background-color:">
#               <div class="flex flex-column justify-center relative" data-testid="horizontal-scroller-chipModule">
#                <a aria-label="Previous slide for chipModule list" class="absolute dn z-5 bg-white br-100 pa0 pointer br-100 nav-control left-1" data-testid="horizontal-scroller-previous" link-identifier="horizontalScrollerPrevious" role="button">
#                 <i class="ld ld-ChevronLeft" style="font-size:1.5rem;vertical-align:-0.25em;padding:12px;width:1.5rem;height:1.5rem;box-sizing:content-box">
#                 </i>
#                </a>
#                <ul class="list ma0 pl0 overflow-x-scroll hidesb hidesb-wk relative overflow-y-hidden pl3 spl3 pl4-xl" data-testid="carousel-container" style="display:flex;grid-auto-flow:column;scroll-snap-type:;max-height:fit-content">
#                 <li class="flex flex-column items-center" data-slide="0">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Ramen eggs recipe
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="1">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Eggs 12 count
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="2">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Eggs 18 count
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="3">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Eggs 60 count
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="4">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Organic eggs
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="5">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Cage free eggs
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="6">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Large eggs
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="7">
#                  <button class="w_Z4xM w_XOt8 mr2" role="link" type="button">
#                   Brown eggs
#                  </button>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="8">
# ...
#                           Pickup
#                           <span class="b">
#                            tomorrow
#                           </span>
#                          </div>
#                         </div>
#                         <div class="f7 flex self-baseline dark-gray">
#                          <div>
#                           Delivery
#                           <span class="b">
#                            tomorrow
#                           </span>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="AxI3IDz84pNu6eqo" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"chipModule","pillsV2":[{"title":"Ramen eggs recipe ","titleColor":null,"url":"https://www.walmart.com/cp/dairy-recipe-food-trends/9527865?povid=976759_9176907_topnavpill_DairyEggBrowse_RamenEggsRecipe_Rweb_11.13.23","image":null},{"title":"Eggs 12 count","titleColor":null,"url":"https://www.walmart.com/browse/food/eggs-12-count/976759_9176907_1001469_9480548?povid=976759_topnavpill_9176907_EggsBrowse_Eggs12Count_Rweb_2_23_2024","image":null},{"title":"Eggs 18 count","titleColor":null,"url":"https://www.walmart.com/browse/food/eggs-18-count/976759_9176907_1001469_6665743?povid=976759_topnavpill_9176907_EggsBrowse_Eggs18Count_Rweb_2_23_2024","image":null},{"title":"Eggs 60 count","titleColor":null,"url":"https://www.walmart.com/browse/food/egg-60-count/976759_9176907_1001469_6040506?povid=976759_topnavpill_9176907_EggsBrowse_Eggs60Count_Rweb_2_23_2024","image":null},{"title":"Organic eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/organic-eggs/976759_9176907_1001469_2682345?povid=976759_topnavpill_9176907_EggsBrowse_Organic_Rweb_2_23_2024","image":null},{"title":"Cage free eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/cage-free-eggs/976759_9176907_1001469_9040914?povid=976759_topnavpill_9176907_EggsBrowse_CageFreeEggs_Rweb_2_23_2024","image":null},{"title":"Large eggs","titleColor":null,"url":"https://www.walmart.com/search?q=large+eggs\u0026povid=976759_9176907_topnavpill_DairyEggSearch_LargeEggs_Rweb_10.21.22","image":null},{"title":"Brown eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/brown-eggs/976759_9176907_1001469_4574987?povid=976759_topnavpill_9176907_EggsBrowse_BrownEggs_Rweb_2_23_2024","image":null},{"title":"White eggs","titleColor":null,"url":"https://walmart.com/browse/food/white-eggs/976759_9176907_1001469_4958883?povid=976759_topnavpill_9176907_EggsBrowse_WhiteEggs_Rweb_2_23_2024","image":null},{"title":"Liquid eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/liquid-substitute-eggs/976759_9176907_1001469_7582331?povid=976759_topnavpill_9176907_EggsBrowse_LiquidEggs_Rweb_2_23_2024","image":null},{"title":"Great Value eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/great-value-eggs/976759_9176907_1001469_9049110?povid=976759_topnavpill_9176907_EggsBrowse_GreatValueEggs_Rweb_2_23_2024","image":null},{"title":"Egg whites","titleColor":null,"url":"https://www.walmart.com/search?q=egg+whites\u0026povid=976759_9176907_topnavpill_DairyEggSearch_EggWhites_Rweb_10.21.22","image":null},{"title":"Hard-boiled eggs","titleColor":null,"url":"https://www.walmart.com/browse/food/hard-boiled-eggs/976759_9176907_1001469_8520168?povid=976759_topnavpill_9176907_EggsBrowse_HardBoiledEggs_Rweb_2_23_2024","image":null},{"title":"Recipe library","titleColor":null,"url":"https://www.walmart.com/i/recipe-library?povid=976759_nup_976794_recipelibrary_egg_Rweb_Aug_30","image":null},{"title":"Refrigerator bins","titleColor":null,"url":"https://www.walmart.com/browse/home/refrigerator-bins/4044_90548_1231929_1231931_9559674_8129543?povid=Home_D74_SearchPill_XSELL_Storage_RefrigeratorBins_EggSearch","image":null},{"title":"Egg carriers","titleColor":null,"url":"https://www.walmart.com/search?q=egg+carrier\u0026povid=Home_D74_SearchPill_XSELL_Storage_EggCarrier_EggSearch","image":null}]}},"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":"bottomZone1"},"configs":{"__typename":"TempoWM_GLASSWWWMarqueeDisplayAdConfigs ...
#   </script>
#   <script id="release-metadata" nonce="AxI3IDz84pNu6eqo" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"scus"}
#   </script>
#   <script nonce="AxI3IDz84pNu6eqo">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="AxI3IDz84pNu6eqo">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="AxI3IDz84pNu6eqo">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="AxI3IDz84pNu6eqo" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
#conditional_elements = soup.find_all('div', {'data-testid': 'item-stack'})
#print(conditional_elements)

# %%
#conditional_elements = soup.find_all("div", class_="mb1")
#conditional_text = [item.text for item in price]
#for i in conditional_text:
    #print(i)

# %%
#<span class="w_iUH7">current price $2.66</span>
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Great Value Large White Eggs, 12 Count
# current price $2.78
# Great Value Jumbo White Eggs, 12 Count
# current price $3.47
# Marketside Large Cage-Free Brown Eggs, 12 Count
# current price $3.58
# Eggland's Best Large White Eggs, 12 Count
# current price $2.96
# Eggland's Best Cage Free Large, Brown Eggs, 12 Count
# current price $4.14
# Marketside Organic Cage-Free Large Brown Eggs, 12 Count
# current price $4.42
# Eggland's Best Extra Large White Eggs, 12 Count
# current price $3.18
# Vital Farms Pasture Raised Grade A Large Brown Eggs, 12 Count
# current price $6.12
# Pete and Gerry's Organic Free Range Large Brown Eggs, 12 Count
# current price $5.18

# %%
eggs = pd.DataFrame(conditional_text)

eggs
# Out:
#                                                     0
# 0             Great Value Large White Eggs, 12 Count
# 1                                 current price $2.78
# 2             Great Value Jumbo White Eggs, 12 Count
# 3                                 current price $3.47
# 4    Marketside Large Cage-Free Brown Eggs, 12 Count
# 5                                 current price $3.58
# 6          Eggland's Best Large White Eggs, 12 Count
# 7                                 current price $2.96
# 8   Eggland's Best Cage Free Large, Brown Eggs, 12...
# 9                                 current price $4.14
# 10  Marketside Organic Cage-Free Large Brown Eggs,...
# 11                                current price $4.42
# 12   Eggland's Best Extra Large White Eggs, 12 Count
# 13                                current price $3.18
# 14  Vital Farms Pasture Raised Grade A Large Brown...
# 15                                current price $6.12
# 16  Pete and Gerry's Organic Free Range Large Brow...
# 17                                current price $5.18

# %%
eggs.insert(1, 'Current Price', '')
eggs
# Out:
#                                                     0 Current Price
# 0             Great Value Large White Eggs, 12 Count
# 1                                 current price $2.78
# 2             Great Value Jumbo White Eggs, 12 Count
# 3                                 current price $3.47
# 4    Marketside Large Cage-Free Brown Eggs, 12 Count
# 5                                 current price $3.58
# 6          Eggland's Best Large White Eggs, 12 Count
# 7                                 current price $2.96
# 8   Eggland's Best Cage Free Large, Brown Eggs, 12...
# 9                                 current price $4.14
# 10  Marketside Organic Cage-Free Large Brown Eggs,...
# 11                                current price $4.42
# 12   Eggland's Best Extra Large White Eggs, 12 Count
# 13                                current price $3.18
# 14  Vital Farms Pasture Raised Grade A Large Brown...
# 15                                current price $6.12
# 16  Pete and Gerry's Organic Free Range Large Brow...
# 17                                current price $5.18

# %%
eggs.columns = ["Name", "Current Price"]
eggs
# Out:
#                                                  Name Current Price
# 0             Great Value Large White Eggs, 12 Count
# 1                                 current price $2.78
# 2             Great Value Jumbo White Eggs, 12 Count
# 3                                 current price $3.47
# 4    Marketside Large Cage-Free Brown Eggs, 12 Count
# 5                                 current price $3.58
# 6          Eggland's Best Large White Eggs, 12 Count
# 7                                 current price $2.96
# 8   Eggland's Best Cage Free Large, Brown Eggs, 12...
# 9                                 current price $4.14
# 10  Marketside Organic Cage-Free Large Brown Eggs,...
# 11                                current price $4.42
# 12   Eggland's Best Extra Large White Eggs, 12 Count
# 13                                current price $3.18
# 14  Vital Farms Pasture Raised Grade A Large Brown...
# 15                                current price $6.12
# 16  Pete and Gerry's Organic Free Range Large Brow...
# 17                                current price $5.18

# %%
egg_list = pd.DataFrame({'Name':eggs['Name'].iloc[::2].values, 'Current Price':eggs['Name'].iloc[1::2].values})
egg_list
# Out:
#                                                 Name        Current Price
# 0            Great Value Large White Eggs, 12 Count   current price $2.78
# 1            Great Value Jumbo White Eggs, 12 Count   current price $3.47
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count   current price $3.58
# 3         Eggland's Best Large White Eggs, 12 Count   current price $2.96
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...  current price $4.14
# 5  Marketside Organic Cage-Free Large Brown Eggs,...  current price $4.42
# 6   Eggland's Best Extra Large White Eggs, 12 Count   current price $3.18
# 7  Vital Farms Pasture Raised Grade A Large Brown...  current price $6.12
# 8  Pete and Gerry's Organic Free Range Large Brow...  current price $5.18

# %%
egg_list[['1', '2']] = egg_list['Current Price'].str.split('$', expand=True)
print(egg_list)
# Out:
#                                                 Name        Current Price  \
# 0            Great Value Large White Eggs, 12 Count   current price $2.78
# 1            Great Value Jumbo White Eggs, 12 Count   current price $3.47
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count   current price $3.58
# 3         Eggland's Best Large White Eggs, 12 Count   current price $2.96
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...  current price $4.14
# 5  Marketside Organic Cage-Free Large Brown Eggs,...  current price $4.42
# 6   Eggland's Best Extra Large White Eggs, 12 Count   current price $3.18
# 7  Vital Farms Pasture Raised Grade A Large Brown...  current price $6.12
# 8  Pete and Gerry's Organic Free Range Large Brow...  current price $5.18
#
#                 1     2
# 0  current price   2.78
# 1  current price   3.47
# 2  current price   3.58
# 3  current price   2.96
# 4  current price   4.14
# 5  current price   4.42
# 6  current price   3.18
# 7  current price   6.12
# 8  current price   5.18

# %%
egg_list
# Out:
#                                                 Name        Current Price  \
# 0            Great Value Large White Eggs, 12 Count   current price $2.78
# 1            Great Value Jumbo White Eggs, 12 Count   current price $3.47
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count   current price $3.58
# 3         Eggland's Best Large White Eggs, 12 Count   current price $2.96
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...  current price $4.14
# 5  Marketside Organic Cage-Free Large Brown Eggs,...  current price $4.42
# 6   Eggland's Best Extra Large White Eggs, 12 Count   current price $3.18
# 7  Vital Farms Pasture Raised Grade A Large Brown...  current price $6.12
# 8  Pete and Gerry's Organic Free Range Large Brow...  current price $5.18
#
#                 1     2
# 0  current price   2.78
# 1  current price   3.47
# 2  current price   3.58
# 3  current price   2.96
# 4  current price   4.14
# 5  current price   4.42
# 6  current price   3.18
# 7  current price   6.12
# 8  current price   5.18

# %%
egg_list = egg_list.drop(['Current Price', '1'], axis=1)

# %%
egg_list.columns = ["Name", "Current Price"]
egg_list
# Out:
#                                                 Name Current Price
# 0            Great Value Large White Eggs, 12 Count           2.78
# 1            Great Value Jumbo White Eggs, 12 Count           3.47
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count           3.58
# 3         Eggland's Best Large White Eggs, 12 Count           2.96
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...          4.14
# 5  Marketside Organic Cage-Free Large Brown Eggs,...          4.42
# 6   Eggland's Best Extra Large White Eggs, 12 Count           3.18
# 7  Vital Farms Pasture Raised Grade A Large Brown...          6.12
# 8  Pete and Gerry's Organic Free Range Large Brow...          5.18

# %%
egg_list["Category"] = "Eggs"
egg_list["Store"] = "Walmart"
egg_list
# Out:
#                                                 Name Current Price Category  \
# 0            Great Value Large White Eggs, 12 Count           2.78     Eggs
# 1            Great Value Jumbo White Eggs, 12 Count           3.47     Eggs
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count           3.58     Eggs
# 3         Eggland's Best Large White Eggs, 12 Count           2.96     Eggs
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...          4.14     Eggs
# 5  Marketside Organic Cage-Free Large Brown Eggs,...          4.42     Eggs
# 6   Eggland's Best Extra Large White Eggs, 12 Count           3.18     Eggs
# 7  Vital Farms Pasture Raised Grade A Large Brown...          6.12     Eggs
# 8  Pete and Gerry's Organic Free Range Large Brow...          5.18     Eggs
#
#      Store
# 0  Walmart
# 1  Walmart
# 2  Walmart
# 3  Walmart
# 4  Walmart
# 5  Walmart
# 6  Walmart
# 7  Walmart
# 8  Walmart

# %%
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
# Visit the walmart site for flour
url = 'https://www.walmart.com/browse/food/flours-meals/976759_976780_9959366_9084673?sort=best_match&cat_id=976759_976780_9959366_9084673_7544865&stores=5012&ps=40&facet=fulfillment_method_in_store%3AIn-store'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="sbNg1xLH-gXi0KEh">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="sbNg1xLH-gXi0KEh" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    All Purpose Flour in Flours &amp; Meals - Walmart.com
#   </title>
#   <meta content="Shop for All Purpose Flour in Flours &amp; Meals. Buy products such as Great Value All-Purpose Flour, 5LB Bag, GV All Purpose Flour 2LB Bag at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/all-purpose-flour/976759_976780_9959366_9084673_7544865" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/all-purpose-flour/976759_976780_9959366_9084673_7544865" property="og:url"/>
#   <meta content="Shop for All Purpose Flour in Flours &amp; Meals. Buy products such as Great Value All-Purpose Flour, 5LB Bag, GV All Purpose Flour 2LB Bag at Walmart and save." property="og:description"/>
#   <meta content="All Purpose Flour in Flours &amp; Meals - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/asr/923d0601-6244-48e0-88fd-1d8202b07415.22f35763ff12f4f0f3f47ae48963864c.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="sbNg1xLH-gXi0KEh" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking/976780","name":"Baking"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking-ingredients/9959366","name":"Baking Ingredients"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/flours-meals/9084673","name":"Flours & Meals"}},{"@type":"ListItem","position":5,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/flours-meals/all-purpose-flour/976759_976780_9959366_9084673_7544865","name":"All Purpose Flour"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/923d0601-6244-48e0-88fd-1d8202b07415.22f35763ff12f4f0f3f47ae48963864c.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/60ce50b8-16c9-4275-847b-2ab0b5533db7.23a98ba7c3641bac5a2863a86aa0ac49.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/f57c4b6a-4f03-4ed0-bd70-82adde15b4ec.c9b2f598f8dfec081d6f39a50afefb1b.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/d7aa57c7-7561-46d6-ae30-b6ab5e23bdff.443e6c2773035b610523e13d74deda01.png?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="sbNg1xLH-gXi0KEh" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="sbNg1xLH-gXi0KEh" rel="stylesheet"/>
#   <noscript data-n-css="sbNg1xLH-gXi0KEh">
#   </noscript>
#   <script defer="" nomodule="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-548a7d0b4fae9c5b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_in-grid-ad-placeholder.098358f7fc5219aa.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="sbNg1xLH-gXi0KEh" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="sbNg1xLH-gXi0KEh" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_976780_9959366_9084673_7544865&amp;_be_shelf_id=&amp;facet=fulfillment_method%3AIn-store&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=fulfillment_method%3AIn-store&amp;stores=5281&amp;cat_id=976759_976780_9959366_9084673_7544865&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking/976780" itemprop="item">
#                   <span itemprop="name">
#                    Baking
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking-ingredients/9959366" itemprop="item">
#                   <span itemprop="name">
#                    Baking Ingredients
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/flours-meals/9084673" itemprop="item">
#                   <span itemprop="name">
#                    Flours &amp; Meals
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/flours-meals/all-purpose-flour/976759_976780_9959366_9084673_7544865" itemprop="item">
#                   <span itemprop="name">
#                    All Purpose Flour
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-black near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="true" aria-label="In-store , filter applied" class="f6 pv2 br-pill bn sans-serif flex bg-black near-white pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Price" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Brand" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Fulfillment Speed" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <button class="flex-shrink-0 f6 bg-white bn ph2 pv0 pointer sans-serif underline">
#                 Clear all
#                </button>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <!-- -->
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w-100 relative-m pl4 pr4 flex pt2">
#               <div class="fl w-20 dn br b--black-10 flex-grow-0 flex-shrink-0 db-m" data-testid="lhn">
#                <section class="overflow-y-auto overflow-x-hidden" style="position:sticky;top:128px;height:86vh">
#                 <div class="pb6 pr3">
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Departments">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Departments
#                      </div>
#                      <i aria-hidden="true" class="ld ld-ChevronDown pa0" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                      </i>
#                     </button>
#                    </div>
#                   </div>
#                   <hr aria-hidden="true" class="w_8Gn9"/>
#                  </section>
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Price">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Price
#                      </div>
# ...
#                         <div class="f6">
#                          In stock
#                         </div>
#                         <div class="flex flex-row">
#                          <i class="ld ld-Location mt1 mb1" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                          </i>
#                          <div class="f6 mt1 mb1">
#                           G10
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="sbNg1xLH-gXi0KEh" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":"bottomZone1"},"configs":{"__typename":"TempoWM_GLASSWWWMarqueeDisplayAdConfigs","_rawConfigs":{"moduleLocation":"marquee2","lazy":"1000"},"ad":null}},"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"browsePills","pillsV2":[]}},"bottomZone3":{"__typename":"TempoModule","type":"CopyBlock","name":"Copy Block","version":5,"moduleId":"2ca07422-a364-4155-9173-79e615c57141","schedule":{"priority":1},"matchedTrigger":{"zone":"bottomZone3"},"configs":{"__typename":"TempoWM_GLASSWWWCopyBlockConfigs","copyBlock":{"cwc":null}}},"bottomZone5":{"__typename":"TempoModule","type":"GenericSEOFAQModule","name":"NEW GenericSEOFAQModule Thu Oct 05 2023 9:50 PM PDT","version":8,"moduleId":"b7ae9d11-2a1f-49c4-8ee7-10f2e7794a4c","schedule":{"priority":10},"matchedTrigger":{"zone":"bottomZone5"},"configs":{"__typename":"TempoWM_GLASSWWWGenericSEOFAQModuleConfigs","seoFaqList":null}},"topZone3":{"__typename":"TempoModule","type":"SearchSortFilterModule","name":"New Sort \u0026 Filter on Search Page Module, Wednesday, July 14, 2021, 3:12:54:47 pm","version":1,"moduleId":"c4592076-abb9-4007-8ad9-891ec264278c","schedule":{"priority":1},"matchedTrigger":{"zone":"topZone3"},"configs":{"__typename":"_TempoWM_GLASSWWWSearchSortFilterModuleConfigs","topNavFacets":[{"title":"In-store","name":"In-store","expandOnLoad":true,"type":"fulfillment_method_in_store","displayType":null,"layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":true,"values":null},{"title":"Price","name":"Price","expandOnLoad":false,"type":"price","displayType":null,"layout":"pill","min":0,"max":20,"selectedMin":null,"selectedMax":null,"unboundedMax":true,"stepSize":1,"isSelected":null,"values":null},{"title":"Brand","name":"Brand","expandOnLoad":false,"type":"brand","displayType":null,"layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"values":[{"id":null,"title":"Great Value","name":"Great Value","expandOnLoad":false,"description":null,"type":null,"itemCount":3,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Gold Medal","name":"Gold Medal","expandOnLoad":false,"description":null,"type":null,"itemCount":3,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"King Arthur Flour","name":"King Arthur Flour","expandOnLoad":false,"description":null,"type":null,"itemCount":2,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"King Arthur Baking Company","name":"King Arthur Baking Company","expandOnLoad":false,"description":null,"type":null,"itemCount":1,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Pillsbury","name":"Pillsbury","expandOnLoad":false,"description":null,"type":null,"itemCount":2,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Arrowhead Mills","name":"Arrowhead Mills","expandOnLoad":false,"description":null,"type":null,"itemCount":1,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Oatsome","name":"Oatsome","expandOnLoad":false,"description":null,"type":null,"itemCount":1,"isSelected":null,"baseSeoURL":null,"values":null}]},{"title":"Fulfillment Speed","name":"Fulfillment Speed","expandOnLoad":false,"type":"fulfillment_speed","displayType":null,"layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"va ...
#   </script>
#   <script id="release-metadata" nonce="sbNg1xLH-gXi0KEh" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"scus"}
#   </script>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="sbNg1xLH-gXi0KEh">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="sbNg1xLH-gXi0KEh" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Great Value All-Purpose Flour, 5LB Bag
# current price $2.43
# 4.1 out of 5 Stars. 1073 reviews
# GV All Purpose Flour 2LB Bag
# current price $1.32
# 4.1 out of 5 Stars. 178 reviews
# Great Value All-Purpose Flour, 10 lbs
# current price $4.34
# 4.2 out of 5 Stars. 813 reviews
# King Arthur Baking Company All-Purpose Unbleached Flour 5lbs
# current price $5.24
# 4.8 out of 5 Stars. 3032 reviews
# Gold Medal Four, All Purpose Flour, Cooking And Baking Ingredient, 2 lb.
# current price $2.98
# 3.9 out of 5 Stars. 95 reviews
# Gold Medal Flour, All Purpose Flour, Baking And Cooking Ingredient, 5 lb.
# current price $3.98
# 4.2 out of 5 Stars. 250 reviews
# Pillsbury Best All Purpose Flour, Bleached, Enriched
# current price $4.37
# 3.2 out of 5 Stars. 22 reviews
# Gold Medal Flour, All Purpose Flour, Baking And Cooking Ingredient, 10 lb.
# current price $7.23
# 4.3 out of 5 Stars. 437 reviews
# OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )
# current price $6.97
# 4.1 out of 5 Stars. 152 reviews

# %%
flour = pd.DataFrame(conditional_text)

flour
# Out:
#                                                     0
# 0             Great Value All-Purpose Flour, 5LB Bag
# 1                                 current price $2.43
# 2                    4.1 out of 5 Stars. 1073 reviews
# 3                       GV All Purpose Flour 2LB Bag
# 4                                 current price $1.32
# 5                     4.1 out of 5 Stars. 178 reviews
# 6              Great Value All-Purpose Flour, 10 lbs
# 7                                 current price $4.34
# 8                     4.2 out of 5 Stars. 813 reviews
# 9   King Arthur Baking Company All-Purpose Unbleac...
# 10                                current price $5.24
# 11                   4.8 out of 5 Stars. 3032 reviews
# 12  Gold Medal Four, All Purpose Flour, Cooking An...
# 13                                current price $2.98
# 14                     3.9 out of 5 Stars. 95 reviews
# 15  Gold Medal Flour, All Purpose Flour, Baking An...
# 16                                current price $3.98
# 17                    4.2 out of 5 Stars. 250 reviews
# 18  Pillsbury Best All Purpose Flour, Bleached, En...
# 19                                current price $4.37
# 20                     3.2 out of 5 Stars. 22 reviews
# 21  Gold Medal Flour, All Purpose Flour, Baking An...
# 22                                current price $7.23
# 23                    4.3 out of 5 Stars. 437 reviews
# 24           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )
# 25                                current price $6.97
# 26                    4.1 out of 5 Stars. 152 reviews

# %%
flour.insert(1, 'Current Price', '')
flour
# Out:
#                                                     0 Current Price
# 0             Great Value All-Purpose Flour, 5LB Bag
# 1                                 current price $2.43
# 2                    4.1 out of 5 Stars. 1073 reviews
# 3                       GV All Purpose Flour 2LB Bag
# 4                                 current price $1.32
# 5                     4.1 out of 5 Stars. 178 reviews
# 6              Great Value All-Purpose Flour, 10 lbs
# 7                                 current price $4.34
# 8                     4.2 out of 5 Stars. 813 reviews
# 9   King Arthur Baking Company All-Purpose Unbleac...
# 10                                current price $5.24
# 11                   4.8 out of 5 Stars. 3032 reviews
# 12  Gold Medal Four, All Purpose Flour, Cooking An...
# 13                                current price $2.98
# 14                     3.9 out of 5 Stars. 95 reviews
# 15  Gold Medal Flour, All Purpose Flour, Baking An...
# 16                                current price $3.98
# 17                    4.2 out of 5 Stars. 250 reviews
# 18  Pillsbury Best All Purpose Flour, Bleached, En...
# 19                                current price $4.37
# 20                     3.2 out of 5 Stars. 22 reviews
# 21  Gold Medal Flour, All Purpose Flour, Baking An...
# 22                                current price $7.23
# 23                    4.3 out of 5 Stars. 437 reviews
# 24           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )
# 25                                current price $6.97
# 26                    4.1 out of 5 Stars. 152 reviews

# %%
#flour.insert(2, 'Reviews', '')
#flour

# %%
flour.columns = ["Name", "Current Price"]
flour
# Out:
#                                                  Name Current Price
# 0             Great Value All-Purpose Flour, 5LB Bag
# 1                                 current price $2.43
# 2                    4.1 out of 5 Stars. 1073 reviews
# 3                       GV All Purpose Flour 2LB Bag
# 4                                 current price $1.32
# 5                     4.1 out of 5 Stars. 178 reviews
# 6              Great Value All-Purpose Flour, 10 lbs
# 7                                 current price $4.34
# 8                     4.2 out of 5 Stars. 813 reviews
# 9   King Arthur Baking Company All-Purpose Unbleac...
# 10                                current price $5.24
# 11                   4.8 out of 5 Stars. 3032 reviews
# 12  Gold Medal Four, All Purpose Flour, Cooking An...
# 13                                current price $2.98
# 14                     3.9 out of 5 Stars. 95 reviews
# 15  Gold Medal Flour, All Purpose Flour, Baking An...
# 16                                current price $3.98
# 17                    4.2 out of 5 Stars. 250 reviews
# 18  Pillsbury Best All Purpose Flour, Bleached, En...
# 19                                current price $4.37
# 20                     3.2 out of 5 Stars. 22 reviews
# 21  Gold Medal Flour, All Purpose Flour, Baking An...
# 22                                current price $7.23
# 23                    4.3 out of 5 Stars. 437 reviews
# 24           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )
# 25                                current price $6.97
# 26                    4.1 out of 5 Stars. 152 reviews

# %%
df1 = flour[flour.index % 3 != 2] 
df1
# Out:
#                                                  Name Current Price
# 0             Great Value All-Purpose Flour, 5LB Bag
# 1                                 current price $2.43
# 3                       GV All Purpose Flour 2LB Bag
# 4                                 current price $1.32
# 6              Great Value All-Purpose Flour, 10 lbs
# 7                                 current price $4.34
# 9   King Arthur Baking Company All-Purpose Unbleac...
# 10                                current price $5.24
# 12  Gold Medal Four, All Purpose Flour, Cooking An...
# 13                                current price $2.98
# 15  Gold Medal Flour, All Purpose Flour, Baking An...
# 16                                current price $3.98
# 18  Pillsbury Best All Purpose Flour, Bleached, En...
# 19                                current price $4.37
# 21  Gold Medal Flour, All Purpose Flour, Baking An...
# 22                                current price $7.23
# 24           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )
# 25                                current price $6.97

# %%
flour_list = pd.DataFrame({'Name':df1['Name'].iloc[::2].values, 'Current Price':df1['Name'].iloc[1::2].values})
flour_list
# Out:
#                                                 Name        Current Price
# 0            Great Value All-Purpose Flour, 5LB Bag   current price $2.43
# 1                      GV All Purpose Flour 2LB Bag   current price $1.32
# 2             Great Value All-Purpose Flour, 10 lbs   current price $4.34
# 3  King Arthur Baking Company All-Purpose Unbleac...  current price $5.24
# 4  Gold Medal Four, All Purpose Flour, Cooking An...  current price $2.98
# 5  Gold Medal Flour, All Purpose Flour, Baking An...  current price $3.98
# 6  Pillsbury Best All Purpose Flour, Bleached, En...  current price $4.37
# 7  Gold Medal Flour, All Purpose Flour, Baking An...  current price $7.23
# 8           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )   current price $6.97

# %%
flour_list[['1', '2']] = flour_list['Current Price'].str.split('$', expand=True)
print(flour_list)
# Out:
#                                                 Name        Current Price  \
# 0            Great Value All-Purpose Flour, 5LB Bag   current price $2.43
# 1                      GV All Purpose Flour 2LB Bag   current price $1.32
# 2             Great Value All-Purpose Flour, 10 lbs   current price $4.34
# 3  King Arthur Baking Company All-Purpose Unbleac...  current price $5.24
# 4  Gold Medal Four, All Purpose Flour, Cooking An...  current price $2.98
# 5  Gold Medal Flour, All Purpose Flour, Baking An...  current price $3.98
# 6  Pillsbury Best All Purpose Flour, Bleached, En...  current price $4.37
# 7  Gold Medal Flour, All Purpose Flour, Baking An...  current price $7.23
# 8           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )   current price $6.97
#
#                 1     2
# 0  current price   2.43
# 1  current price   1.32
# 2  current price   4.34
# 3  current price   5.24
# 4  current price   2.98
# 5  current price   3.98
# 6  current price   4.37
# 7  current price   7.23
# 8  current price   6.97

# %%
flour_list = flour_list.drop(['Current Price', '1'], axis=1)

# %%
flour_list.columns = ["Name", "Current Price"]
flour_list
# Out:
#                                                 Name Current Price
# 0            Great Value All-Purpose Flour, 5LB Bag           2.43
# 1                      GV All Purpose Flour 2LB Bag           1.32
# 2             Great Value All-Purpose Flour, 10 lbs           4.34
# 3  King Arthur Baking Company All-Purpose Unbleac...          5.24
# 4  Gold Medal Four, All Purpose Flour, Cooking An...          2.98
# 5  Gold Medal Flour, All Purpose Flour, Baking An...          3.98
# 6  Pillsbury Best All Purpose Flour, Bleached, En...          4.37
# 7  Gold Medal Flour, All Purpose Flour, Baking An...          7.23
# 8           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )           6.97

# %%
flour_list["Category"] = "Flour"
flour_list["Store"] = "Walmart"
flour_list
# Out:
#                                                 Name Current Price Category  \
# 0            Great Value All-Purpose Flour, 5LB Bag           2.43    Flour
# 1                      GV All Purpose Flour 2LB Bag           1.32    Flour
# 2             Great Value All-Purpose Flour, 10 lbs           4.34    Flour
# 3  King Arthur Baking Company All-Purpose Unbleac...          5.24    Flour
# 4  Gold Medal Four, All Purpose Flour, Cooking An...          2.98    Flour
# 5  Gold Medal Flour, All Purpose Flour, Baking An...          3.98    Flour
# 6  Pillsbury Best All Purpose Flour, Bleached, En...          4.37    Flour
# 7  Gold Medal Flour, All Purpose Flour, Baking An...          7.23    Flour
# 8           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )           6.97    Flour
#
#      Store
# 0  Walmart
# 1  Walmart
# 2  Walmart
# 3  Walmart
# 4  Walmart
# 5  Walmart
# 6  Walmart
# 7  Walmart
# 8  Walmart

# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
# Visit the walmart site for sugar
url = 'https://www.walmart.com/browse/food/baking-ingredients/976759_976780_9959366?sort=best_match&cat_id=976759_976780_9959366_3219393_4479282&stores=5012&ps=40&facet=fulfillment_method_in_store%3AIn-store'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="Jfh9Tuyr9PXESJc_">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="Jfh9Tuyr9PXESJc_" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    Granulated Sugar in Sugar - Walmart.com
#   </title>
#   <meta content="Shop for Granulated Sugar in Sugar. Buy products such as Great Value Pure Granulated Sugar, 4 lb, Great Value Pure Granulated Sugar, 10lb at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/granulated-sugar/976759_976780_9959366_3219393_4479282" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/granulated-sugar/976759_976780_9959366_3219393_4479282" property="og:url"/>
#   <meta content="Shop for Granulated Sugar in Sugar. Buy products such as Great Value Pure Granulated Sugar, 4 lb, Great Value Pure Granulated Sugar, 10lb at Walmart and save." property="og:description"/>
#   <meta content="Granulated Sugar in Sugar - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/asr/0697b95e-eb68-4da1-afce-499793e190ac.267330310c7c523c5f187e59f93d3cd4.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="Jfh9Tuyr9PXESJc_" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking/976780","name":"Baking"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking-ingredients/9959366","name":"Baking Ingredients"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/sugar/3219393","name":"Sugar"}},{"@type":"ListItem","position":5,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/sugar/granulated-sugar/976759_976780_9959366_3219393_4479282","name":"Granulated Sugar"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/0697b95e-eb68-4da1-afce-499793e190ac.267330310c7c523c5f187e59f93d3cd4.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/e4ed16c3-bda5-443d-95a8-62ae73ce765d.f3ba6da4adba9244dd86c6ac3105df56.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/5da64e8c-c303-48d2-b7c4-f449b52f37e0.a977541a18ef59bf1819afee25a1f2d5.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/5c8d9479-4a7a-4526-a5e4-08a038bcef25.e0fac1ab63e2a0acc7cbaccf98349def.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="Jfh9Tuyr9PXESJc_" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="Jfh9Tuyr9PXESJc_" rel="stylesheet"/>
#   <noscript data-n-css="Jfh9Tuyr9PXESJc_">
#   </noscript>
#   <script defer="" nomodule="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="Jfh9Tuyr9PXESJc_" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="Jfh9Tuyr9PXESJc_" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_976780_9959366_3219393_4479282&amp;_be_shelf_id=&amp;facet=fulfillment_method%3AIn-store&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=fulfillment_method%3AIn-store&amp;stores=5281&amp;cat_id=976759_976780_9959366_3219393_4479282&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking/976780" itemprop="item">
#                   <span itemprop="name">
#                    Baking
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking-ingredients/9959366" itemprop="item">
#                   <span itemprop="name">
#                    Baking Ingredients
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/sugar/3219393" itemprop="item">
#                   <span itemprop="name">
#                    Sugar
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/sugar/granulated-sugar/976759_976780_9959366_3219393_4479282" itemprop="item">
#                   <span itemprop="name">
#                    Granulated Sugar
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-black near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="true" aria-label="Filter by In-store , filter applied" class="f6 pv2 br-pill bn sans-serif flex bg-black near-white pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Filter by Price not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Filter by Brand not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Filter by Fulfillment Speed not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <button class="flex-shrink-0 f6 bg-white bn ph2 pv0 pointer sans-serif underline">
#                 Clear all
#                </button>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <!-- -->
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w-100 relative-m pl4 pr4 flex pt2">
#               <div class="fl w-20 dn br b--black-10 flex-grow-0 flex-shrink-0 db-m" data-testid="lhn">
#                <section class="overflow-y-auto overflow-x-hidden" style="position:sticky;top:128px;height:86vh">
#                 <div class="pb6 pr3">
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Departments">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Departments
#                      </div>
#                      <i aria-hidden="true" class="ld ld-ChevronDown pa0" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                      </i>
#                     </button>
#                    </div>
#                   </div>
#                   <hr aria-hidden="true" class="w_8Gn9"/>
#                  </section>
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Price">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Price
#                      </div>
#                      <i aria-hidden="true" class="ld ld-ChevronDown pa0" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                      </i>
#                     </button>
#                    </div>
#                   </div>
#                   <hr aria-hidden="true" class="w_8Gn9"/>
#                  </section>
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Brand">
# ...
#                         </div>
#                         <div class="flex flex-row">
#                          <i class="ld ld-Location mt1 mb1" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                          </i>
#                          <div class="f6 mt1 mb1">
#                           G10
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="bb b--near-white w-100 absolute mt3" style="left:1.5rem">
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="Jfh9Tuyr9PXESJc_" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":"bottomZone1"},"configs":{"__typename":"TempoWM_GLASSWWWMarqueeDisplayAdConfigs","_rawConfigs":{"moduleLocation":"marquee2","lazy":"1000"},"ad":null}},"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"browsePills","pillsV2":[]}},"bottomZone3":{"__typename":"TempoModule","type":"CopyBlock","name":"Copy Block","version":5,"moduleId":"2ca07422-a364-4155-9173-79e615c57141","schedule":{"priority":1},"matchedTrigger":{"zone":"bottomZone3"},"configs":{"__typename":"TempoWM_GLASSWWWCopyBlockConfigs","copyBlock":{"cwc":null}}},"bottomZone5":{"__typename":"TempoModule","type":"GenericSEOFAQModule","name":"NEW GenericSEOFAQModule Thu Oct 05 2023 9:50 PM PDT","version":8,"moduleId":"b7ae9d11-2a1f-49c4-8ee7-10f2e7794a4c","schedule":{"priority":10},"matchedTrigger":{"zone":"bottomZone5"},"configs":{"__typename":"TempoWM_GLASSWWWGenericSEOFAQModuleConfigs","seoFaqList":null}},"topZone3":{"__typename":"TempoModule","type":"SearchSortFilterModule","name":"New Sort \u0026 Filter on Search Page Module, Wednesday, July 14, 2021, 3:12:54:47 pm","version":1,"moduleId":"c4592076-abb9-4007-8ad9-891ec264278c","schedule":{"priority":1},"matchedTrigger":{"zone":"topZone3"},"configs":{"__typename":"_TempoWM_GLASSWWWSearchSortFilterModuleConfigs","topNavFacets":[{"title":"In-store","name":"In-store","expandOnLoad":null,"type":"fulfillment_method_in_store","displayType":"TOGGLE","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":true,"values":null},{"title":"Price","name":"Price","expandOnLoad":false,"type":"price","displayType":"DROPDOWN","layout":"pill","min":0,"max":30,"selectedMin":null,"selectedMax":null,"unboundedMax":false,"stepSize":1,"isSelected":null,"values":null},{"title":"Brand","name":"Brand","expandOnLoad":false,"type":"brand","displayType":"DROPDOWN","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"values":[{"id":null,"title":"Great Value","name":"Great Value","expandOnLoad":false,"description":null,"type":null,"itemCount":4,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Domino","name":"Domino","expandOnLoad":false,"description":null,"type":null,"itemCount":3,"isSelected":null,"baseSeoURL":null,"values":null}]},{"title":"Fulfillment Speed","name":"Fulfillment Speed","expandOnLoad":false,"type":"fulfillment_speed","displayType":"DROPDOWN","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"values":[{"id":null,"title":"Today","name":"Today","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Tomorrow","name":"Tomorrow","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"2 days","name":"2 days","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Anytime","name":"Anytime","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null}]}],"allSortAndFilterFacets":[{"title":"Sort by","name":"Sort by","expandOnLoad":false,"type":"sort","displayType":null,"layout":"default","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize ...
#   </script>
#   <script id="release-metadata" nonce="Jfh9Tuyr9PXESJc_" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"eus2"}
#   </script>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="Jfh9Tuyr9PXESJc_">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="Jfh9Tuyr9PXESJc_" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Great Value Pure Granulated Sugar, 4 lb
# current price $3.24
# 4.3 out of 5 Stars. 5171 reviews
# Great Value Pure Granulated Sugar, 10lb
# current price $8.17
# 4.2 out of 5 Stars. 2581 reviews
# Domino Premium Pure Cane Granulated Sugar, 4 lb
# current price $4.54
# 4.2 out of 5 Stars. 338 reviews
# Domino Premium Pure Cane Granulated Sugar, 1 lb Box
# current price $1.72
# 3 out of 5 Stars. 108 reviews
# Great Value Pure Granulated Sugar, 25 Lb
# current price $19.97
# 4.2 out of 5 Stars. 518 reviews
# Great Value Organic Granulated Cane Sugar, 2 Lb
# current price $3.14
# 3.1 out of 5 Stars. 29 reviews
# Domino Pure Cane Granulated Golden Sugar, 1.75 lb
# current price $2.24
# 2.5 out of 5 Stars. 23 reviews

# %%
sugar = pd.DataFrame(conditional_text)

sugar
# Out:
#                                                     0
# 0            Great Value Pure Granulated Sugar, 4 lb
# 1                                 current price $3.24
# 2                    4.3 out of 5 Stars. 5171 reviews
# 3            Great Value Pure Granulated Sugar, 10lb
# 4                                 current price $8.17
# 5                    4.2 out of 5 Stars. 2581 reviews
# 6    Domino Premium Pure Cane Granulated Sugar, 4 lb
# 7                                 current price $4.54
# 8                     4.2 out of 5 Stars. 338 reviews
# 9   Domino Premium Pure Cane Granulated Sugar, 1 l...
# 10                                current price $1.72
# 11                      3 out of 5 Stars. 108 reviews
# 12          Great Value Pure Granulated Sugar, 25 Lb
# 13                               current price $19.97
# 14                    4.2 out of 5 Stars. 518 reviews
# 15   Great Value Organic Granulated Cane Sugar, 2 Lb
# 16                                current price $3.14
# 17                     3.1 out of 5 Stars. 29 reviews
# 18  Domino Pure Cane Granulated Golden Sugar, 1.75...
# 19                                current price $2.24
# 20                     2.5 out of 5 Stars. 23 reviews

# %%
sugar.insert(1, 'Current Price', '')
sugar
# Out:
#                                                     0 Current Price
# 0            Great Value Pure Granulated Sugar, 4 lb
# 1                                 current price $3.24
# 2                    4.3 out of 5 Stars. 5171 reviews
# 3            Great Value Pure Granulated Sugar, 10lb
# 4                                 current price $8.17
# 5                    4.2 out of 5 Stars. 2581 reviews
# 6    Domino Premium Pure Cane Granulated Sugar, 4 lb
# 7                                 current price $4.54
# 8                     4.2 out of 5 Stars. 338 reviews
# 9   Domino Premium Pure Cane Granulated Sugar, 1 l...
# 10                                current price $1.72
# 11                      3 out of 5 Stars. 108 reviews
# 12          Great Value Pure Granulated Sugar, 25 Lb
# 13                               current price $19.97
# 14                    4.2 out of 5 Stars. 518 reviews
# 15   Great Value Organic Granulated Cane Sugar, 2 Lb
# 16                                current price $3.14
# 17                     3.1 out of 5 Stars. 29 reviews
# 18  Domino Pure Cane Granulated Golden Sugar, 1.75...
# 19                                current price $2.24
# 20                     2.5 out of 5 Stars. 23 reviews

# %%
sugar.columns = ["Name", "Current Price"]
sugar
# Out:
#                                                  Name Current Price
# 0            Great Value Pure Granulated Sugar, 4 lb
# 1                                 current price $3.24
# 2                    4.3 out of 5 Stars. 5171 reviews
# 3            Great Value Pure Granulated Sugar, 10lb
# 4                                 current price $8.17
# 5                    4.2 out of 5 Stars. 2581 reviews
# 6    Domino Premium Pure Cane Granulated Sugar, 4 lb
# 7                                 current price $4.54
# 8                     4.2 out of 5 Stars. 338 reviews
# 9   Domino Premium Pure Cane Granulated Sugar, 1 l...
# 10                                current price $1.72
# 11                      3 out of 5 Stars. 108 reviews
# 12          Great Value Pure Granulated Sugar, 25 Lb
# 13                               current price $19.97
# 14                    4.2 out of 5 Stars. 518 reviews
# 15   Great Value Organic Granulated Cane Sugar, 2 Lb
# 16                                current price $3.14
# 17                     3.1 out of 5 Stars. 29 reviews
# 18  Domino Pure Cane Granulated Golden Sugar, 1.75...
# 19                                current price $2.24
# 20                     2.5 out of 5 Stars. 23 reviews

# %%
df2 = sugar[sugar.index % 3 != 2] 
df2
# Out:
#                                                  Name Current Price
# 0            Great Value Pure Granulated Sugar, 4 lb
# 1                                 current price $3.24
# 3            Great Value Pure Granulated Sugar, 10lb
# 4                                 current price $8.17
# 6    Domino Premium Pure Cane Granulated Sugar, 4 lb
# 7                                 current price $4.54
# 9   Domino Premium Pure Cane Granulated Sugar, 1 l...
# 10                                current price $1.72
# 12          Great Value Pure Granulated Sugar, 25 Lb
# 13                               current price $19.97
# 15   Great Value Organic Granulated Cane Sugar, 2 Lb
# 16                                current price $3.14
# 18  Domino Pure Cane Granulated Golden Sugar, 1.75...
# 19                                current price $2.24

# %%
sugar_list = pd.DataFrame({'Name':df2['Name'].iloc[::2].values, 'Current Price':df2['Name'].iloc[1::2].values})
sugar_list
# Out:
#                                                 Name         Current Price
# 0           Great Value Pure Granulated Sugar, 4 lb    current price $3.24
# 1           Great Value Pure Granulated Sugar, 10lb    current price $8.17
# 2   Domino Premium Pure Cane Granulated Sugar, 4 lb    current price $4.54
# 3  Domino Premium Pure Cane Granulated Sugar, 1 l...   current price $1.72
# 4          Great Value Pure Granulated Sugar, 25 Lb   current price $19.97
# 5   Great Value Organic Granulated Cane Sugar, 2 Lb    current price $3.14
# 6  Domino Pure Cane Granulated Golden Sugar, 1.75...   current price $2.24

# %%
sugar_list[['1', '2']] = sugar_list['Current Price'].str.split('$', expand=True)
print(sugar_list)
# Out:
#                                                 Name         Current Price  \
# 0           Great Value Pure Granulated Sugar, 4 lb    current price $3.24
# 1           Great Value Pure Granulated Sugar, 10lb    current price $8.17
# 2   Domino Premium Pure Cane Granulated Sugar, 4 lb    current price $4.54
# 3  Domino Premium Pure Cane Granulated Sugar, 1 l...   current price $1.72
# 4          Great Value Pure Granulated Sugar, 25 Lb   current price $19.97
# 5   Great Value Organic Granulated Cane Sugar, 2 Lb    current price $3.14
# 6  Domino Pure Cane Granulated Golden Sugar, 1.75...   current price $2.24
#
#                 1      2
# 0  current price    3.24
# 1  current price    8.17
# 2  current price    4.54
# 3  current price    1.72
# 4  current price   19.97
# 5  current price    3.14
# 6  current price    2.24

# %%
sugar_list = sugar_list.drop(['Current Price', '1'], axis=1)
sugar_list.columns = ["Name", "Current Price"]
sugar_list
# Out:
#                                                 Name Current Price
# 0           Great Value Pure Granulated Sugar, 4 lb           3.24
# 1           Great Value Pure Granulated Sugar, 10lb           8.17
# 2   Domino Premium Pure Cane Granulated Sugar, 4 lb           4.54
# 3  Domino Premium Pure Cane Granulated Sugar, 1 l...          1.72
# 4          Great Value Pure Granulated Sugar, 25 Lb          19.97
# 5   Great Value Organic Granulated Cane Sugar, 2 Lb           3.14
# 6  Domino Pure Cane Granulated Golden Sugar, 1.75...          2.24

# %%
sugar_list["Category"] = "Sugar"
sugar_list["Store"] = "Walmart"
sugar_list
# Out:
#                                                 Name Current Price Category  \
# 0           Great Value Pure Granulated Sugar, 4 lb           3.24    Sugar
# 1           Great Value Pure Granulated Sugar, 10lb           8.17    Sugar
# 2   Domino Premium Pure Cane Granulated Sugar, 4 lb           4.54    Sugar
# 3  Domino Premium Pure Cane Granulated Sugar, 1 l...          1.72    Sugar
# 4          Great Value Pure Granulated Sugar, 25 Lb          19.97    Sugar
# 5   Great Value Organic Granulated Cane Sugar, 2 Lb           3.14    Sugar
# 6  Domino Pure Cane Granulated Golden Sugar, 1.75...          2.24    Sugar
#
#      Store
# 0  Walmart
# 1  Walmart
# 2  Walmart
# 3  Walmart
# 4  Walmart
# 5  Walmart
# 6  Walmart

# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
url = 'https://www.walmart.com/browse/food/2-milk/976759_9176907_4405816_4288431?povid=976759_topnavpill_9176907_Milkbrowsepills_2%milk_Rweb_aug_23'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="EVf0Jd6eEqP7ySVz">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="EVf0Jd6eEqP7ySVz" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    2% Milk in Milk - Walmart.com
#   </title>
#   <meta content="Shop for 2% Milk in Milk. Buy products such as Great Value 2% Reduced Fat Milk, 128 Fl Oz, Great Value 2% Reduced Fat Milk, Half Gallon, 64 fl oz at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/2-milk/976759_9176907_4405816_4288431" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/2-milk/976759_9176907_4405816_4288431" property="og:url"/>
#   <meta content="Shop for 2% Milk in Milk. Buy products such as Great Value 2% Reduced Fat Milk, 128 Fl Oz, Great Value 2% Reduced Fat Milk, Half Gallon, 64 fl oz at Walmart and save." property="og:description"/>
#   <meta content="2% Milk in Milk - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/seo/Lactaid-2-Reduced-Fat-Milk-64-oz_860a54cb-a98c-4930-accc-af1720125e7a.8311d05bef6bd2113351ace0009149c5.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=FFFFFF" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="EVf0Jd6eEqP7ySVz" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/dairy-eggs/9176907","name":"Dairy & Eggs"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/milk/4405816","name":"Milk"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/milk/2-milk/976759_9176907_4405816_4288431","name":"2% Milk"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/seo/Lactaid-2-Reduced-Fat-Milk-64-oz_860a54cb-a98c-4930-accc-af1720125e7a.8311d05bef6bd2113351ace0009149c5.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/seo/Parmalat-2-Reduced-Fat-Milk-32-fl-oz-Shelf-Stable_a25ed4d0-3f92-4562-842d-948b3af25ea6.96b5853a93d0c9f3a6e6be766def4782.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/seo/Parmalat-Lactose-Free-2-Reduced-Fat-Milk-32-fl-oz_84f60260-a69d-42f1-a81f-34de1d474132.dee857ab3028f3d1c8bcd6c1d1380cfc.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/2f277900-1881-4f98-849f-0a19d37fe85d.6bd626794600e9f4069979ef44a28696.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="EVf0Jd6eEqP7ySVz" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="EVf0Jd6eEqP7ySVz" rel="stylesheet"/>
#   <noscript data-n-css="EVf0Jd6eEqP7ySVz">
#   </noscript>
#   <script defer="" nomodule="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_calloutWrapper.ada70c84fbc99481.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_modules_pills-module.eb63d8a3432ae3f8.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_locale-text-sponsored.dbdd0f3382b29a8e.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_feedback.c3ba971626fca41f.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/livingdesign_deprecated-components.e2e5d1a7367a34dd.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-548a7d0b4fae9c5b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_in-grid-ad-placeholder.098358f7fc5219aa.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="EVf0Jd6eEqP7ySVz" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="EVf0Jd6eEqP7ySVz" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_9176907_4405816_4288431&amp;_be_shelf_id=&amp;facet=&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=&amp;stores=5281&amp;cat_id=976759_9176907_4405816_4288431&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/dairy-eggs/9176907" itemprop="item">
#                   <span itemprop="name">
#                    Dairy &amp; Eggs
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/milk/4405816" itemprop="item">
#                   <span itemprop="name">
#                    Milk
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/milk/2-milk/976759_9176907_4405816_4288431" itemprop="item">
#                   <span itemprop="name">
#                    2% Milk
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="false" aria-label="In-store" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Price" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Brand" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Fulfillment Speed" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white" data-testid="filter_chip_subscription_eligible">
#                  <span class="w_PkCl w_J7NE" style="display:inline">
#                   <button aria-checked="false" aria-label="Subscription" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" role="switch" type="button">
#                    <i aria-hidden="true" class="ld ld-Subscription ph2" data-testid="Subscription-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                    </i>
#                    <span aria-hidden="true" class="flex pointer pr3">
#                     Subscription
#                    </span>
#                   </button>
#                  </span>
#                 </div>
#                 <div id="react-aria-5">
#                 </div>
#                </span>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-8" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-8">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <section aria-label="Quick refinements" class="pv3" style="background-color:">
#               <div class="flex flex-column justify-center relative" data-testid="horizontal-scroller-chipModule">
#                <a aria-label="Previous slide for chipModule list" class="absolute dn z-5 bg-white br-100 pa0 pointer br-100 nav-control left-1" data-testid="horizontal-scroller-previous" link-identifier="horizontalScrollerPrevious" role="button">
#                 <i class="ld ld-ChevronLeft" style="font-size:1.5rem;vertical-align:-0.25em;padding:12px;width:1.5rem;height:1.5rem;box-sizing:content-box">
#                 </i>
#                </a>
# ...
#                           Pickup
#                           <span class="b">
#                            tomorrow
#                           </span>
#                          </div>
#                         </div>
#                         <div class="f7 flex self-baseline dark-gray">
#                          <div>
#                           Delivery
#                           <span class="b">
#                            tomorrow
#                           </span>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="EVf0Jd6eEqP7ySVz" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"chipModule","pillsV2":[{"title":"Shop all dairy","titleColor":null,"url":"https://www.walmart.com/cp/dairy-eggs/9176907?povid=976759_topnavpill_9176907_DairyEggBrowseSearch_Shopalldairy_Rweb_10_19","image":null},{"title":"Shop all milk","titleColor":null,"url":"https://www.walmart.com/browse/food/milk/976759_9176907_4405816?povid=976759_topnavpill_9176907_Milkbrowsepills_Shopallmilk_Rweb_aug_23","image":null},{"title":"2% milk","titleColor":null,"url":"https://www.walmart.com/browse/food/2-milk/976759_9176907_4405816_4288431?povid=976759_topnavpill_9176907_Milkbrowsepills_2%milk_Rweb_aug_23","image":null},{"title":"1% milk","titleColor":null,"url":"https://www.walmart.com/browse/food/1-milk/976759_9176907_4405816_2534265?povid=976759_topnavpill_9176907_Milkbrowsepills_1%milk_Rweb_aug_23","image":null},{"title":"Whole milk","titleColor":null,"url":"https://www.walmart.com/browse/food/whole-milk/976759_9176907_4405816_6541475_6877499?povid=976759_topnavpill_9176907_Milkbrowsepills_Wholemilk_Rweb_10_5","image":null},{"title":"Chocolate milk","titleColor":null,"url":"https://www.walmart.com/browse/food/chocolate-milk/976759_9176907_4405816_9265788_1284521?povid=976759_nup_9176907_Milkbrowsepills_Chocolatemilk_Rweb_11_17","image":null},{"title":"Lactose free milk ","titleColor":null,"url":"https://www.walmart.com/browse/food/lactose-free-milk/976759_9176907_4405816_6541475_2705308?povid=976759_topnavpill_9176907_Lactosefreemilkbrowsepill_Lactosefreemilk_Rweb_10_5","image":null},{"title":"Almond milk","titleColor":null,"url":"https://www.walmart.com/browse/food/almond-milk/976759_9176907_4405816_3107987_3226399?povid=976759_nup_9176907_Milkbrowsepills_Almondmilk_Rweb_11_17","image":null},{"title":"Oat milk","titleColor":null,"url":"https://www.walmart.com/browse/food/oat-milk/976759_9176907_4405816_3107987_7668028?povid=976759_nup_9176907_Milkbrowsepills_Oatmilk_Rweb_11_17","image":null},{"title":"Coconut milk","titleColor":null,"url":"https://www.walmart.com/browse/food/coconut-milk/976759_9176907_4405816_3107987_1960610?povid=976759_nup_9176907_Milkbrowsepills_Coconutmilk_Rweb_11_17","image":null},{"title":"Soy milk","titleColor":null,"url":"https://www.walmart.com/browse/food/soy-milk/976759_9176907_4405816_3107987_8048823?povid=976759_nup_9176907_Milkbrowsepills_Soymilk_Rweb_11_17","image":null},{"title":"Fairlife milk","titleColor":null,"url":"https://www.walmart.com/browse/food/fairlife-milk/976759_9176907_4405816_6541475_2705308_5672312?povid=976759_nup_9176907_Milkbrowsepills_Fairlifemilk_Rweb_11_17","image":null},{"title":"Fat free milk","titleColor":null,"url":"https://www.walmart.com/browse/food/fat-free-milk/976759_9176907_4405816_5493060?povid=976759_topnavpill_9176907_Milkbrowsepills_Fatfreemilk_Rweb_aug_23","image":null},{"title":"Organic milk","titleColor":null,"url":"https://www.walmart.com/browse/food/organic-milk/976759_9176907_4405816_3153553?povid=976759_topnavpill_9176907_Milkbrowsepills_Organicmilk_Rweb_aug_23","image":null},{"title":"Non dairy milk","titleColor":null,"url":"https://www.walmart.com/cp/non-dairy-milk-buying-guide/2427118?povid=976759_topnavpill_2427118_Milkbrowsepills_Nondairymilkbuyingguide_Rweb_2_1_2024","image":null},{"title":"Shop all beverages ","titleColor":null,"url":"https://www.walmart.com/cp/beverages/976782?povid=976759_topnavpill_9176907_Milkbrowsepills_Shopallbeverages_Rweb_10_5","image":null}]}},"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":" ...
#   </script>
#   <script id="release-metadata" nonce="EVf0Jd6eEqP7ySVz" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"eus2"}
#   </script>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="EVf0Jd6eEqP7ySVz">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="EVf0Jd6eEqP7ySVz" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Lactaid 2% Reduced Fat Milk, 64 oz
# current price $4.48
# 4.7 out of 5 Stars. 1986 reviews
# Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-Stable)
# current price $2.98
# 4.1 out of 5 Stars. 150 reviews
# Parmalat Lactose Free 2% Reduced Fat Milk, 32 fl oz
# current price $2.98
# 3.1 out of 5 Stars. 112 reviews
# Tuscan Dairy Farms 2% Reduced Fat Milk with Vitamin A and Vitamin D,  Milk Quart - 1 Milk Bottle
# current price $1.98
# fairlife Lactose Free 2% Reduced Fat Ultra Filtered Milk, 52 fl oz
# current price $4.48
# a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk, 59 fl oz.
# current price $3.97
# Great Value Organic 2% Reduced Fat Milk, Half Gallon, 64 fl oz
# current price $3.98
# Great Value Organic Reduced Fat 2% Milk, 1 Gallon
# current price $6.98
# Great Value Lactose Free 2% Reduced Fat Milk, Half Gallon, 64 fl oz
# current price $3.38

# %%
milk = pd.DataFrame(conditional_text)

milk
# Out:
#                                                     0
# 0                 Lactaid 2% Reduced Fat Milk, 64 oz
# 1                                 current price $4.48
# 2                    4.7 out of 5 Stars. 1986 reviews
# 3   Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...
# 4                                 current price $2.98
# 5                     4.1 out of 5 Stars. 150 reviews
# 6   Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...
# 7                                 current price $2.98
# 8                     3.1 out of 5 Stars. 112 reviews
# 9   Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...
# 10                                current price $1.98
# 11  fairlife Lactose Free 2% Reduced Fat Ultra Fil...
# 12                                current price $4.48
# 13  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...
# 14                                current price $3.97
# 15  Great Value Organic 2% Reduced Fat Milk, Half ...
# 16                                current price $3.98
# 17  Great Value Organic Reduced Fat 2% Milk, 1 Gal...
# 18                                current price $6.98
# 19  Great Value Lactose Free 2% Reduced Fat Milk, ...
# 20                                current price $3.38

# %%
milk.insert(1, 'Current Price', '')

# %%
milk.columns = ["Name", "Current Price"]
milk
# Out:
#                                                  Name Current Price
# 0                 Lactaid 2% Reduced Fat Milk, 64 oz
# 1                                 current price $4.48
# 2                    4.7 out of 5 Stars. 1986 reviews
# 3   Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...
# 4                                 current price $2.98
# 5                     4.1 out of 5 Stars. 150 reviews
# 6   Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...
# 7                                 current price $2.98
# 8                     3.1 out of 5 Stars. 112 reviews
# 9   Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...
# 10                                current price $1.98
# 11  fairlife Lactose Free 2% Reduced Fat Ultra Fil...
# 12                                current price $4.48
# 13  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...
# 14                                current price $3.97
# 15  Great Value Organic 2% Reduced Fat Milk, Half ...
# 16                                current price $3.98
# 17  Great Value Organic Reduced Fat 2% Milk, 1 Gal...
# 18                                current price $6.98
# 19  Great Value Lactose Free 2% Reduced Fat Milk, ...
# 20                                current price $3.38

# %%
#df4 = milk[milk.index % 3 != 2] 
df4 = milk[milk.index % 3 != 2].iloc[:8]
df4
# Out:
#                                                  Name Current Price
# 0                 Lactaid 2% Reduced Fat Milk, 64 oz
# 1                                 current price $4.48
# 3   Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...
# 4                                 current price $2.98
# 6   Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...
# 7                                 current price $2.98
# 9   Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...
# 10                                current price $1.98

# %%
last_10_rows = milk.tail(10)
last_10_rows
# Out:
#                                                  Name Current Price
# 11  fairlife Lactose Free 2% Reduced Fat Ultra Fil...
# 12                                current price $4.48
# 13  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...
# 14                                current price $3.97
# 15  Great Value Organic 2% Reduced Fat Milk, Half ...
# 16                                current price $3.98
# 17  Great Value Organic Reduced Fat 2% Milk, 1 Gal...
# 18                                current price $6.98
# 19  Great Value Lactose Free 2% Reduced Fat Milk, ...
# 20                                current price $3.38

# %%
frames = [df4, last_10_rows]
 
result = pd.concat(frames)
display(result)
# Out:
#                                                  Name Current Price
# 0                 Lactaid 2% Reduced Fat Milk, 64 oz
# 1                                 current price $4.48
# 3   Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...
# 4                                 current price $2.98
# 6   Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...
# 7                                 current price $2.98
# 9   Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...
# 10                                current price $1.98
# 11  fairlife Lactose Free 2% Reduced Fat Ultra Fil...
# 12                                current price $4.48
# 13  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...
# 14                                current price $3.97
# 15  Great Value Organic 2% Reduced Fat Milk, Half ...
# 16                                current price $3.98
# 17  Great Value Organic Reduced Fat 2% Milk, 1 Gal...
# 18                                current price $6.98
# 19  Great Value Lactose Free 2% Reduced Fat Milk, ...
# 20                                current price $3.38

# %%
milk_list = pd.DataFrame({'Name':result['Name'].iloc[::2].values, 'Current Price':result['Name'].iloc[1::2].values})
milk_list
# Out:
#                                                 Name        Current Price
# 0                Lactaid 2% Reduced Fat Milk, 64 oz   current price $4.48
# 1  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...  current price $2.98
# 2  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...  current price $2.98
# 3  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...  current price $1.98
# 4  fairlife Lactose Free 2% Reduced Fat Ultra Fil...  current price $4.48
# 5  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...  current price $3.97
# 6  Great Value Organic 2% Reduced Fat Milk, Half ...  current price $3.98
# 7  Great Value Organic Reduced Fat 2% Milk, 1 Gal...  current price $6.98
# 8  Great Value Lactose Free 2% Reduced Fat Milk, ...  current price $3.38

# %%
milk_list[['1', '2']] = milk_list['Current Price'].str.split('$', expand=True)
print(milk_list)
# Out:
#                                                 Name        Current Price  \
# 0                Lactaid 2% Reduced Fat Milk, 64 oz   current price $4.48
# 1  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...  current price $2.98
# 2  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...  current price $2.98
# 3  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...  current price $1.98
# 4  fairlife Lactose Free 2% Reduced Fat Ultra Fil...  current price $4.48
# 5  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...  current price $3.97
# 6  Great Value Organic 2% Reduced Fat Milk, Half ...  current price $3.98
# 7  Great Value Organic Reduced Fat 2% Milk, 1 Gal...  current price $6.98
# 8  Great Value Lactose Free 2% Reduced Fat Milk, ...  current price $3.38
#
#                 1     2
# 0  current price   4.48
# 1  current price   2.98
# 2  current price   2.98
# 3  current price   1.98
# 4  current price   4.48
# 5  current price   3.97
# 6  current price   3.98
# 7  current price   6.98
# 8  current price   3.38

# %%
milk_list = milk_list.drop(['Current Price', '1'], axis=1)
milk_list.columns = ["Name", "Current Price"]
milk_list
# Out:
#                                                 Name Current Price
# 0                Lactaid 2% Reduced Fat Milk, 64 oz           4.48
# 1  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...          2.98
# 2  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...          2.98
# 3  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...          1.98
# 4  fairlife Lactose Free 2% Reduced Fat Ultra Fil...          4.48
# 5  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...          3.97
# 6  Great Value Organic 2% Reduced Fat Milk, Half ...          3.98
# 7  Great Value Organic Reduced Fat 2% Milk, 1 Gal...          6.98
# 8  Great Value Lactose Free 2% Reduced Fat Milk, ...          3.38

# %%
milk_list["Category"] = "Milk"
milk_list["Store"] = "Walmart"
milk_list
# Out:
#                                                 Name Current Price Category  \
# 0                Lactaid 2% Reduced Fat Milk, 64 oz           4.48     Milk
# 1  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...          2.98     Milk
# 2  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...          2.98     Milk
# 3  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...          1.98     Milk
# 4  fairlife Lactose Free 2% Reduced Fat Ultra Fil...          4.48     Milk
# 5  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...          3.97     Milk
# 6  Great Value Organic 2% Reduced Fat Milk, Half ...          3.98     Milk
# 7  Great Value Organic Reduced Fat 2% Milk, 1 Gal...          6.98     Milk
# 8  Great Value Lactose Free 2% Reduced Fat Milk, ...          3.38     Milk
#
#      Store
# 0  Walmart
# 1  Walmart
# 2  Walmart
# 3  Walmart
# 4  Walmart
# 5  Walmart
# 6  Walmart
# 7  Walmart
# 8  Walmart

# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
url = 'https://www.walmart.com/browse/food/vanilla-extract-food-coloring-spices/976759_976780_9959366_5020530?sort=best_match&cat_id=976759_976780_9959366_5020530_1343575&stores=5012&ps=40&facet=fulfillment_method_in_store%3AIn-store'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="GDYgosXLm1si5QFj">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="GDYgosXLm1si5QFj">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="GDYgosXLm1si5QFj" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    Vanilla Extract - Walmart.com
#   </title>
#   <meta content="Shop for Vanilla Extract in Vanilla Extract, Food Coloring &amp; Spices. Buy products such as Great Value Pure Vanilla Extract, 2 fl oz (Food Form: Liquid, Plastic Container) at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/vanilla-extract/976759_976780_9959366_5020530_1343575" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/vanilla-extract/976759_976780_9959366_5020530_1343575" property="og:url"/>
#   <meta content="Shop for Vanilla Extract in Vanilla Extract, Food Coloring &amp; Spices. Buy products such as Great Value Pure Vanilla Extract, 2 fl oz (Food Form: Liquid, Plastic Container) at Walmart and save." property="og:description"/>
#   <meta content="Vanilla Extract - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/asr/5e491221-35c3-4e58-9025-c9ac41028005_1.53c1a6aabedd102503dbbf9985eeb49a.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="GDYgosXLm1si5QFj" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking/976780","name":"Baking"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking-ingredients/9959366","name":"Baking Ingredients"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/vanilla-extract-food-coloring-spices/5020530","name":"Vanilla Extract, Food Coloring & Spices"}},{"@type":"ListItem","position":5,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/baking/vanilla-extract/976759_976780_1343575","name":"Vanilla Extract"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/5e491221-35c3-4e58-9025-c9ac41028005_1.53c1a6aabedd102503dbbf9985eeb49a.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/0e0e46f9-84cd-4f56-a72d-90aa9ddda859.e2500a08b8d1c861819e9654eaf1a5e4.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/6a24f245-6bb0-4df5-9c0b-23069c86bc5e.773594ae15126877bba2b0b481a3e5e7.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/1660cb44-1478-45c4-bacf-e464defd48c1.35f5b98472debe9c8cb4eee3ae6d33cf.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="GDYgosXLm1si5QFj">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="GDYgosXLm1si5QFj" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="GDYgosXLm1si5QFj" rel="stylesheet"/>
#   <noscript data-n-css="GDYgosXLm1si5QFj">
#   </noscript>
#   <script defer="" nomodule="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_modules_pills-module.eb63d8a3432ae3f8.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="GDYgosXLm1si5QFj" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="GDYgosXLm1si5QFj">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="GDYgosXLm1si5QFj" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_976780_9959366_5020530_1343575&amp;_be_shelf_id=&amp;facet=fulfillment_method%3AIn-store&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=fulfillment_method%3AIn-store&amp;stores=5281&amp;cat_id=976759_976780_9959366_5020530_1343575&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking/976780" itemprop="item">
#                   <span itemprop="name">
#                    Baking
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking-ingredients/9959366" itemprop="item">
#                   <span itemprop="name">
#                    Baking Ingredients
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/vanilla-extract-food-coloring-spices/5020530" itemprop="item">
#                   <span itemprop="name">
#                    Vanilla Extract, Food Coloring &amp; Spices
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/baking/vanilla-extract/976759_976780_1343575" itemprop="item">
#                   <span itemprop="name">
#                    Vanilla Extract
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-black near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="true" aria-label="In-store , filter applied" class="f6 pv2 br-pill bn sans-serif flex bg-black near-white pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Price" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Brand" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Fulfillment Speed" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <button class="flex-shrink-0 f6 bg-white bn ph2 pv0 pointer sans-serif underline">
#                 Clear all
#                </button>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <section aria-label="Quick refinements" class="pv3" style="background-color:">
#               <div class="flex flex-column justify-center relative" data-testid="horizontal-scroller-chipModuleWithImages">
#                <a aria-label="Previous slide for chipModuleWithImages list" class="absolute dn z-5 bg-white br-100 pa0 pointer br-100 nav-control left-1" data-testid="horizontal-scroller-previous" link-identifier="horizontalScrollerPrevious" role="button">
#                 <i class="ld ld-ChevronLeft" style="font-size:1.5rem;vertical-align:-0.25em;padding:12px;width:1.5rem;height:1.5rem;box-sizing:content-box">
#                 </i>
#                </a>
#                <ul class="list ma0 pl0 overflow-x-scroll hidesb hidesb-wk relative overflow-y-hidden pl3 spl3 pl4-xl" data-testid="carousel-container" style="display:flex;grid-auto-flow:column;scroll-snap-type:;max-height:fit-content">
#                 <li class="flex flex-column items-center" data-slide="0">
#                  <a class="link w5 pointer tc mr3" href="https://www.walmart.com/browse/food/extracts-flavoring/976759_976780_9959366_5020530_6652727?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Extractsandflavorings_Rweb_Aug_28" link-identifier="Extracts &amp; flavorings click" role="link" style="width:104px">
#                   <div class="overflow-hidden relative tc mh3" style="height:72px">
#                    <img alt="pure peppermint extract" class="mw-100 absolute left-0 bottom-0" height="100%" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-8f19/k2-_cf850c0b-6c3b-47dd-878d-864b032d4645.v1.jpg" style="object-fit:contain" width="100%"/>
#                   </div>
#                   <div class="black mt2 mb1 lh-solid ph1">
#                    Extracts &amp; flavorings
#                   </div>
#                  </a>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="1">
# ...
#                         </div>
#                         <div class="flex flex-row">
#                          <i class="ld ld-Location mt1 mb1" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                          </i>
#                          <div class="f6 mt1 mb1">
#                           G11
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="bb b--near-white w-100 absolute mt3" style="left:1.5rem">
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="GDYgosXLm1si5QFj" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"chipModuleWithImages","pillsV2":[{"title":"Extracts \u0026 flavorings","titleColor":null,"url":"https://www.walmart.com/browse/food/extracts-flavoring/976759_976780_9959366_5020530_6652727?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Extractsandflavorings_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-8f19/k2-_cf850c0b-6c3b-47dd-878d-864b032d4645.v1.jpg","alt":"pure peppermint extract","assetId":"Pure Peppermint Extract.jpg","assetName":"Pure Peppermint Extract.jpg"}},{"title":"Vanilla extract","titleColor":null,"url":"https://www.walmart.com/browse/food/vanilla-extract/976759_976780_1343575?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Vanillaextract_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-4233/k2-_33d0dd94-695a-4852-8793-f3945d0d9227.v1.webp","alt":"McCormick Vanilla","assetId":"McCormick Vanilla.webp","assetName":"McCormick Vanilla.webp"}},{"title":"Food coloring ","titleColor":null,"url":"https://www.walmart.com/browse/food/food-coloring/976759_976780_9959366_5020530_4456480?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Foodcoloring_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-fea4/k2-_ce953235-e560-45b7-aca2-b67d8b3d343a.v1.png","alt":"red food color ","assetId":"Red Food Color.png","assetName":"Red Food Color.png"}},{"title":"Cinnamon","titleColor":null,"url":"https://www.walmart.com/browse/food/cinnamon/976759_976780_2911883?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Cinnamon_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-a0cb/k2-_0fa58aa8-9be7-478d-8d1e-cc6aa244ced4.v1.jpg","alt":"McCormick Cinnamon ","assetId":"FY24Q4_Cinnamon_Pill.jpeg","assetName":"FY24Q4_Cinnamon_Pill.jpeg"}},{"title":"Pumpkin spice","titleColor":null,"url":"https://www.walmart.com/browse/food/pumpkin-spice/976759_976780_9071370?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Pumpkinspice_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-7e0e/k2-_27894733-2de0-43ff-8205-ec903d5fb030.v1.webp","alt":"Pumpkin Spice","assetId":"Pumpkin spice","assetName":"Pumpkin spice"}},{"title":"Nutmeg","titleColor":null,"url":"https://www.walmart.com/browse/food/nutmeg/976759_976780_9959366_5020530_6917559?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Nutmeg_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-4e5e/k2-_a96bfcb1-48d3-46ec-be56-64b106f20bc4.v1.png","alt":"Nutmeg","assetId":"Nutmeg.png","assetName":"Nutmeg.png"}},{"title":"Cloves","titleColor":null,"url":"https://www.walmart.com/browse/food/cloves/976759_976780_4389538?povid=976759_nup_976780_BakingSpicesExtractsFoodColor_Cloves_Rweb_Aug_28","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-b14c/k2-_5907310e-a21e-482f-ac56-50d93b48420e.v1.png","alt":"ground cloves","assetId":"Ground Cloves.png","assetName":"Ground Cloves.png"}}]}},"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":"bottomZone1"},"configs":{"__typename":"TempoWM_GLASSWWWMarqueeDisplayAdConfigs","_rawConfigs":{"moduleLocation":"marquee2","lazy":"1000"},"ad":null}},"bottomZone3":{"__typename":"TempoModule","type":"CopyBlock","name":"Copy Block","version":5,"moduleId":"2ca07422-a364-4155-9173-79e615c57141","schedule":{"priority":1},"matchedTrigger":{"zone":"bottomZone3"},"configs":{"__typename":"TempoWM_GLASSWWWCopyBlockConfigs","copyBlock":{"cwc":null}}},"bottomZone5":{"__typename":"TempoModule","type":"Ge ...
#   </script>
#   <script id="release-metadata" nonce="GDYgosXLm1si5QFj" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"eus2"}
#   </script>
#   <script nonce="GDYgosXLm1si5QFj">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="GDYgosXLm1si5QFj">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="GDYgosXLm1si5QFj">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="GDYgosXLm1si5QFj" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Great Value Pure Vanilla Extract, 2 fl oz (Food Form: Liquid, Plastic Container)
# current price $5.72
# 4.5 out of 5 Stars. 606 reviews
# Baker's Imitation Vanilla Flavor, 8 fl oz
# current price $1.46
# 4.5 out of 5 Stars. 555 reviews
# McCormick Pure Vanilla Extract, 2 fl oz Baking Extracts
# current price $6.97
# 4.5 out of 5 Stars. 281 reviews
# Great Value Pure Vanilla Extract, 1 fl oz (Ambient, Plastic Container)
# current price $3.94
# 4.2 out of 5 Stars. 110 reviews
# Molina Mexican Vanilla Blend, 8.3 FL OZ
# current price $1.58
# 4.4 out of 5 Stars. 297 reviews
# Watkins Baking Vanilla, 8 fl oz (Plastic Container)
# current price $8.98
# 4.6 out of 5 Stars. 201 reviews

# %%
vanilla = pd.DataFrame(conditional_text)

vanilla
# Out:
#                                                     0
# 0   Great Value Pure Vanilla Extract, 2 fl oz (Foo...
# 1                                 current price $5.72
# 2                     4.5 out of 5 Stars. 606 reviews
# 3          Baker's Imitation Vanilla Flavor, 8 fl oz
# 4                                 current price $1.46
# 5                     4.5 out of 5 Stars. 555 reviews
# 6   McCormick Pure Vanilla Extract, 2 fl oz Baking...
# 7                                 current price $6.97
# 8                     4.5 out of 5 Stars. 281 reviews
# 9   Great Value Pure Vanilla Extract, 1 fl oz (Amb...
# 10                                current price $3.94
# 11                    4.2 out of 5 Stars. 110 reviews
# 12           Molina Mexican Vanilla Blend, 8.3 FL OZ
# 13                                current price $1.58
# 14                    4.4 out of 5 Stars. 297 reviews
# 15  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...
# 16                                current price $8.98
# 17                    4.6 out of 5 Stars. 201 reviews

# %%
vanilla.insert(1, 'Current Price', '')

# %%
vanilla.columns = ["Name", "Current Price"]
vanilla
# Out:
#                                                  Name Current Price
# 0   Great Value Pure Vanilla Extract, 2 fl oz (Foo...
# 1                                 current price $5.72
# 2                     4.5 out of 5 Stars. 606 reviews
# 3          Baker's Imitation Vanilla Flavor, 8 fl oz
# 4                                 current price $1.46
# 5                     4.5 out of 5 Stars. 555 reviews
# 6   McCormick Pure Vanilla Extract, 2 fl oz Baking...
# 7                                 current price $6.97
# 8                     4.5 out of 5 Stars. 281 reviews
# 9   Great Value Pure Vanilla Extract, 1 fl oz (Amb...
# 10                                current price $3.94
# 11                    4.2 out of 5 Stars. 110 reviews
# 12           Molina Mexican Vanilla Blend, 8.3 FL OZ
# 13                                current price $1.58
# 14                    4.4 out of 5 Stars. 297 reviews
# 15  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...
# 16                                current price $8.98
# 17                    4.6 out of 5 Stars. 201 reviews

# %%
df5 = vanilla[vanilla.index % 3 != 2] 
df5
# Out:
#                                                  Name Current Price
# 0   Great Value Pure Vanilla Extract, 2 fl oz (Foo...
# 1                                 current price $5.72
# 3          Baker's Imitation Vanilla Flavor, 8 fl oz
# 4                                 current price $1.46
# 6   McCormick Pure Vanilla Extract, 2 fl oz Baking...
# 7                                 current price $6.97
# 9   Great Value Pure Vanilla Extract, 1 fl oz (Amb...
# 10                                current price $3.94
# 12           Molina Mexican Vanilla Blend, 8.3 FL OZ
# 13                                current price $1.58
# 15  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...
# 16                                current price $8.98

# %%
vanilla_list = pd.DataFrame({'Name':df5['Name'].iloc[::2].values, 'Current Price':df5['Name'].iloc[1::2].values})
vanilla_list
# Out:
#                                                 Name        Current Price
# 0  Great Value Pure Vanilla Extract, 2 fl oz (Foo...  current price $5.72
# 1         Baker's Imitation Vanilla Flavor, 8 fl oz   current price $1.46
# 2  McCormick Pure Vanilla Extract, 2 fl oz Baking...  current price $6.97
# 3  Great Value Pure Vanilla Extract, 1 fl oz (Amb...  current price $3.94
# 4           Molina Mexican Vanilla Blend, 8.3 FL OZ   current price $1.58
# 5  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...  current price $8.98

# %%
vanilla_list[['1', '2']] = vanilla_list['Current Price'].str.split('$', expand=True)
print(vanilla_list)
# Out:
#                                                 Name        Current Price  \
# 0  Great Value Pure Vanilla Extract, 2 fl oz (Foo...  current price $5.72
# 1         Baker's Imitation Vanilla Flavor, 8 fl oz   current price $1.46
# 2  McCormick Pure Vanilla Extract, 2 fl oz Baking...  current price $6.97
# 3  Great Value Pure Vanilla Extract, 1 fl oz (Amb...  current price $3.94
# 4           Molina Mexican Vanilla Blend, 8.3 FL OZ   current price $1.58
# 5  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...  current price $8.98
#
#                 1     2
# 0  current price   5.72
# 1  current price   1.46
# 2  current price   6.97
# 3  current price   3.94
# 4  current price   1.58
# 5  current price   8.98

# %%
vanilla_list = vanilla_list.drop(['Current Price', '1'], axis=1)
vanilla_list.columns = ["Name", "Current Price"]
vanilla_list
# Out:
#                                                 Name Current Price
# 0  Great Value Pure Vanilla Extract, 2 fl oz (Foo...          5.72
# 1         Baker's Imitation Vanilla Flavor, 8 fl oz           1.46
# 2  McCormick Pure Vanilla Extract, 2 fl oz Baking...          6.97
# 3  Great Value Pure Vanilla Extract, 1 fl oz (Amb...          3.94
# 4           Molina Mexican Vanilla Blend, 8.3 FL OZ           1.58
# 5  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...          8.98

# %%
vanilla_list["Category"] = "Vanilla Extract"
vanilla_list["Store"] = "Walmart"
vanilla_list
# Out:
#                                                 Name Current Price  \
# 0  Great Value Pure Vanilla Extract, 2 fl oz (Foo...          5.72
# 1         Baker's Imitation Vanilla Flavor, 8 fl oz           1.46
# 2  McCormick Pure Vanilla Extract, 2 fl oz Baking...          6.97
# 3  Great Value Pure Vanilla Extract, 1 fl oz (Amb...          3.94
# 4           Molina Mexican Vanilla Blend, 8.3 FL OZ           1.58
# 5  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...          8.98
#
#           Category    Store
# 0  Vanilla Extract  Walmart
# 1  Vanilla Extract  Walmart
# 2  Vanilla Extract  Walmart
# 3  Vanilla Extract  Walmart
# 4  Vanilla Extract  Walmart
# 5  Vanilla Extract  Walmart

# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
url = 'https://www.walmart.com/browse/food/unsalted-butter/976759_9176907_1001467_5254440?povid=976759_nup_9176907_ButterBrowseNup_UnsaltedButter_Rweb_2_15_2024'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="DYWCFzYBOZ211vUQ">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="DYWCFzYBOZ211vUQ" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    Unsalted Butter in Butter &amp; Margarine - Walmart.com
#   </title>
#   <meta content="Shop for Unsalted Butter in Butter &amp; Margarine. Buy products such as Great Value Sweet Cream Unsalted Butter Sticks, 4 Count,16 oz at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/unsalted-butter/976759_9176907_1001467_5254440" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/unsalted-butter/976759_9176907_1001467_5254440" property="og:url"/>
#   <meta content="Shop for Unsalted Butter in Butter &amp; Margarine. Buy products such as Great Value Sweet Cream Unsalted Butter Sticks, 4 Count,16 oz at Walmart and save." property="og:description"/>
#   <meta content="Unsalted Butter in Butter &amp; Margarine - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/seo/Kerrygold-Grass-Fed-Pure-Irish-Unsalted-Butter-8-oz-2-Sticks_e119c28c-f977-4de1-b0f0-d56dcf8fc758.f5a4483d0f88f9f38d3ccbc178f7a545.png?odnHeight=180&amp;odnWidth=180&amp;odnBg=FFFFFF" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="DYWCFzYBOZ211vUQ" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/dairy-eggs/9176907","name":"Dairy & Eggs"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/butter-margarine/1001467","name":"Butter & Margarine"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/butter-margarine/unsalted-butter/976759_9176907_1001467_5254440","name":"Unsalted Butter"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/seo/Kerrygold-Grass-Fed-Pure-Irish-Unsalted-Butter-8-oz-2-Sticks_e119c28c-f977-4de1-b0f0-d56dcf8fc758.f5a4483d0f88f9f38d3ccbc178f7a545.png?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/b2f46708-c0e7-4bb5-b5c9-b2f0d2cf74e7.d4f4b3d4d889ce7215159f0680b82c87.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/e119c28c-f977-4de1-b0f0-d56dcf8fc758.f5a4483d0f88f9f38d3ccbc178f7a545.png?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/aeb66634-1492-4e84-833c-e7b59e2215f1.dcf8061c933ec1e7778df0f00740d266.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="DYWCFzYBOZ211vUQ" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="DYWCFzYBOZ211vUQ" rel="stylesheet"/>
#   <noscript data-n-css="DYWCFzYBOZ211vUQ">
#   </noscript>
#   <script defer="" nomodule="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_modules_pills-module.eb63d8a3432ae3f8.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_locale-text-sponsored.dbdd0f3382b29a8e.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_feedback.c3ba971626fca41f.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/livingdesign_deprecated-components.e2e5d1a7367a34dd.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="DYWCFzYBOZ211vUQ" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="DYWCFzYBOZ211vUQ" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_9176907_1001467_5254440&amp;_be_shelf_id=&amp;facet=&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=&amp;stores=5281&amp;cat_id=976759_9176907_1001467_5254440&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/dairy-eggs/9176907" itemprop="item">
#                   <span itemprop="name">
#                    Dairy &amp; Eggs
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/butter-margarine/1001467" itemprop="item">
#                   <span itemprop="name">
#                    Butter &amp; Margarine
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/butter-margarine/unsalted-butter/976759_9176907_1001467_5254440" itemprop="item">
#                   <span itemprop="name">
#                    Unsalted Butter
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="false" aria-label="In-store" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Price" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Brand" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Fulfillment Speed" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <section aria-label="Quick refinements" class="pv3" style="background-color:">
#               <div class="flex flex-column justify-center relative" data-testid="horizontal-scroller-chipModuleWithImages">
#                <a aria-label="Previous slide for chipModuleWithImages list" class="absolute dn z-5 bg-white br-100 pa0 pointer br-100 nav-control left-1" data-testid="horizontal-scroller-previous" link-identifier="horizontalScrollerPrevious" role="button">
#                 <i class="ld ld-ChevronLeft" style="font-size:1.5rem;vertical-align:-0.25em;padding:12px;width:1.5rem;height:1.5rem;box-sizing:content-box">
#                 </i>
#                </a>
#                <ul class="list ma0 pl0 overflow-x-scroll hidesb hidesb-wk relative overflow-y-hidden pl3 spl3 pl4-xl" data-testid="carousel-container" style="display:flex;grid-auto-flow:column;scroll-snap-type:;max-height:fit-content">
#                 <li class="flex flex-column items-center" data-slide="0">
#                  <a class="link w5 pointer tc mr3" href="https://www.walmart.com/cp/dairy-eggs/9176907?povid=976759_nup_9176907_ButterBrowseNup_Shopalldairy_Rweb_2_15_2024" link-identifier="Shop all dairy click" role="link" style="width:104px">
#                   <div class="overflow-hidden relative tc mh3" style="height:72px">
#                    <img alt="Shop all dairy" class="mw-100 absolute left-0 bottom-0" height="100%" loading="lazy" src="https://i5.walmartimages.com/dfw/4ff9c6c9-215d/k2-_7c6d7205-ca8f-4ec2-8e79-8c0e84e5cb4b.v1.jpg" style="object-fit:contain" width="100%"/>
#                   </div>
#                   <div class="black mt2 mb1 lh-solid ph1" style="color:#000000">
#                    Shop all dairy
#                   </div>
#                  </a>
#                 </li>
#                 <li class="flex flex-column items-center" data-slide="1">
#                  <a class="link w5 pointer tc mr3" href="https://www.walmart.com/browse/food/butter-margarine/976759_9176907_1001467?povid=976759_nup_9176907_ButterBrowseNup_Butter_Rweb_2_15_2024" link-identifier="Butter click" role="link" style="width:104px">
#                   <div class="overflow-hidden relative tc mh3" style="height:72px">
# ...
#                        <div class="mv2" data-automation-id="fulfillment-badge">
#                         <div class="f7 flex self-baseline dark-gray">
#                          <div>
#                           Free shipping, arrives
#                           <span class="b">
#                            in 3+ days
#                           </span>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="bb b--near-white w-100 absolute mt3" style="left:1.5rem">
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="DYWCFzYBOZ211vUQ" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"chipModuleWithImages","pillsV2":[{"title":"Shop all dairy","titleColor":"#000000","url":"https://www.walmart.com/cp/dairy-eggs/9176907?povid=976759_nup_9176907_ButterBrowseNup_Shopalldairy_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-215d/k2-_7c6d7205-ca8f-4ec2-8e79-8c0e84e5cb4b.v1.jpg","alt":"Shop all dairy","assetId":"Shop all dairy_Hubandspoke.jpg","assetName":"Shop all dairy_Hubandspoke.jpg"}},{"title":"Butter","titleColor":null,"url":"https://www.walmart.com/browse/food/butter-margarine/976759_9176907_1001467?povid=976759_nup_9176907_ButterBrowseNup_Butter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-ffcc/k2-_0e1c353d-45a8-445a-a40e-453245106abc.v1.png","alt":"Butter","assetId":"44314b40-9845-11ed-9974-b936d69b3912","assetName":"Dairy_butter_nup.png"}},{"title":"Margarine","titleColor":null,"url":"https://www.walmart.com/browse/food/margarines/976759_9176907_1001467_6384204?povid=976759_nup_9176907_ButterBrowseNup_Margarine_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-7eb3/k2-_f73bbe5c-52e4-49c9-956b-7361062fc8c5.v1.png","alt":"Margarine","assetId":"66739690-9845-11ed-a9f9-b392df429abf","assetName":"Dairy_margarine_nup.png"}},{"title":"Clarified butter","titleColor":null,"url":"https://www.walmart.com/browse/food/clarified-butter/976759_9176907_1001467_3315830?povid=976759_nup_9176907_ButterBrowseNup_ClarifiedButter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-82d9/k2-_fd27436f-a778-4868-b57b-a7e387de68e1.v1.jpg","alt":"Clarified butter","assetId":"57f39520-9845-11ed-9141-4368a4e5e332","assetName":"Dairy_clarified_butter_nup.jpeg"}},{"title":"Stick butter","titleColor":null,"url":"https://www.walmart.com/browse/food/butter-sticks/976759_9176907_1001467_6344705?povid=976759_nup_9176907_ButterBrowseNup_StickButter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-9dec/k2-_2861c264-9d20-4ba8-93a3-3787908c7505.v1.jpg","alt":"Stick butter","assetId":"2a439c00-9846-11ed-a9fe-b1c5c806f093","assetName":"Dairy_butter_sticks_nup3.jpeg"}},{"title":"Unsalted butter","titleColor":null,"url":"https://www.walmart.com/browse/food/unsalted-butter/976759_9176907_1001467_5254440?povid=976759_nup_9176907_ButterBrowseNup_UnsaltedButter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-8b57/k2-_acfa3ea0-0f78-42d5-8521-4f19e853c787.v1.png","alt":"Unsalted butter","assetId":"709a01e0-9845-11ed-9974-b936d69b3912","assetName":"Dairy_unsalted_butter_nup.png"}},{"title":"Cultured butter","titleColor":null,"url":"https://www.walmart.com/browse/food/cultured-butter/976759_9176907_1001467_4780832?povid=976759_nup_9176907_ButterBrowseNup_CulturedButter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-c200/k2-_c3a4c76c-669e-46e8-8b91-eda4f7341dd5.v1.jpg","alt":"Cultured butter","assetId":"603b7c70-9845-11ed-8204-0764f3a2604d","assetName":"Dairy_cultured_butter_nup.jpeg"}},{"title":"Plant based butter","titleColor":null,"url":"https://www.walmart.com/browse/food/plant-based-butter/976759_9176907_1001467_6048965?povid=976759_nup_9176907_ButterBrowseNup_PlantBasedButter_Rweb_2_15_2024","image":{"src":"https://i5.walmartimages.com/dfw/4ff9c6c9-b0da/k2-_047ec5dd-fc44-46c5-8a57-78fc58aa2322.v1.jpg","alt":"Plant based butter","assetId":"6bc9b520-9845-11ed-a9f9-b392df429abf","assetName":"Dairy_plant_based_butter_nup.jpeg"}},{"title":"Grass fed butter","titleColor":null,"url":"https://www.walmart.com/browse/food/grass-fed-butter/976759_9176907_1001467_7526239?povid=976759_nup_9176907_ButterBrowseNup_GrassFedBut ...
#   </script>
#   <script id="release-metadata" nonce="DYWCFzYBOZ211vUQ" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"scus"}
#   </script>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="DYWCFzYBOZ211vUQ">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="DYWCFzYBOZ211vUQ" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Kerrygold Grass-Fed Pure Irish Unsalted Butter, 8 oz 2 Sticks
# current price $4.27
# 4 out of 5 Stars. 74 reviews
# Great Value Sweet Cream Unsalted Butter Sticks, 4 Count,16 oz
# current price $3.98
# Kerrygold Grass-Fed Pure Irish Unsalted Butter, 8 oz 2 Sticks
# current price $4.27
# Horizon Organic Unsalted Butter Sticks, 16 oz 4 Count
# current price $7.12
# (20 Pack)Kerrygold Unsalted Butter, 8 oz.
# current price $135.47

# %%
butter = pd.DataFrame(conditional_text)

butter
# Out:
#                                                     0
# 0   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 1                                 current price $4.27
# 2                        4 out of 5 Stars. 74 reviews
# 3   Great Value Sweet Cream Unsalted Butter Sticks...
# 4                                 current price $3.98
# 5   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 6                                 current price $4.27
# 7   Horizon Organic Unsalted Butter Sticks, 16 oz ...
# 8                                 current price $7.12
# 9          (20 Pack)Kerrygold Unsalted Butter, 8 oz.
# 10                              current price $135.47

# %%
butter.insert(1, 'Current Price', '')

# %%
butter.columns = ["Name", "Current Price"]
butter
# Out:
#                                                  Name Current Price
# 0   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 1                                 current price $4.27
# 2                        4 out of 5 Stars. 74 reviews
# 3   Great Value Sweet Cream Unsalted Butter Sticks...
# 4                                 current price $3.98
# 5   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 6                                 current price $4.27
# 7   Horizon Organic Unsalted Butter Sticks, 16 oz ...
# 8                                 current price $7.12
# 9          (20 Pack)Kerrygold Unsalted Butter, 8 oz.
# 10                              current price $135.47

# %%
df6 = butter[butter.index % 3 != 2].iloc[:2]
df6
# Out:
#                                                 Name Current Price
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 1                                current price $4.27

# %%
last_rows = butter.tail(8)
last_rows
# Out:
#                                                  Name Current Price
# 3   Great Value Sweet Cream Unsalted Butter Sticks...
# 4                                 current price $3.98
# 5   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 6                                 current price $4.27
# 7   Horizon Organic Unsalted Butter Sticks, 16 oz ...
# 8                                 current price $7.12
# 9          (20 Pack)Kerrygold Unsalted Butter, 8 oz.
# 10                              current price $135.47

# %%
frames2 = [df6, last_rows]
 
result2 = pd.concat(frames2)
display(result2)
# Out:
#                                                  Name Current Price
# 0   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 1                                 current price $4.27
# 3   Great Value Sweet Cream Unsalted Butter Sticks...
# 4                                 current price $3.98
# 5   Kerrygold Grass-Fed Pure Irish Unsalted Butter...
# 6                                 current price $4.27
# 7   Horizon Organic Unsalted Butter Sticks, 16 oz ...
# 8                                 current price $7.12
# 9          (20 Pack)Kerrygold Unsalted Butter, 8 oz.
# 10                              current price $135.47

# %%
butter_list = pd.DataFrame({'Name':result2['Name'].iloc[::2].values, 'Current Price':result2['Name'].iloc[1::2].values})
butter_list
# Out:
#                                                 Name          Current Price
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...    current price $4.27
# 1  Great Value Sweet Cream Unsalted Butter Sticks...    current price $3.98
# 2  Kerrygold Grass-Fed Pure Irish Unsalted Butter...    current price $4.27
# 3  Horizon Organic Unsalted Butter Sticks, 16 oz ...    current price $7.12
# 4         (20 Pack)Kerrygold Unsalted Butter, 8 oz.   current price $135.47

# %%
butter_list[['1', '2']] = butter_list['Current Price'].str.split('$', expand=True)
print(butter_list)
# Out:
#                                                 Name          Current Price  \
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...    current price $4.27
# 1  Great Value Sweet Cream Unsalted Butter Sticks...    current price $3.98
# 2  Kerrygold Grass-Fed Pure Irish Unsalted Butter...    current price $4.27
# 3  Horizon Organic Unsalted Butter Sticks, 16 oz ...    current price $7.12
# 4         (20 Pack)Kerrygold Unsalted Butter, 8 oz.   current price $135.47
#
#                 1       2
# 0  current price     4.27
# 1  current price     3.98
# 2  current price     4.27
# 3  current price     7.12
# 4  current price   135.47

# %%
butter_list = butter_list.drop(['Current Price', '1'], axis=1)
butter_list.columns = ["Name", "Current Price"]
butter_list
# Out:
#                                                 Name Current Price
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 1  Great Value Sweet Cream Unsalted Butter Sticks...          3.98
# 2  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 3  Horizon Organic Unsalted Butter Sticks, 16 oz ...          7.12
# 4         (20 Pack)Kerrygold Unsalted Butter, 8 oz.         135.47

# %%
butter_list["Category"] = "Butter"
butter_list["Store"] = "Walmart"
butter_list
# Out:
#                                                 Name Current Price Category  \
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27   Butter
# 1  Great Value Sweet Cream Unsalted Butter Sticks...          3.98   Butter
# 2  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27   Butter
# 3  Horizon Organic Unsalted Butter Sticks, 16 oz ...          7.12   Butter
# 4         (20 Pack)Kerrygold Unsalted Butter, 8 oz.         135.47   Butter
#
#      Store
# 0  Walmart
# 1  Walmart
# 2  Walmart
# 3  Walmart
# 4  Walmart

# %%
# Import Splinter and BeautifulSoup
import requests
from splinter import Browser
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
url = 'https://www.walmart.com/browse/food/chocolate-chips-cocoa/976759_976780_9959366_2710937?sort=best_match&cat_id=976759_976780_9959366_2710937_6862428&stores=5012&ps=40&facet=fulfillment_method%3AIn-store'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

response = requests.get(url, headers=headers) 
soup = soup(response.content, 'html.parser') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <script blocking="render" id="ttp-marker" nonce="ikmvCG0sg2g4bTdx">
#    (()=>{window.performance.mark("ttp")})();
#   </script>
#   <meta content="105223049547814" property="fb:app_id"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://tap.walmart.com " rel="dns-prefetch"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" fetchpriority="high" href="https://i5.walmartimages.com/dfw/63fd9f59-a78c/fcfae9b6-2f69-4f89-beed-f0eeb4237946/v1/BogleWeb_subset-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link href="https://beacon.walmart.com" rel="preconnect"/>
#   <link href="https://b.wal.co" rel="preconnect"/>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    var _bcq=_bcq || [];var _sessionAIBcq=_sessionAIBcq || [];_bcq.push(['_setOptions',{start_time:(new Date()).getTime(),bd:'beacon.walmart.com',bh:'beacon.lightest.walmart.com',sv:'1.2.159'}]);(function initObserver(){function getSessionId(){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}var sid=dd&&dd.props&&dd.props.pageProps&&dd.props.pageProps.isomorphicSessionId;return sid||"unknown"}function getContextInfo(propName){var nextEl=document.getElementById("__NEXT_DATA__");var text=nextEl&&nextEl.textContent;var dd;try{dd=JSON.parse(text||"{}")}catch(exc){dd={}}return dd&&dd.runtimeConfig&&dd.runtimeConfig[propName]||"unknown"}function onerror(evt){var el=evt.target;var url=el.getAttribute("src")||el.getAttribute("href");_bcq.push(["_tagAction","walmartWeb","log","wcnp_walmart-web",{msg:{isomorphicSessionId:getSessionId(),appVersion:getContextInfo("appVersion"),datacenter:getContextInfo("dataCenter"),message:{logContent:{message:"Required script failed to load. "+url},type:"CONSOLE_ERROR"},tags:["error","platform","client-error-logger"]},pg:{nm:"walmartWeb"},ta:{}}])}function onchange(changes){if(!(changes&&changes.length)){return}for(var chg of changes){var added=chg.addedNodes;if(!(added&&added.length&&chg.type==="childList")){continue}var node=added[0];var tag=node.nodeName;var rel=node.rel;var isLink=tag==="LINK";var isCss=isLink&&rel==="stylesheet";var isPreload=isLink&&rel==="preload"&&["font","style"].indexOf(node.as)>=0;if(tag==="SCRIPT"||isCss||isPreload){node.onerror=onerror}}}var observer=new MutationObserver(onchange);observer.observe(document,{attributes:true,childList:true,subtree:true});return{getSessionId:getSessionId,getContextInfo:getContextInfo,observer:observer,onchange:onchange,onerror:onerror}})();
#   </script>
#   <script async="" data-testid="pulse-script" nonce="ikmvCG0sg2g4bTdx" src="//i5.walmartimages.com/beacon/beacon.js?bd=beacon.walmart.com&amp;bh=beacon.lightest.walmart.com">
#   </script>
#   <title>
#    Semi Sweet Chocolate Chips in Chocolate Chips &amp; Cocoa - Walmart.com
#   </title>
#   <meta content="Shop for Semi Sweet Chocolate Chips in Chocolate Chips &amp; Cocoa. Buy products such as Nestle Toll House Semi Sweet Chocolate Baking Chips, 12 oz Bag at Walmart and save." name="description"/>
#   <link href="https://www.walmart.com/browse/food/semi-sweet-chocolate-chips/976759_976780_9959366_2710937_6862428" rel="canonical"/>
#   <meta content="https://www.walmart.com/browse/food/semi-sweet-chocolate-chips/976759_976780_9959366_2710937_6862428" property="og:url"/>
#   <meta content="Shop for Semi Sweet Chocolate Chips in Chocolate Chips &amp; Cocoa. Buy products such as Nestle Toll House Semi Sweet Chocolate Baking Chips, 12 oz Bag at Walmart and save." property="og:description"/>
#   <meta content="Semi Sweet Chocolate Chips in Chocolate Chips &amp; Cocoa - Walmart.com" property="og:title"/>
#   <meta content="https://i5.walmartimages.com/asr/ed61e4e0-7b73-4e86-8494-6a4b10feed92.302393d0437518a80eaf7dbcca1c9ea3.jpeg?odnHeight=180&amp;odnWidth=180&amp;odnBg=ffffff" property="og:image"/>
#   <meta content="Website" property="og:type"/>
#   <meta content="Walmart.com" property="og:site_name"/>
#   <meta content="INDEX,FOLLOW" name="robots"/>
#   <script nonce="ikmvCG0sg2g4bTdx" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/food/976759","name":"Food"}},{"@type":"ListItem","position":2,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking/976780","name":"Baking"}},{"@type":"ListItem","position":3,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/baking-ingredients/9959366","name":"Baking Ingredients"}},{"@type":"ListItem","position":4,"item":{"@type":"Thing","@id":"https://www.walmart.com/cp/chocolate-chips-cocoa/2710937","name":"Chocolate Chips & Cocoa"}},{"@type":"ListItem","position":5,"item":{"@type":"Thing","@id":"https://www.walmart.com/browse/chocolate-chips-cocoa/semi-sweet-chocolate-chips/976759_976780_9959366_2710937_6862428","name":"Semi Sweet Chocolate Chips"}}]}
#   </script>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/ed61e4e0-7b73-4e86-8494-6a4b10feed92.302393d0437518a80eaf7dbcca1c9ea3.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/96008bbf-be92-44e7-868e-340a97cf7dd7.fc070fa0d65930a08162457a96c35dd2.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/f8b7590c-0732-4f53-a3f3-4c934ecac379.4eb01412f1b4778e6281ea6b04b17345.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <link as="image" fetchpriority="high" href="https://i5.walmartimages.com/asr/a365cb5d-9f65-4c59-90c2-11aebd2c90be.f6ce96f456f20aa183ee160ff27a5831.jpeg?odnHeight=784&amp;odnWidth=580&amp;odnBg=FFFFFF" rel="preload"/>
#   <meta content="26" name="next-head-count"/>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    (()=>{
#     const lang = document.documentElement.lang;
#     Object.defineProperty(document.documentElement, "lang", {
#         get () {
#             return lang;
#         },
#         set () {}
#     });
# })()
#   </script>
#   <link href="https://i5.walmartimages.com" rel="preconnect"/>
#   <link as="style" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="ikmvCG0sg2g4bTdx" rel="preload"/>
#   <link data-n-g="" href="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/css/9d3fe594b2f1b5ac.css" nonce="ikmvCG0sg2g4bTdx" rel="stylesheet"/>
#   <noscript data-n-css="ikmvCG0sg2g4bTdx">
#   </noscript>
#   <script defer="" nomodule="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_item-queue_banner_queue-banner-6092d6be26ec365b.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_image_utils.fc1688771ea23d3b.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_@walmart+use-safeframe@0.4.0_react@17.0_node_modules_@walmart_use-safeframe_lib_index-29b5da6dfb811bc2.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-is-tracking-enabled-98f2a7cf6db73ec4.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_video-player-5788688db99e5093.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-load-ivt.088b3e6b0c37f620.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_safeframe-ui_safeframe-wrapper.639817db944121b7.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_video_vast-video-player.9fbdda654afea153.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_hooks_use-class-name-container.dcfbd72f0f690d12.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_brand-box-wrapper.35669d5b053f527f.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_gallery.402c9a981c314c1a.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp-v3.19600cc967cc20d3.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf_ads-btf-cmp.85f759519b2eef5e.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_btf.b88a7af2b2bf5ed5.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-and-filter-bar.822528463c99d00c.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_types_constants.11f935e9f307e9f6.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_helpers_get-filter-pill-click-beacon.ef70a7df02ea8c70.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-container_filter-popover.df8b744eafda6f4a.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_sort-by-dropdown.a221d52ba98670cc.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_all-filters-panel_panel-facets.9687a34d1170ffb4.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets.8cdc153d1f0744d1.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart.c1ef93f8abec3127.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_formatted-product-price.b7ae0a4549e6e786.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/webpack-e21334d13c7dca57.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/framework-fbf51d978577c6fa.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/main-703ef94972616b35.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/_app-f81d887f9be7d7f9.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_isomorphic-dompurify@0.13_node_modules_isomorphic-dompurify_browser-40a80efbab37a530.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/node_modules_.pnpm_react-google-places-autocomplete@3.4_node_modules_react-google-places-autocomplete_build_index.es-7549be97bcf2b303.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_locale_messages-57fae807f86c826a.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_horizontal-scroller_horizontal-scroller-c7dc6afa6482ea84.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_locale_messages-f5f1265a1df9abaf.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_quantity-stepper_quantity-stepper-8336f7e4b1b2b338.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/item_data-hooks_item-data-hooks-4b39ed53e9b41908.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_utils_get-ads-ccm-d2c93bccae77a71f.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_add-to-cart-37f813bc3568c74e.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_hooks_use-on-product-c1a634f75fd0a0e8.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-reward-f17764abd31f99d3.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical-a56300f1142c34c1.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/platform_tempo_components_tempo-layout-188f54bd7406cda4.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_provider_ads-context-provider-f209a3761faadbb5.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-tile_vertical_product-image-58716ba8c38483ca.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-components_locale_messages-4b327a8dc1ae83b0.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_event-timer_queue-timer-5a1ed6bfacbca6b9.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/marketplace_pro-seller_pro-seller-b87134925bd80350.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_common-data-access_locale_messages-53b9450e11b6dc5c.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ui_product-carousel_product-carousel-bf3bc6df4d72ce6f.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_data-access_hooks_use-get-cart-query-info-bc0f4ab978ec73b8.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/lists_notify-list_notify-list-8e19668537d6c1ab.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_locale_messages-9997c0311df0eeff.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector_near-by-nodes-tile-3bb4db9696068e7f.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_oos-product-tile-container-b419246058d3be0c.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_pos_fees-21856cfd72eb04d1.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_item-updates-container_utils_beacon-payload-95fc56939f4e81a7.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selector-7b15baad1746519b.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_common-components_error-text-with-tooltip-07d3250cb19fc736.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_hooks_use-save-store-set-pickup-dd6dbd68c534edc1.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/checkout_store-chooser_store-selection-modal-e8dccb8085926971.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_data-access_transforms_common-query-to-props-2b3a1ac314183ab4.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/cart_add-to-cart_use-hot-pac-bottom-sheet-e9ac571d55d73cf9.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_sponsored-products-tracking_use-sponsored-item-8d046637c5101406.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_display-ad-wrapper-4d868df6edcacb4e.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_locale_messages-fe0493d89704dc80.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_typeahead_typeahead-container-4aa59a761a85eff1.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/amends_data-access_hooks_use-amendable-order-query-01226a625decd51a.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_ui_search-brand-amplifier-top-46855c60d6b6993b.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_data-access_transforms-04424ad3bcad3dc9.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_facets_filter-bar_toggle-pill-9d5a56cd5d3d388e.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/ads_core_components_ads-error-boundary-865ddaa43627bbac.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/search_results-page_browse_results-page-7a60630dd8901212.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/chunks/pages/browse/%5B...seo%5D-93f60c6a46acad8b.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_buildManifest.js">
#   </script>
#   <script defer="" nonce="ikmvCG0sg2g4bTdx" src="https://i5.walmartimages.com/dfw/63fd9f59-75e4/a41fca0c-2a32-4df4-9025-be355def87ce/v2/en-US/_next/static/production_20240224T015011526Z-en-US/_ssgManifest.js">
#   </script>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    var TBRewriteHostAltWeight = 10.000000;
#   </script>
#   <script async="async" defer="defer" nonce="ikmvCG0sg2g4bTdx" src="//i5.walmartimages.com/a14/capabilities.min.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <div class="flex flex-column min-vh-100 shadow-2" data-testid="layout-container" style="transform:none;transition:transform .2s">
#      <span class="sticky bg-secondary w-100 top-0 z-1" data-pcss-show="true" data-testid="global-header" style="transition:top 0.65s">
#       <a class="o-0 absolute" link-identifier="Generic Name" tabindex="-1">
#       </a>
#       <a class="slider skip-main bg-white-90" href="#maincontent" link-identifier="Generic Name">
#        Skip to Main Content
#       </a>
#       <header class="flex items-center justify-center pa3 center-hdkp ph3-hdkp nav-clickable-padded" data-testid="responsiveHeader" style="transition:top 0.65s">
#        <div class="flex items-center justify-center dn-hdkp" style="transition:opacity .3s">
#         <a aria-hidden="false" aria-label="All Departments Menu" class="flex items-center b--none bg-transparent mr3 pa0 pointer h3 w3 no-underline white" href="/all-departments" link-identifier="hamburgerMenu">
#          <i aria-hidden="true" class="ld ld-Menu" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#          </i>
#         </a>
#         <a aria-hidden="false" aria-label="Walmart Homepage" class="gold h3 w3 dn-hdkp" data-automation-id="header-link-walmartLogo" href="/" link-identifier="walmartLogoMobile">
#          <i aria-hidden="true" class="ld ld-Spark" style="font-size:2rem;vertical-align:-0.325em;width:2rem;height:2rem;box-sizing:content-box">
#          </i>
#         </a>
#        </div>
#        <a aria-label="Walmart Homepage" class="dn db-hdkp flex-none pa3 hover-bg-dark-primary pt2" href="/" link-identifier="walmartLogoDesktop" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px">
#         <img alt="Walmart" class="db" data-automation-id="header-walmartLogo" height="32" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-b3e1/7a569e53-f29a-4c3d-bfaf-6f7a158bfadd/v1/walmartLogo.svg" width="130"/>
#        </a>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Grid pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Departments
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="departments-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <section class="dn db-hdkp">
#         <div class="relative">
#          <button aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title b ph3 white pointer sans-serif bg-transparent ba b--transparent" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)" type="button">
#           <i aria-hidden="true" class="ld ld-Services pr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#           Services
#          </button>
#          <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="services-flyout" style="margin-top:20px;left:50%;transform:none;margin-left:-135px;max-height:0">
#           <div>
#           </div>
#          </div>
#         </div>
#        </section>
#        <form action="/search" aria-label="Walmart Site-Wide" autocomplete="off" class="flex flex-auto items-center justify-center pl3 justify-start-hdkp pa0-hdkp ml3-hdkp static" data-testid="search-form" role="search">
#         <div class="flex flex-auto items-center relative">
#          <input aria-activedescendant="" aria-autocomplete="list" aria-haspopup="listbox" aria-label="Search" autocomplete="off" class="flex-auto lh-solid sans-serif search-bar br-pill f5 b--none" data-automation-id="header-input-search" name="q" placeholder="Search Walmart" style="padding-left:1.5rem;padding-right:2.5rem" type="search" value=""/>
#          <button aria-hidden="true" aria-label="Clear search field text" class="absolute bn bg-transparent h-100 right-2" style="padding:0 0.75rem;cursor:pointer;opacity:0" tabindex="-1" type="reset">
#           <i class="ld ld-Close" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#          <button aria-label="Search icon" class="absolute bn br-100 hover-bg-navy search-icon" style="cursor:pointer">
#           <i aria-hidden="true" class="ld ld-Search absolute" data-automation-id="search-icon" style="font-size:1rem;vertical-align:-0.175em;top:50%;left:50%;transform:translate(-50%, -50%);width:1rem;height:1rem;box-sizing:content-box">
#           </i>
#          </button>
#         </div>
#         <button aria-hidden="true" aria-label="Cancel" class="bn bg-transparent mh1 ph2 pv2 pointer sans-serif underline z-1 dn-hdkp clip o-0 white" style="transition:opacity .3s" tabindex="-1" type="button">
#          Cancel
#         </button>
#        </form>
#        <nav aria-label="My Items, Account and Cart">
#         <ul class="flex ma0 pa0 list" style="height:">
#          <li class="dn db-hdkp ml3 relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/my-items" link-identifier="Reorder my items" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-Heart pr2" style="font-size:1rem;vertical-align:-0.175em;width:16px;height:1rem;box-sizing:content-box">
#            </i>
#            <div class="nowrap">
#             <div class="lh-title f7">
#              Reorder
#             </div>
#             <div class="b">
#              My Items
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="my-items-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="ph4 pt4 pb2" data-automation-id="walmart-myitems">
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-reorder" href="/my-items" link-identifier="Reorder">
#              <i class="ld ld-Reorder mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Reorder
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" data-automation-id="walmart-list" href="/lists" link-identifier="Lists">
#              <i class="ld ld-Heart mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Lists
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mb3" href="/my-registries" link-identifier="Registries">
#              <i class="ld ld-Gift mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Registries
#             </a>
#            </div>
#           </div>
#          </li>
#          <li class="dn db-hdkp relative">
#           <a aria-expanded="false" aria-haspopup="true" class="flex items-center no-underline desktop-header-trigger lh-title lh-solid ph3 white" href="/account/login?vid=oaoh" link-identifier="Account" role="button" style="border-radius:100px;height:48px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1)">
#            <i aria-hidden="true" class="ld ld-User" style="font-size:16px;vertical-align:-0.175em;width:16px;height:16px;box-sizing:content-box">
#            </i>
#            <div class="ml2 nowrap" data-automation-id="headerSignIn">
#             <div class="mw3 mw4-hdkp truncate lh-title f7" style="height:">
#              Sign In
#             </div>
#             <div class="b" style="margin-top:">
#              Account
#             </div>
#            </div>
#           </a>
#           <div class="absolute bg-white br3 br--bottom left-0 lh-copy mt3 overflow-hidden shadow-1 dn" data-testid="account-flyout" style="margin-top:20px;left:50%;transform:translateX(-50%)">
#            <div class="pa4">
#             <button class="w_hhLG w_8nsR w_0_LY db mb3 w-100" data-testid="sign-in" type="button">
#              Sign In
#             </button>
#             <button class="w_hhLG w_XK4d w_0_LY db mb3 w-100" data-automation-id="header-create-account" type="button">
#              Create an account
#             </button>
#             <div class="mb3">
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link" data-automation-id="headerPurchaseHistory" href="/orders" link-identifier="Purchase History">
#              <i class="ld ld-Receipt mr2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#              </i>
#              Purchase History
#             </a>
#             <a class="dark-gray db f6 no-underline nowrap desktop-header-flyout-link mt3" href="/plus" link-identifier="Walmart Plus">
#              <img alt="Walmart+" class="mr2 f5" height="16" loading="lazy" src="//i5.walmartimages.com/dfw/63fd9f59-ac39/29c6759d-7f14-49fa-bd3a-b870eb4fb8fb/v1/wplus-icon-blue.svg" style="vertical-align:-0.175em" width="16"/>
#              Walmart+
#             </a>
#            </div>
#           </div>
#          </li>
#          <li aria-hidden="false" class="undefined" style="transition:opacity .3s">
#           <div class="relative">
#            <div class="cart-button ml2 flex justify-center db-hdkp justify-start-hdkp h-auto-hdkp mr4-hdkp flex-column">
#             <button aria-label="Cart contains 0 items Total Amount $0.00" class="bn bg-transparent br2 flex flex-column items-center pa0 pointer relative sans-serif pa3 justify-center white hover-bg-dark-primary" data-automation-id="cart-button-header" id="cart-button-header" style="border-radius:100px;transition:all 100ms cubic-bezier(0.77, 0, 0.175, 1);height:48px" type="button">
#              <i class="ld ld-Cart mr1 white" style="font-size:1.5rem;vertical-align:-0.25em;width:24px;height:24px;box-sizing:content-box">
#              </i>
#              <span class="db nowrap" style="font-size:.625rem;visibility:hidden;height:10px;vertical-align:-0.25em;width:30px">
#               $0.00
#              </span>
#             </button>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </nav>
#       </header>
#      </span>
#      <div aria-hidden="false" class="flex flex-column flex-auto relative z-0">
#       <div class="bg-primary white sticky z-3 gic-wrapper gic-wrapper-top" data-pcss-show="true" data-testid="gic-wrapper" id="gic-wrapper" style="min-height:41px;transition:top 0.65s">
#        <hr aria-hidden="true" class="w_8Gn9 banner-divider"/>
#        <div class="items-center flex flex-auto pv1 ph3 ph4-m" data-pcss-hide="true">
#         <div class="flex items-center h3">
#          <img alt="Banner title icon" class="mr2 br-100 v-btm" height="26" loading="lazy" src="https://i5.walmartimages.com/dfwrs/76316474-3850/k2-_c6d4aec7-b4a7-4ea4-9223-07c8daef4fcf.v1.png" width="26"/>
#          <span class="b f6">
#           How do you want your items?
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="flex-auto relative z-1" data-testid="main-content-container">
#        <div class="main-content mw1600 center" data-testid="maincontent" id="maincontent">
#         <main data-ads-url="http://swag-wmt.prod.walmart.com/fs?prg=desktop&amp;limit=40&amp;query=&amp;cat_id=976759_976780_9959366_2710937_6862428&amp;_be_shelf_id=&amp;facet=fulfillment_method%3AIn-store&amp;page=1&amp;ps=10&amp;min_price=&amp;max_price=&amp;sort=best_match&amp;ptss=&amp;pageType=BrowsePage&amp;module_search=&amp;trsp=&amp;zipcode=07095&amp;stores=5281&amp;stateOrProvinceCode=NJ&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;inCatchment=true&amp;autoOptIn=false&amp;isMoreOptionsTileEnabled=true&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS" data-sis-url="http://preso-usgm-wcnp.prod.walmart.com/v1/search?query=&amp;facet=fulfillment_method%3AIn-store&amp;stores=5281&amp;cat_id=976759_976780_9959366_2710937_6862428&amp;sort=best_match&amp;page=1&amp;min_price=&amp;max_price=&amp;_be_shelf_id=&amp;ptss=&amp;trsp=&amp;isMoreOptionsTileEnabled=true&amp;autoOptIn=false&amp;prg=desktop&amp;stateOrProvinceCode=NJ&amp;ps=40&amp;zipcode=07095&amp;pageType=BrowsePage&amp;module_search=&amp;inCatchment=true&amp;latitude=40.5545&amp;longitude=-74.2878&amp;extended_zipcode=07095&amp;addressId=&amp;customerContext=%7B%22customerId%22%3Anull%2C%22isPaidMember%22%3Afalse%2C%22isActiveMember%22%3Afalse%2C%22purseTags%22%3A%5B%5D%7D&amp;pickupStore=5281&amp;deliveryStore=5281&amp;subIntentSource=LS">
#          <div class="flex undefined flex-column h-100" data-testid="flex-container">
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="overflow-x-auto nowrap hidesb hidesb-wk mr3">
#               <nav aria-label="breadcrumb" class="pv3 pl3 ph4-xl">
#                <ol class="w_4HBV">
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/food/976759" itemprop="item">
#                   <span itemprop="name">
#                    Food
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking/976780" itemprop="item">
#                   <span itemprop="name">
#                    Baking
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/baking-ingredients/9959366" itemprop="item">
#                   <span itemprop="name">
#                    Baking Ingredients
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a class="w_MSFl" href="/cp/chocolate-chips-cocoa/2710937" itemprop="item">
#                   <span itemprop="name">
#                    Chocolate Chips &amp; Cocoa
#                   </span>
#                  </a>
#                  <span aria-hidden="true" class="w_95To">
#                   /
#                  </span>
#                 </li>
#                 <li class="w_wqtJ">
#                  <a aria-current="location" class="w_MSFl w_CNPD" href="/browse/chocolate-chips-cocoa/semi-sweet-chocolate-chips/976759_976780_9959366_2710937_6862428" itemprop="item">
#                   <span itemprop="name">
#                    Semi Sweet Chocolate Chips
#                   </span>
#                  </a>
#                 </li>
#                </ol>
#               </nav>
#              </div>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div data-testid="skyline-ad" style="height:55px;overflow:hidden">
#               <div class="w_3jM4 pa0" id="BROWSE-SkylineDisplayAd-top-">
#               </div>
#              </div>
#              <section>
#               <section aria-label="Sort and Filter section" class="w-100 flex flex-shrink-0 hidesb hidesb-wk pl3 ph4-xl pv3 relative z-10" style="min-height:64px;overflow-x:auto">
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-black near-white mr2" data-testid="filter_chip_fulfillment_method_in_store">
#                  <button aria-checked="true" aria-label="Filter by In-store , filter applied" class="f6 pv2 br-pill bn sans-serif flex bg-black near-white pointer" role="switch" type="button">
#                   <i aria-hidden="true" class="ld ld-Store ph2" data-testid="Store-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer pr3">
#                    In-store
#                   </span>
#                  </button>
#                 </div>
#                 <div id="react-aria-1">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_price">
#                  <button aria-expanded="false" aria-label="Filter by Price not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-MoneyCircle ph2" data-testid="MoneyCircle-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Price
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-2">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_brand">
#                  <button aria-expanded="false" aria-label="Filter by Brand not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <span aria-hidden="true" class="flex pointer pl3">
#                    Brand
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-3">
#                 </div>
#                </span>
#                <span class="w_J9Nk flex-shrink-0 facet-popover">
#                 <div class="flex flex-row flex-shrink-0 items-center br-pill bn bg-near-white mr2" data-testid="filter_chip_fulfillment_speed">
#                  <button aria-expanded="false" aria-label="Filter by Fulfillment Speed not applied, activate to change" class="f6 pv2 br-pill bn sans-serif flex bg-near-white filter-chip-hover-state pointer" type="button">
#                   <i aria-hidden="true" class="ld ld-Clock ph2" data-testid="Clock-icon" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                   <span aria-hidden="true" class="flex pointer">
#                    Fulfillment Speed
#                   </span>
#                   <i class="ld ld-ChevronDown mh2" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                 </div>
#                 <div id="react-aria-4">
#                 </div>
#                </span>
#                <button class="flex-shrink-0 f6 bg-white bn ph2 pv0 pointer sans-serif underline">
#                 Clear all
#                </button>
#                <div class="dark-gray flex flex-row items-center ml-auto flex-shrink-0">
#                 <span class="b mh2">
#                  Sort by
#                 </span>
#                 |
#                 <span class="w_J9Nk flex-shrink-0">
#                  <button aria-controls="react-aria-5" aria-expanded="false" aria-label="Sort by Best Match" class="bw0 bg-white sans-serif pointer pa1" type="button">
#                   Best Match
#                   <i arial-hiden="true" class="ld ld-ChevronDown pa0 ml6" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                   </i>
#                  </button>
#                  <div id="react-aria-5">
#                  </div>
#                 </span>
#                </div>
#               </section>
#              </section>
#              <hr aria-hidden="true" class="w_8Gn9"/>
#              <!-- -->
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w-100 relative-m pl4 pr4 flex pt2">
#               <div class="fl w-20 dn br b--black-10 flex-grow-0 flex-shrink-0 db-m" data-testid="lhn">
#                <section class="overflow-y-auto overflow-x-hidden" style="position:sticky;top:128px;height:86vh">
#                 <div class="pb6 pr3">
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Departments">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Departments
#                      </div>
#                      <i aria-hidden="true" class="ld ld-ChevronDown pa0" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                      </i>
#                     </button>
#                    </div>
#                   </div>
#                   <hr aria-hidden="true" class="w_8Gn9"/>
#                  </section>
#                  <section class="expand-collapse-section">
#                   <div class="nl3 nr3 relative" data-testid="expand-section-Price">
#                    <div class="ma0 f4" role="tab">
#                     <button aria-expanded="false" class="bg-white bw0 flex items-center justify-between ph3 pointer sans-serif w-100" type="button">
#                      <div class="dib b dark-gray f4 lh-copy tl w-100 pv3">
#                       Price
#                      </div>
#                      <i aria-hidden="true" class="ld ld-ChevronDown pa0" role="img" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                      </i>
#                     </button>
#                    </div>
# ...
#                         </div>
#                         <div class="flex flex-row">
#                          <i class="ld ld-Location mt1 mb1" style="font-size:1rem;vertical-align:-0.175em;width:1rem;height:1rem;box-sizing:content-box">
#                          </i>
#                          <div class="f6 mt1 mb1">
#                           G11
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                    <div class="bb b--near-white w-100 absolute mt3" style="left:1.5rem">
#                    </div>
#                   </div>
#                  </div>
#                 </section>
#                </div>
#               </div>
#              </div>
#              <div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="h-100 relative">
#            <div class="flex undefined flex-column h-100" data-testid="flex-container">
#             <div class="h-100 relative">
#              <div class="w_3jM4 pa0" id="BROWSE-MarqueeDisplayAd-marquee2-">
#              </div>
#              <div class="pt3">
#               <div class="w_3jM4 pa0" id="BROWSE-SponsoredProductCarousel-bottom-">
#               </div>
#              </div>
#              <!-- -->
#              <!-- -->
#              <!-- -->
#             </div>
#            </div>
#           </div>
#          </div>
#         </main>
#        </div>
#       </div>
#       <span>
#        <footer class="db pt5-hdkp lh-copy relative z-0">
#         <section class="flex flex-column flex-row-hdkp justify-center bg-washed-primary">
#          <section class="">
#           <div class="pb4 pt3 pa0-hdkp footer-wrapper ph3 tc" style="padding-top:2rem;padding-bottom:2rem">
#            <p class="f5 mt0">
#             We’d love to hear what you think!
#            </p>
#            <button class="w_hhLG w_XK4d w_jDfj" type="button">
#             Give feedback
#            </button>
#           </div>
#          </section>
#         </section>
#         <div class="bw2 bt-0 bl-0 br-0 b--solid b--near-white b--none-hdkp">
#         </div>
#         <section>
#          <ul class="list ma0 mt3 ph3 pt1 ma0-hdkp ph4-hdkp pb4-hdkp pt3-hdkp flex-hdkp flex-wrap-hdkp justify-center-hdkp footer-list" data-testid="responsive-footer-list">
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/all-departments" link-identifier="All Departments">
#             All Departments
#            </a>
#           </li>
#           <li>
#            <a aria-label="Store Directory - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/store/directory" link-identifier="Store Directory" rel="noopener noreferrer" target="_blank">
#             Store Directory
#            </a>
#           </li>
#           <li>
#            <a aria-label="Careers - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://careers.walmart.com/" link-identifier="Careers" rel="noopener noreferrer" target="_blank">
#             Careers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Our Company - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/" link-identifier="Our Company" rel="noopener noreferrer" target="_blank">
#             Our Company
#            </a>
#           </li>
#           <li>
#            <a aria-label="Sell on Walmart.com - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://marketplace.walmart.com/?utm_source=Walmart.com&amp;utm_medium=link&amp;utm_campaign=footer" link-identifier="Sell on Walmart.com" rel="noopener noreferrer" target="_blank">
#             Sell on Walmart.com
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help" link-identifier="Help">
#             Help
#            </a>
#           </li>
#           <li>
#            <a aria-label="Product Recalls - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/recalls" link-identifier="Product Recalls" rel="noopener noreferrer" target="_blank">
#             Product Recalls
#            </a>
#           </li>
#           <li>
#            <a aria-label="Accessibility - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/help/article/responsible-disclosure-and-accessibility-policies/0f173dab8bd942da84b1cd7ab5ffc3cb" link-identifier="Accessibility" rel="noopener noreferrer" target="_blank">
#             Accessibility
#            </a>
#           </li>
#           <li>
#            <a aria-label="Tax Exempt Program - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/taxexempt/" link-identifier="Tax Exempt Program" rel="noopener noreferrer" target="_blank">
#             Tax Exempt Program
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://walmart.onelink.me/UIev?pid=walmart.com&amp;af_web_dp=https%3A%2F%2Fwww.walmart.com%2Fcp%2Fwalmart-mobile-app%2F1087865&amp;c=Walmart.com%20Site%20Footer&amp;af_dp=walmart%3A%2F%2F" link-identifier="Get the Walmart App">
#             Get the Walmart App
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/email-opt-in/8196352?gbo=1" link-identifier="Sign-up for Email">
#             Sign-up for Email
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="http://msds.walmartstores.com/" link-identifier="Safety Data Sheet">
#             Safety Data Sheet
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="/help/article/walmart-com-terms-of-use/3b75080af40340d6bbd596f116fae5a0" link-identifier="Terms of Use">
#             Terms of Use
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy &amp; Security - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security" link-identifier="Privacy &amp; Security" rel="noopener noreferrer" target="_blank">
#             Privacy &amp; Security
#            </a>
#           </li>
#           <li>
#            <a aria-label="California Supply Chain Act - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/california-transparency" link-identifier="California Supply Chain Act" rel="noopener noreferrer" target="_blank">
#             California Supply Chain Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Your Privacy Choices - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp flex items-center" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=sod" link-identifier="Your Privacy Choices" rel="noopener noreferrer" target="_blank">
#             <img alt="Privacy choices icon" class="mr1" height="14" loading="lazy" src="//i5.walmartimages.com/dfwrs/76316474-f70e/k2-_67001355-c576-4ca2-989d-260a2673c41a.v1.png" width="29"/>
#             Your Privacy Choices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Notice at Collection - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://corporate.walmart.com/privacy-security/california-privacy-rights#what-are-the-categories-of-personal-information-collected" link-identifier="Notice at Collection" rel="noopener noreferrer" target="_blank">
#             Notice at Collection
#            </a>
#           </li>
#           <li>
#            <a aria-label="Request My Personal Information - opens in a new window" class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/account/api/ccpa-intake?native=false&amp;app=gm&amp;type=access" link-identifier="Request My Personal Information" rel="noopener noreferrer" target="_blank">
#             Request My Personal Information
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/brand/branddirectory" link-identifier="Brand Shop Directory">
#             Brand Shop Directory
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://www.walmart.com/cp/pharmacy/5431?povid=HWS_GlobalFooter_Pharmacy" link-identifier="Pharmacy">
#             Pharmacy
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link mr4-hdkp db" href="https://business.walmart.com/account/logout?vid=b2b&amp;tid=0&amp;returnUrl=%3Fpovid%3D5008973_homepage_WMTFOOTER" link-identifier="Walmart Business">
#             Walmart Business
#            </a>
#           </li>
#           <li>
#            <a class="f6 no-underline mb3 ma0-hdkp footer-link db" href="https://www.walmart.com/cp/walmart-in-the-know/7781927" link-identifier="#IYWYK">
#             #IYWYK
#            </a>
#           </li>
#          </ul>
#          <div class="f7 lh-title mt6 pb5 ph3 pt1 tc-hdkp pa0-hdkp pt2-hdkp ma0-hdkp pb5-hdkp footer-copyright">
#           © 2024 Walmart. All Rights Reserved.
#          </div>
#         </section>
#        </footer>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div aria-live="assertive">
#    </div>
#    <div aria-live="assertive">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="ikmvCG0sg2g4bTdx" type="application/json">
#    {"props":{"pageProps":{"initialData":{"headers":{},"moduleDataByZone":{"bottomZone1":{"__typename":"TempoModule","type":"MarqueeDisplayAd","name":"Marquee Display Ad BTF BP rWeb","version":3,"moduleId":"17741b72-82a8-4fee-8de2-fd4f27679ab6","schedule":{"priority":0},"matchedTrigger":{"zone":"bottomZone1"},"configs":{"__typename":"TempoWM_GLASSWWWMarqueeDisplayAdConfigs","_rawConfigs":{"moduleLocation":"marquee2","lazy":"1000"},"ad":null}},"pillsTopZone":{"__typename":"TempoModule","type":"PillsModule","name":"Browse Pills Module","version":10,"moduleId":"1b40507d-81e6-4a56-a1ac-186a21cbd058","schedule":{"priority":2},"matchedTrigger":{"zone":"pillsTopZone"},"configs":{"__typename":"TempoWM_GLASSWWWPillsModuleConfigs","moduleSource":"browsePills","pillsV2":[]}},"bottomZone3":{"__typename":"TempoModule","type":"CopyBlock","name":"Copy Block","version":5,"moduleId":"2ca07422-a364-4155-9173-79e615c57141","schedule":{"priority":1},"matchedTrigger":{"zone":"bottomZone3"},"configs":{"__typename":"TempoWM_GLASSWWWCopyBlockConfigs","copyBlock":{"cwc":null}}},"bottomZone5":{"__typename":"TempoModule","type":"GenericSEOFAQModule","name":"NEW GenericSEOFAQModule Thu Oct 05 2023 9:50 PM PDT","version":8,"moduleId":"b7ae9d11-2a1f-49c4-8ee7-10f2e7794a4c","schedule":{"priority":10},"matchedTrigger":{"zone":"bottomZone5"},"configs":{"__typename":"TempoWM_GLASSWWWGenericSEOFAQModuleConfigs","seoFaqList":null}},"topZone3":{"__typename":"TempoModule","type":"SearchSortFilterModule","name":"New Sort \u0026 Filter on Search Page Module, Wednesday, July 14, 2021, 3:12:54:47 pm","version":1,"moduleId":"c4592076-abb9-4007-8ad9-891ec264278c","schedule":{"priority":1},"matchedTrigger":{"zone":"topZone3"},"configs":{"__typename":"_TempoWM_GLASSWWWSearchSortFilterModuleConfigs","topNavFacets":[{"title":"In-store","name":"In-store","expandOnLoad":null,"type":"fulfillment_method_in_store","displayType":"TOGGLE","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":true,"values":null},{"title":"Price","name":"Price","expandOnLoad":false,"type":"price","displayType":"DROPDOWN","layout":"pill","min":1,"max":10,"selectedMin":null,"selectedMax":null,"unboundedMax":true,"stepSize":1,"isSelected":null,"values":null},{"title":"Brand","name":"Brand","expandOnLoad":false,"type":"brand","displayType":"DROPDOWN","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"values":[{"id":null,"title":"Great Value","name":"Great Value","expandOnLoad":false,"description":null,"type":null,"itemCount":2,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Nestl Toll House","name":"Nestl Toll House","expandOnLoad":false,"description":null,"type":null,"itemCount":2,"isSelected":null,"baseSeoURL":null,"values":null}]},{"title":"Fulfillment Speed","name":"Fulfillment Speed","expandOnLoad":false,"type":"fulfillment_speed","displayType":"DROPDOWN","layout":"pill","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unboundedMax":null,"stepSize":null,"isSelected":null,"values":[{"id":null,"title":"Today","name":"Today","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Tomorrow","name":"Tomorrow","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"2 days","name":"2 days","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null},{"id":null,"title":"Anytime","name":"Anytime","expandOnLoad":true,"description":null,"type":null,"itemCount":0,"isSelected":null,"baseSeoURL":null,"values":null}]}],"allSortAndFilterFacets":[{"title":"Sort by","name":"Sort by","expandOnLoad":false,"type":"sort","displayType":null,"layout":"default","min":null,"max":null,"selectedMin":null,"selectedMax":null,"unbounded ...
#   </script>
#   <script id="release-metadata" nonce="ikmvCG0sg2g4bTdx" type="application/json">
#    {"appVersion":"us-web-1.119.1-b74fd50e55ca6e8b9f9fecf76a9f5ab1298641f2-0224","dataCenter":"eus2"}
#   </script>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    window.SW_DOMAIN = "walmart.com"
#   </script>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    (function(e){var t=e.document;BOOMR=e.BOOMR||{};BOOMR.plugins=BOOMR.plugins||{};var n={localStorageTestKey:"TorbitLSTest",pageTags:[],pageConversions:[],initHasRun:false};BOOMR.plugins.pageMeta={init:function(r){initHasRun=true;try{localStorage.setItem(n.localStorageTestKey,n.localStorageTestKey);localStorage.removeItem(n.localStorageTestKey);BOOMR.addVar("ls",1)}catch(i){BOOMR.addVar("ls",0)}if(e.location.protocol=="https:")BOOMR.addVar("prt",1);else BOOMR.addVar("prt",0);BOOMR.addVar("ref",t.referrer);if(e.performance&&e.performance.memory){for(m_name in e.performance.memory){if(e.performance.memory.hasOwnProperty(m_name)){BOOMR.addVar(m_name,e.performance.memory[m_name])}}}BOOMR.addVar("wH",e.innerHeight||t.body.clientHeight||t.documentElement.clientHeight);BOOMR.addVar("tags",n.pageTags.join("|"));return this},addTag:function(e){n.pageTags.push(e);if(!n.initHasRun){return}BOOMR.addVar("tags",n.pageTags.join("|"))},addConversion:function(e,t){var r=e;if(t&&(t>0||t.length>0))r=e+"="+t;n.pageConversions.push(r);BOOMR.addVar("conversion",n.pageConversions.join("|"))},is_complete:function(){return true}}})(window);(function(e){try{e._tbq=e._tbq||[];_tbq.push=function(e){if(e.length<1||!e[0])return;switch(e[0]){case"tag":if(e.length<2)return;BOOMR.plugins.pageMeta.addTag(e[1]);break;case"startTimer":if(e.length<2)return;BOOMR.plugins.customEvents.startTimer(e[1]);break;case"endTimer":if(e.length<2)return;BOOMR.plugins.customEvents.endTimer(e[1]);break}};for(i in _tbq){if(_tbq.hasOwnProperty(i)&&i!="push"){_tbq.push(_tbq[i]);delete _tbq[i]}}}catch(t){}})(window);
#   </script>
#   <script nonce="ikmvCG0sg2g4bTdx">
#    window._pxAppId = 'PXu6b0qd2S'
#   </script>
#   <script async="async" defer="defer" nonce="ikmvCG0sg2g4bTdx" src="/px/PXu6b0qd2S/init.js">
#   </script>
#  </body>
# </html>

# %%
conditional_elements = soup.find_all("span", class_="w_iUH7")
conditional_text = [item.text for item in conditional_elements]
for i in conditional_text:
    print(i)
# Out:
# Nestle Toll House Semi Sweet Chocolate Baking Chips, 12 oz Bag
# current price $2.98
# 4.6 out of 5 Stars. 8347 reviews
# Great Value Semi-Sweet Chocolate Baking Chips, 12 oz Bag
# current price $2.62
# 4 out of 5 Stars. 248 reviews
# Nestle Toll House Semi Sweet Chocolate Mini Baking Chips, 10 oz Bag
# current price $2.98
# 4.4 out of 5 Stars. 276 reviews
# Great Value Mini Semi-Sweet Chocolate Baking Chips, 12 oz Bag
# current price $2.32
# 3.6 out of 5 Stars. 65 reviews

# %%
chips = pd.DataFrame(conditional_text)
chips
# Out:
#                                                     0
# 0   Nestle Toll House Semi Sweet Chocolate Baking ...
# 1                                 current price $2.98
# 2                    4.6 out of 5 Stars. 8347 reviews
# 3   Great Value Semi-Sweet Chocolate Baking Chips,...
# 4                                 current price $2.62
# 5                       4 out of 5 Stars. 248 reviews
# 6   Nestle Toll House Semi Sweet Chocolate Mini Ba...
# 7                                 current price $2.98
# 8                     4.4 out of 5 Stars. 276 reviews
# 9   Great Value Mini Semi-Sweet Chocolate Baking C...
# 10                                current price $2.32
# 11                     3.6 out of 5 Stars. 65 reviews

# %%
chips.insert(1, 'Current Price', '')

# %%
chips.columns = ["Name", "Current Price"]
chips
# Out:
#                                                  Name Current Price
# 0   Nestle Toll House Semi Sweet Chocolate Baking ...
# 1                                 current price $2.98
# 2                    4.6 out of 5 Stars. 8347 reviews
# 3   Great Value Semi-Sweet Chocolate Baking Chips,...
# 4                                 current price $2.62
# 5                       4 out of 5 Stars. 248 reviews
# 6   Nestle Toll House Semi Sweet Chocolate Mini Ba...
# 7                                 current price $2.98
# 8                     4.4 out of 5 Stars. 276 reviews
# 9   Great Value Mini Semi-Sweet Chocolate Baking C...
# 10                                current price $2.32
# 11                     3.6 out of 5 Stars. 65 reviews

# %%
df7 = chips[chips.index % 3 != 2]
df7
# Out:
#                                                  Name Current Price
# 0   Nestle Toll House Semi Sweet Chocolate Baking ...
# 1                                 current price $2.98
# 3   Great Value Semi-Sweet Chocolate Baking Chips,...
# 4                                 current price $2.62
# 6   Nestle Toll House Semi Sweet Chocolate Mini Ba...
# 7                                 current price $2.98
# 9   Great Value Mini Semi-Sweet Chocolate Baking C...
# 10                                current price $2.32

# %%
chips_list = pd.DataFrame({'Name':df7['Name'].iloc[::2].values, 'Current Price':df7['Name'].iloc[1::2].values})
chips_list
# Out:
#                                                 Name        Current Price
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...  current price $2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...  current price $2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...  current price $2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...  current price $2.32

# %%
chips_list[['1', '2']] = chips_list['Current Price'].str.split('$', expand=True)
print(chips_list)
# Out:
#                                                 Name        Current Price  \
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...  current price $2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...  current price $2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...  current price $2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...  current price $2.32
#
#                 1     2
# 0  current price   2.98
# 1  current price   2.62
# 2  current price   2.98
# 3  current price   2.32

# %%
chips_list = chips_list.drop(['Current Price', '1'], axis=1)
chips_list.columns = ["Name", "Current Price"]
chips_list
# Out:
#                                                 Name Current Price
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...          2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...          2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...          2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...          2.32

# %%
chips_list["Category"] = "Chocolate Chips"
chips_list
# Out:
#                                                 Name Current Price  \
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...          2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...          2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...          2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...          2.32
#
#           Category
# 0  Chocolate Chips
# 1  Chocolate Chips
# 2  Chocolate Chips
# 3  Chocolate Chips

# %%
chips_list["Store"] = "Walmart"
chips_list
# Out:
#                                                 Name Current Price  \
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...          2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...          2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...          2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...          2.32
#
#           Category    Store
# 0  Chocolate Chips  Walmart
# 1  Chocolate Chips  Walmart
# 2  Chocolate Chips  Walmart
# 3  Chocolate Chips  Walmart

# %%
walmart_info = [egg_list, flour_list, sugar_list, milk_list, vanilla_list, butter_list, chips_list]
walmart_df = pd.concat(walmart_info)
walmart_df
# Out:
#                                                 Name Current Price  \
# 0            Great Value Large White Eggs, 12 Count           2.78
# 1            Great Value Jumbo White Eggs, 12 Count           3.47
# 2   Marketside Large Cage-Free Brown Eggs, 12 Count           3.58
# 3         Eggland's Best Large White Eggs, 12 Count           2.96
# 4  Eggland's Best Cage Free Large, Brown Eggs, 12...          4.14
# 5  Marketside Organic Cage-Free Large Brown Eggs,...          4.42
# 6   Eggland's Best Extra Large White Eggs, 12 Count           3.18
# 7  Vital Farms Pasture Raised Grade A Large Brown...          6.12
# 8  Pete and Gerry's Organic Free Range Large Brow...          5.18
# 0            Great Value All-Purpose Flour, 5LB Bag           2.43
# 1                      GV All Purpose Flour 2LB Bag           1.32
# 2             Great Value All-Purpose Flour, 10 lbs           4.34
# 3  King Arthur Baking Company All-Purpose Unbleac...          5.24
# 4  Gold Medal Four, All Purpose Flour, Cooking An...          2.98
# 5  Gold Medal Flour, All Purpose Flour, Baking An...          3.98
# 6  Pillsbury Best All Purpose Flour, Bleached, En...          4.37
# 7  Gold Medal Flour, All Purpose Flour, Baking An...          7.23
# 8           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )           6.97
# 0           Great Value Pure Granulated Sugar, 4 lb           3.24
# 1           Great Value Pure Granulated Sugar, 10lb           8.17
# 2   Domino Premium Pure Cane Granulated Sugar, 4 lb           4.54
# 3  Domino Premium Pure Cane Granulated Sugar, 1 l...          1.72
# 4          Great Value Pure Granulated Sugar, 25 Lb          19.97
# 5   Great Value Organic Granulated Cane Sugar, 2 Lb           3.14
# 6  Domino Pure Cane Granulated Golden Sugar, 1.75...          2.24
# 0                Lactaid 2% Reduced Fat Milk, 64 oz           4.48
# 1  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...          2.98
# 2  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...          2.98
# 3  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...          1.98
# 4  fairlife Lactose Free 2% Reduced Fat Ultra Fil...          4.48
# 5  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...          3.97
# 6  Great Value Organic 2% Reduced Fat Milk, Half ...          3.98
# 7  Great Value Organic Reduced Fat 2% Milk, 1 Gal...          6.98
# 8  Great Value Lactose Free 2% Reduced Fat Milk, ...          3.38
# 0  Great Value Pure Vanilla Extract, 2 fl oz (Foo...          5.72
# 1         Baker's Imitation Vanilla Flavor, 8 fl oz           1.46
# 2  McCormick Pure Vanilla Extract, 2 fl oz Baking...          6.97
# 3  Great Value Pure Vanilla Extract, 1 fl oz (Amb...          3.94
# 4           Molina Mexican Vanilla Blend, 8.3 FL OZ           1.58
# 5  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...          8.98
# 0  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 1  Great Value Sweet Cream Unsalted Butter Sticks...          3.98
# 2  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 3  Horizon Organic Unsalted Butter Sticks, 16 oz ...          7.12
# 4         (20 Pack)Kerrygold Unsalted Butter, 8 oz.         135.47
# 0  Nestle Toll House Semi Sweet Chocolate Baking ...          2.98
# 1  Great Value Semi-Sweet Chocolate Baking Chips,...          2.62
# 2  Nestle Toll House Semi Sweet Chocolate Mini Ba...          2.98
# 3  Great Value Mini Semi-Sweet Chocolate Baking C...          2.32
#
#           Category    Store
# 0             Eggs  Walmart
# 1             Eggs  Walmart
# 2             Eggs  Walmart
# 3             Eggs  Walmart
# 4             Eggs  Walmart
# 5             Eggs  Walmart
# 6             Eggs  Walmart
# 7             Eggs  Walmart
# 8             Eggs  Walmart
# 0            Flour  Walmart
# 1            Flour  Walmart
# 2            Flour  Walmart
# 3            Flour  Walmart
# 4            Flour  Walmart
# 5            Flour  Walmart
# 6            Flour  Walmart
# 7            Flour  Walmart
# 8            Flour  Walmart
# 0            Sugar  Walmart
# 1            Sugar  Walmart
# 2            Sugar  Walmart
# 3            Sugar  Walmart
# 4            Sugar  Walmart
# 5            Sugar  Walmart
# 6            Sugar  Walmart
# 0             Milk  Walmart
# 1             Milk  Walmart
# 2             Milk  Walmart
# 3             Milk  Walmart
# 4             Milk  Walmart
# 5             Milk  Walmart
# 6             Milk  Walmart
# 7             Milk  Walmart
# 8             Milk  Walmart
# 0  Vanilla Extract  Walmart
# 1  Vanilla Extract  Walmart
# 2  Vanilla Extract  Walmart
# 3  Vanilla Extract  Walmart
# 4  Vanilla Extract  Walmart
# 5  Vanilla Extract  Walmart
# 0           Butter  Walmart
# 1           Butter  Walmart
# 2           Butter  Walmart
# 3           Butter  Walmart
# 4           Butter  Walmart
# 0  Chocolate Chips  Walmart
# 1  Chocolate Chips  Walmart
# 2  Chocolate Chips  Walmart
# 3  Chocolate Chips  Walmart

# %%
walmart_df.reset_index(drop=True, inplace=True)
walmart_df
# Out:
#                                                  Name Current Price  \
# 0             Great Value Large White Eggs, 12 Count           2.78
# 1             Great Value Jumbo White Eggs, 12 Count           3.47
# 2    Marketside Large Cage-Free Brown Eggs, 12 Count           3.58
# 3          Eggland's Best Large White Eggs, 12 Count           2.96
# 4   Eggland's Best Cage Free Large, Brown Eggs, 12...          4.14
# 5   Marketside Organic Cage-Free Large Brown Eggs,...          4.42
# 6    Eggland's Best Extra Large White Eggs, 12 Count           3.18
# 7   Vital Farms Pasture Raised Grade A Large Brown...          6.12
# 8   Pete and Gerry's Organic Free Range Large Brow...          5.18
# 9             Great Value All-Purpose Flour, 5LB Bag           2.43
# 10                      GV All Purpose Flour 2LB Bag           1.32
# 11             Great Value All-Purpose Flour, 10 lbs           4.34
# 12  King Arthur Baking Company All-Purpose Unbleac...          5.24
# 13  Gold Medal Four, All Purpose Flour, Cooking An...          2.98
# 14  Gold Medal Flour, All Purpose Flour, Baking An...          3.98
# 15  Pillsbury Best All Purpose Flour, Bleached, En...          4.37
# 16  Gold Medal Flour, All Purpose Flour, Baking An...          7.23
# 17           OG2 AM UNBLCHD WHITE FLR ( 8 X 5 LB   )           6.97
# 18           Great Value Pure Granulated Sugar, 4 lb           3.24
# 19           Great Value Pure Granulated Sugar, 10lb           8.17
# 20   Domino Premium Pure Cane Granulated Sugar, 4 lb           4.54
# 21  Domino Premium Pure Cane Granulated Sugar, 1 l...          1.72
# 22          Great Value Pure Granulated Sugar, 25 Lb          19.97
# 23   Great Value Organic Granulated Cane Sugar, 2 Lb           3.14
# 24  Domino Pure Cane Granulated Golden Sugar, 1.75...          2.24
# 25                Lactaid 2% Reduced Fat Milk, 64 oz           4.48
# 26  Parmalat 2% Reduced Fat Milk, 32 fl oz (Shelf-...          2.98
# 27  Parmalat Lactose Free 2% Reduced Fat Milk, 32 ...          2.98
# 28  Tuscan Dairy Farms 2% Reduced Fat Milk with Vi...          1.98
# 29  fairlife Lactose Free 2% Reduced Fat Ultra Fil...          4.48
# 30  a2 Milk, Ultra-Pasteurized 2% Reduced Fat Milk...          3.97
# 31  Great Value Organic 2% Reduced Fat Milk, Half ...          3.98
# 32  Great Value Organic Reduced Fat 2% Milk, 1 Gal...          6.98
# 33  Great Value Lactose Free 2% Reduced Fat Milk, ...          3.38
# 34  Great Value Pure Vanilla Extract, 2 fl oz (Foo...          5.72
# 35         Baker's Imitation Vanilla Flavor, 8 fl oz           1.46
# 36  McCormick Pure Vanilla Extract, 2 fl oz Baking...          6.97
# 37  Great Value Pure Vanilla Extract, 1 fl oz (Amb...          3.94
# 38           Molina Mexican Vanilla Blend, 8.3 FL OZ           1.58
# 39  Watkins Baking Vanilla, 8 fl oz (Plastic Conta...          8.98
# 40  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 41  Great Value Sweet Cream Unsalted Butter Sticks...          3.98
# 42  Kerrygold Grass-Fed Pure Irish Unsalted Butter...          4.27
# 43  Horizon Organic Unsalted Butter Sticks, 16 oz ...          7.12
# 44         (20 Pack)Kerrygold Unsalted Butter, 8 oz.         135.47
# 45  Nestle Toll House Semi Sweet Chocolate Baking ...          2.98
# 46  Great Value Semi-Sweet Chocolate Baking Chips,...          2.62
# 47  Nestle Toll House Semi Sweet Chocolate Mini Ba...          2.98
# 48  Great Value Mini Semi-Sweet Chocolate Baking C...          2.32
#
#            Category    Store
# 0              Eggs  Walmart
# 1              Eggs  Walmart
# 2              Eggs  Walmart
# 3              Eggs  Walmart
# 4              Eggs  Walmart
# 5              Eggs  Walmart
# 6              Eggs  Walmart
# 7              Eggs  Walmart
# 8              Eggs  Walmart
# 9             Flour  Walmart
# 10            Flour  Walmart
# 11            Flour  Walmart
# 12            Flour  Walmart
# 13            Flour  Walmart
# 14            Flour  Walmart
# 15            Flour  Walmart
# 16            Flour  Walmart
# 17            Flour  Walmart
# 18            Sugar  Walmart
# 19            Sugar  Walmart
# 20            Sugar  Walmart
# 21            Sugar  Walmart
# 22            Sugar  Walmart
# 23            Sugar  Walmart
# 24            Sugar  Walmart
# 25             Milk  Walmart
# 26             Milk  Walmart
# 27             Milk  Walmart
# 28             Milk  Walmart
# 29             Milk  Walmart
# 30             Milk  Walmart
# 31             Milk  Walmart
# 32             Milk  Walmart
# 33             Milk  Walmart
# 34  Vanilla Extract  Walmart
# 35  Vanilla Extract  Walmart
# 36  Vanilla Extract  Walmart
# 37  Vanilla Extract  Walmart
# 38  Vanilla Extract  Walmart
# 39  Vanilla Extract  Walmart
# 40           Butter  Walmart
# 41           Butter  Walmart
# 42           Butter  Walmart
# 43           Butter  Walmart
# 44           Butter  Walmart
# 45  Chocolate Chips  Walmart
# 46  Chocolate Chips  Walmart
# 47  Chocolate Chips  Walmart
# 48  Chocolate Chips  Walmart

# %%
walmart_df.to_csv('walmart_data.csv')
